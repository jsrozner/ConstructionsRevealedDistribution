# %%
# %load_ext autoreload
# %autoreload 2

# %%
from lib.common.mlm_singleton import init_singleton_scorer
from rozlib.libs.plotting.utils_latex_matplot import config_matplot_for_latex, FigSaver
import os

# make sure we init the scorer for all modules first
mlm_scorer = init_singleton_scorer('roberta-large')
# mlm_scorer = init_singleton_scorer('ltg/gpt-bert-babylm-base')

# make the warnings shut up (likely bc of latex call)
os.environ["TOKENIZERS_PARALLELISM"] = "true"
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/cxs_local/lib/python3.12/site-packages/memoization/memoization.py:112: SyntaxWarning: Expected custom_key_maker to have the same signature as the function being cached. Call memoization.suppress_warnings() before using @cached to remove this message.
#   warnings.warn('Expected custom_key_maker to have the same signature as the function being cached. '
# WARNING:root:Initializing roberta-large, None
# WARNING:root:INIT

# %%
# from transformers import AutoModelForMaskedLM, PreTrainedTokenizerFast
#
# model_name = 'ltg/gpt-bert-babylm-base'
# model = AutoModelForMaskedLM.from_pretrained(model_name)
# tokenizer = PreTrainedTokenizerFast.from_pretrained(model_name)
#
# encoding = tokenizer("Hi I am on a farm.", return_tensors='pt', return_offsets_mapping=True)
# print(encoding)

# %%
from lib.plotting.plots import full_plot_single_sentence
from affinity.plots_new import full_plot_single_sentence_new

# for paper ARRreview
config_matplot_for_latex(10, dpi=100)

s1 = "I was so upset that I could not present at the conference."

s1 = "He was hiking and apple by apple he made his way home."
# s1 = "He was hiking and got lost, but he carefully rationed his remaining food and apple by apple he made his way home."
s1 = "The higher up the nicer!"
s1 = "He kicked at the ball."
s1 = "I saw my favorite band, Red Year, in concert. I like Red Year because of their interesting musical style."
s1 = "He made his way."
s1 = "I was so upset that I could not present at the conference."
s1 = "I was so happy that you are crying."
s1 = "And the fact that none of her so - called friends at the college — not even her room - mate — had cared enough to warn her that her handsome fiancé apparently regarded an engagement as no pressing reason to stop playing the field "
s1 = "She had tried hard not to fall in love with him , preferring to play the field and maybe trap a man whose heart was fancy free "
s1 = "So she had played the field , enjoying male company without getting in too deep or too seriously '"
s1 = "Theda turned her head and noted the set look in the other 's face ."
s1 = "All of these generalisations depend of course on a constant wind speed sufficient to fly the kite within its designed wind window ."
s1 = "We made our way home."
# s1 = "I was so happy that you told me that I had won the competition that I cried."
# s1 = "I was so happy that you told me that I had won the competition that we had been working on for months that seemed to stretch endlessly that I called my Mom."
s1 = "I was so happy that you told me that I had won the competition that we had been working on for months that I called my Mom."
s1 = "The supper was so good and the old-young people were so merry that Tilda forgot her fears."
s1 = "The movies that the fellow has are good."
s1 = "The authors know many different foreign languages and also has books."
s1 = "My favorite band is Green Day."
s1 = "Did the person who has seen this boy did try?"
s1 = "Is the child that is alone is unhappy?"
s1 = "Was the child that was alone was unhappy?"
s1 = "I do not have a bike, let alone a car."
s2 = "I do not have a car, let alone a bike."
s2 = "It was so upset that it could not fit."
s2 = "I was so happy to see my date that he actually got scared." # that the speech made me cry." #could get my clothes on"
s2 = "The blargle was so nargled that he coughed." # that the speech made me cry." #could get my clothes on"
s2 = "The blargle was so nargy that he couldn't speak." # that the speech made me cry." #could get my clothes on"
s2 = "The dog was so upset that it could not go outside." # that the speech made me cry." #could get my clothes on"
s2 = "Let alone the man I have not seen the woman." # that the speech made me cry." #could get my clothes on"
# s2 = "The super more, the lesser merrier." # that the speech made me cry." #could get my clothes on"
# s2 = "He has not been put on trial, let alone found guilty." # that the speech made me cry." #could get my clothes on"
s1 = "They liked to discuss the nuts and bolts." # that the speech made me cry." #could get my clothes on"
s1 = "Once John spilled the beans, everyone knew the secret." # that the speech made me cry." #could get my clothes on"
s1 = "It is a secret so do not spill the beans." # that the speech made me cry." #could get my clothes on"
# s1 = "His mom told him to keep his nose clean." # that the speech made me cry." #could get my clothes on"
# s1 = "In the morning we get up, but in the evenings we lie down. But we are down to dance, and we get on with our lives and we get on with presentations." # that the speech made me cry." #could get my clothes on"
# s1 = "People put on clothes." # that the speech made me cry." #could get my clothes on"
# s2 = "But people put up with other people."
# s2 = "The two of them liked to eat nuts and bolts." # that the speech made me cry." #could get my clothes on"
# s2 = "neither the man is here, let alone the woman." # that the speech made me cry." #could get my clothes on"
# s1 = "The dog that had seen the boy barked. Did the dog that had seen the boy bark?"

# s1 = "I know that the lion ate yesterday."
# s1 = "The dog that had seen the boy barked. Had the dog that seen the boy bark?"
# s1 = "I was so happy that you told me that I had won the competition that we had been working on for months and so I called my Mom."
# s1 = "I was so happy that I cried."
def x(s):
    f = full_plot_single_sentence_new(s,
                                      do_print=True,
                                      plot_local=True,
                                      use_euclid=False,
                                      num_preds=5,
                                      add_scores_on_top_font_size=10,
                                      fig_size=(10,2)
                                      # normalize =False
                                      )

x(s1)
# x(s2)
# Out:
# /Users/jsrozner/docs_local/research/proj_code/rozner-mono-cxs-main/rozlib-python/rozlib/libs/plotting/utils_latex_matplot.py:44: UserWarning: /Library/TeX/textbin will be added to path
#   warnings.warn(f"/Library/TeX/textbin will be added to path")
# /Users/jsrozner/docs_local/research/proj_code/rozner-mono-cxs-main/proj/cxs_are_revealed/src/affinity/tokenization.py:344: UserWarning: using a function that does not assert that words match
#   warnings.warn("using a function that does not assert that words match")
# global affinities:
# [0.427, 0.54, 0.534, 0.871, 0.101, 0.973, 0.985, 0.997, 0.968, 0.945]
# multitoken indices are:
#  []
# Top predictions for each word are:
# [['This', 'It', 'That', 'There', 'Here'],
#  [' is', "'s", ' remains', ' was', ' still'],
#  [' a', ' top', ' our', ' my', ' super'],
#  [' secret', ' mystery', ' joke', ' trap', ' crime'],
#  [',', ';', ' so', ' and', ' -'],
#  [' do', ' please', ' lets', ' let', ' better'],
# ...

# %%
from lib.scoring_fns import probability, surprisal
from affinity.corr_matrix_new import get_logits_for_masked_sent, compute_surprisal_for_logits, compute_single_local_affinity
from affinity.tokenization import Sentence

s1 = "It is a secret so do not spill the beans." # that the speech made me cry." #could get my clothes on"
s = Sentence(s1)    # Sentence class takes care of tokenization

# prepare sentence with mask at correct location
# punctuation is preserved, but will not be part of the mask
# this will error if your word is not actually present or if your word is multi-tokenized
# masked_sent keeps track of what was masked
# masked_sent = s.get_input_with_word_masked("Green")
compute_single_local_affinity(
    s,
    index_to_check=9,
    index_to_perturb=3,
    expect_word_at_index_to_check="beans",
    expect_word_at_index_to_perturb="secret",
    print_fills_topk=5
)

# %%
from pathlib import Path

# from utils.utils_latex_matplot import save_fig, config_matplot_for_latex, FigSaver

# config_matplot_for_latex(12, dpi=500)
# figs_dir = Path("/proj/cxs_are_revealed/supplemental/figs")
# # fs = FigSaver()
# if not "fs" in locals():
#     # avoid redefine
#     fs = FigSaver(figs_dir)

# %%
from pprint import pp
from affinity.tokenization import Sentence
# s1 = "I saw my favorite band Green Day in concert."
s1 = "Hi I am on a farm."
s1_s = Sentence(s1)
# s2 = "I saw my favorite band, Green Day, in concert."
# s2 = "Checking if tokenization works."
# s2_s = Sentence(s2)

# pp(s1_s.word_encodings)

# %%
"""Green day examples"""
# from utils.plotting.plots import full_plot_single_sentence

# s1 = "I took a walk down memory lane."
s1 = "My favorite band is Green Day."
s1 = "I was so happy that I cried."
s1 = "I was so full that my stomach hurt."
s1 = "It was so big that it fell over."
config_matplot_for_latex(8, dpi=500)
s1 = "In the boxing match, they went jaw to jaw, exchanging fierce punches each round."
# s1 = "I took a trip down memory lane."
# s1 = "I bought a red shirt at the store."
s1 = "I was so sad that I had cried."
s1 = "In the bustling kitchen, the chef stacked pan upon pan, creating a towering monument of cookware."
s1 = "John is not playing his freshman year; he's red shirting."
s1 = "Nervous though he was, he still managed to do okay."
s1 = ("Handsome though everyone expects me to try to force Bill to make Mom agree "
      "that Dick is, I'm still going to marry Herman.")

s1 = "I saw my favorite band Green Day in concert."
s1 = "I saw my favorite band , Green Day , in concert"
s1 = "That was so easy; it was a piece of cake."
s1 = "I don't like this topic; it is not my cup of tea."
s1 = "That disaster, bad as it was, still pales in comparison to the hurricane of 1950."
# s1 = "Impressive as they said it seems, I am not moved."
# s1 = "The work continued, doubtful though the mother thought that the associate seemed."
# s1 = "The work continued, though the mother thought that the associate seemed doubtful."
# s1 = ("Though everyone expects me to try to force Bill to make Mom agree "
#       "that Dick is handsome, I'm still going to marry Herman.")
#
# s1 = ("Handsome though everyone expects me to try to force Bill to make Mom agree "
#       "that Dick is, I'm still going to marry Herman.")
# s1 = "I know that the lion ate the deer."
# s1 = "I know what the lion ate yesterday."
# s1 = "I know that the lion devoured the deer."
# s1 = "Alice went to the hardware store and she bought a hammer."
# s1 = "My favorite is Green Day."
s1 = "Even though the man in the blue shirt was in a red car, the shirt was still blue."
s1 = "The man was in a dark colored car and wearing bright clothes. I liked his pink hat."
s1 = "His favorite color is yellow. He is a bus driver."
s1 = "His favorite color is pink. He prefers to date women."
s1 = "He likes books. Relatedly his favorite color is black."
s1 = "John's favorite color is red. Sarah's is blue. Mine is orange. Alex likes pink."
s1 = "The work continued quickly, slow though the manager knew she was."
# s1 = "My favorite band is Green Day."
# s1 = "The work continued quickly, though the worker was slow."
f = full_plot_single_sentence_new(s1,
                                  do_print=True,
                                  plot_local=True,
                                  use_euclid=False,
                                  num_preds=5,
                                  # normalize =False
                                  )
# fs.save(f)

# use save_fig to save these
# gaf1 = plot_everything(s1, plot_heamap=False)
# gaf1.insert(2, 0)   # for band
# gaf2 = plot_everything(s2, plot_heamap=False)
# Out:
# /Users/jsrozner/docs_local/research/projects/research_constructions/constructions_repo/rozlib-python/rozlib/libs/plotting/utils_latex_matplot.py:44: UserWarning: /Library/TeX/textbin will be added to path
#   warnings.warn(f"/Library/TeX/textbin will be added to path")
# /Users/jsrozner/docs_local/research/projects/research_constructions/constructions_repo/proj/cxs_are_revealed/src/affinity/tokenization.py:338: UserWarning: using a function that does not assert that words match
#   warnings.warn("using a function that does not assert that words match")
# global affinities:
# [0.166, 0.009, 0.003, 0.004, 0.0, 0.003, 0.342, 0.001, 0.064, 0.001, 0.41]
# multitoken indices are:
#  []
# Top predictions for each word are:
# [['Her', 'The', 'But', 'His', 'Their'],
#  [' conversation', ' woman', ' girl', ' interview', ' waitress'],
#  [' went', ' came', ' passed', ' progressed', ' moved'],
#  [' on', ' though', ' uninterrupted', ' however', ' quietly'],
# ...

# %%
 = "My favorite is Green Day."
# all_words = s1.strip(".").split(" ")
# print(all_words)
# plot_single(gaf1, all_words, [])
full_plot_single_sentence(s)
# Out:
#   Cell In[12], line 1
#     = "My favorite is Green Day."
#     ^
# SyntaxError: invalid syntax

# %%
config_matplot_for_latex(14)

words_1 = all_words.copy()
words_1[2] = (r"\dots .")
# plot_new([gaf1], words_1)
# plot_new([gaf2], all_words)

fig = plot_mult([
    ([gaf1], words_1),
    ([gaf2], all_words),
],
    overall_fig_size=(3,3),
    x_locs=[[2], []]
)
save_fig(fig, "gaf_green_day_band.pdf")
# Out:
# /Users/jsrozner/docs_local/_programming/research_constructions/constructions_repo/utils/utils_latex_matplot.py:62: UserWarning: /Library/TeX/textbin will be added to path
#   warnings.warn(f"/Library/TeX/textbin will be added to path")
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 10
#       4 words_1[2] = (r"\dots .")
#       5 # plot_new([gaf1], words_1)
#       6 # plot_new([gaf2], all_words)
#       8 fig = plot_mult([
#       9     ([gaf1], words_1),
# ---> 10     ([gaf2], all_words),
#      11 ],
#      12     overall_fig_size=(3,3),
#      13     x_locs=[[2], []]
#      14 )
#      15 save_fig(fig, "gaf_green_day_band.pdf")
#
# NameError: name 'gaf2' is not defined
