# %%
# %load_ext autoreload
# %autoreload 2

# %%
from proj.cxs_are_revealed.paper.data_config import Exp4NPN
from dataclasses import dataclass, field
from typing import List

from lib.common.mlm_singleton import init_singleton_scorer
mlm_scorer = init_singleton_scorer('roberta-large', output_attentions=True)

# add or remove to produce the diff plots
judgement_filter = True
# Out:
# WARNING:root:Initializing roberta-large
# WARNING:root:INIT

# %%
from rozlib.libs.common.data.utils_jsonl import read_from_jsonl
from proj.cxs_are_revealed.paper.proj_common.npn_dataset_generation.npn_utils import GPTOutput, HumanAnnotation, count_for_stats
from proj.cxs_are_revealed.paper.proj_common.npn_dataset_generation.npn_utils import filter_outputs

gpt_outputs: List[GPTOutput] = read_from_jsonl(Exp4NPN.npn_gpt_outputs, GPTOutput)
gpt_outputs_after = filter_outputs(gpt_outputs)
gpt_outputs_with_id = [(idx, go) for idx, go in enumerate(gpt_outputs_after)]
for go in gpt_outputs_with_id:
    go[1].output = go[1].output.strip()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2 from paper.exp4_npn.npn_utils import GPTOutput, HumanAnnotation, count_for_stats
#       3 from paper.exp4_npn.npn_utils import filter_outputs
# ----> 5 gpt_outputs: List[GPTOutput] = read_from_jsonl(Exp4NPN.npn_gpt_outputs, GPTOutput)
#       6 gpt_outputs_after = filter_outputs(gpt_outputs)
#       7 gpt_outputs_with_id = [(idx, go) for idx, go in enumerate(gpt_outputs_after)]
#
# File ~/docs_local/research/projects/research_constructions/constructions_repo/rozlib-python/rozlib/libs/common/data/utils_jsonl.py:63, in read_from_jsonl(file_path, cls)
#      61         sentence_dict = json.loads(line.strip())
#      62         # Convert the dictionary back into an MLMResultForSentence object
# ---> 63         sentence_result = from_dict(cls, sentence_dict)
#      64         result.append(sentence_result)
#      66 return result
#
# File ~/docs_local/research/projects/research_constructions/constructions_repo/rozlib-python/rozlib/libs/common/data/utils_dataclass.py:29, in from_dict(cls, dict_obj)
#      26 # try:
#      27 fieldtypes = {f.name: f.type for f in fields(cls)}
#      28 return (
# ---> 29     cls(**{f: from_dict(fieldtypes[f], dict_obj[f])
#      30     if isinstance(dict_obj[f], dict)
#      31     else dict_obj[f]
#      32            for f in dict_obj}))
#
# File ~/docs_local/research/projects/research_constructions/constructions_repo/rozlib-python/rozlib/libs/common/data/utils_dataclass.py:27, in from_dict(cls, dict_obj)
#      16 """
#      17 Recursively converts a dictionary to a dataclass.
#      18
#    (...)
#      24     An instance of the dataclass with the dictionary values populated.
#      25 """
#      26 # try:
# ---> 27 fieldtypes = {f.name: f.type for f in fields(cls)}
#      28 return (
#      29     cls(**{f: from_dict(fieldtypes[f], dict_obj[f])
#      30     if isinstance(dict_obj[f], dict)
#      31     else dict_obj[f]
#      32            for f in dict_obj}))
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/2024_coelm/lib/python3.12/dataclasses.py:1289, in fields(class_or_instance)
#    1287     fields = getattr(class_or_instance, _FIELDS)
#    1288 except AttributeError:
# -> 1289     raise TypeError('must be called with a dataclass type or instance') from None
#    1291 # Exclude pseudo-fields.  Note that fields is sorted by insertion
#    1292 # order, so the order of the tuple is as the fields were defined.
#    1293 return tuple(f for f in fields.values() if f._field_type is _FIELD)
#
# TypeError: must be called with a dataclass type or instance

# %% [markdown]
# ### read in judgements

# %%
from rozlib.libs.common.data.utils_dataclass import read_csv_to_dataclass

def read_judgements() -> List[HumanAnnotation]:
    all_judgements = read_csv_to_dataclass(HumanAnnotation, Exp4NPN.npn_acceptability_ratings_csv)
    for j in all_judgements:
        j.id = int(j.id)
        j.rating = int(j.rating)
        j.sentence = j.sentence.strip()
    return all_judgements
all_judgements = read_judgements()

# %%
# check that everything lines up
# for j in all_judgements:
#     e = gpt_outputs_with_id[j.id]
#     assert j.sentence.strip() == e[1].output.strip()

judgements_aligned = sorted(all_judgements, key=lambda x: x.id)

for i, zipped in enumerate(zip(judgements_aligned, gpt_outputs_with_id)):
    j, e = zipped
    assert j.sentence == e[1].output.strip(), i

# %%
# note does not have bad words removed yet
count_for_stats(judgements_aligned, gpt_outputs_with_id)
# Out:
# Counter({'upon': 64, 'after': 59, 'by': 32, 'to': 7})

# %%
from typing import Tuple


# below adapted from exp8_cogs (which was in turn prev adapted from sth else)
@dataclass
class GPTOut:
    id: int = field(init=False)
    sent: str = field(init=False)
    # indexes in the string
    # tgt_words: List[int] = field(init=False)
    tgt_word_offsets: List[Tuple[int, int]] = field(default_factory=list)
    words: List[str] = field(init=False)


def get_all_data_clean():
    ret_list: List[GPTOut] = []
    for idx, r in enumerate(gpt_outputs_after):
        dr = GPTOut()
        ret_list.append(dr)
        dr.id = idx
        dr.sent = r.output

        # get tgt words
        tgt_str = f"{r.noun.str_rep_no_space} {r.prep} {r.noun.str_rep_no_space}"
        phrase_idx_start = dr.sent.find(tgt_str)
        phrase_idx_end = phrase_idx_start + len(tgt_str)
        phrase_parts = r.output[phrase_idx_start: phrase_idx_end].split(" ")
        for pp, expected in zip(phrase_parts, [r.noun.str_rep_no_space, r.prep, r.noun.str_rep_no_space]):
            assert pp == expected, f"{pp} != {expected}"

        tgt_word_offsets = []
        start_idx = phrase_idx_start
        for w in phrase_parts:
            w_len = len(w)
            assert r.output[start_idx: start_idx + w_len] == w, f"{tgt_str[start_idx: start_idx + w_len]} != {w}"
            tgt_word_offsets.append((start_idx, start_idx + w_len))
            start_idx += w_len + 1  # add 1 for space
        dr.tgt_word_offsets = tgt_word_offsets
        dr.words = [r.output[x[0]: x[1]] for x in dr.tgt_word_offsets]
        for w, expected in zip(dr.words, [r.noun.str_rep_no_space, r.prep, r.noun.str_rep_no_space]):
            assert w == expected, f"{w} != {expected}"

    return ret_list

all_outs_clean = get_all_data_clean()

# %%
all_outs_clean[0]
# Out:
# GPTOut(id=0, sent='After a stressful week of work, she found herself in a cycle of binge after binge, unable to break free from the unhealthy pattern.', tgt_word_offsets=[(64, 69), (70, 75), (76, 81)], words=['binge', 'after', 'binge'])

# %%
from proj.cxs_are_revealed.paper.cxns_in_distrib.exp3_magpie import WrappedIdiomWord, set_allow_deprecated
from transformers import BatchEncoding

set_allow_deprecated()  # for magpie wrapper

# copied from exp8_cogs
class EntryWrapper:
    """ Adapted from MAGPIE_Wrapper"""
    def __init__(self, entry: GPTOut):
        """
        Steps:
        - get the total wordlist (contiguous non space strings)
        - get the alphabetic wordlist (candidates for masking)
        - get the list of idiom words (those with offsets)
            (checks that idiom words do not have spaces in them)

        """
        self.cog_entry = entry

        encoding = mlm_scorer.get_batch_encoding_for_sentence(entry.sent)

        # idiom token indices
        self.idiom_token_list: List[WrappedIdiomWord] = self.get_idiom_token_list(encoding)

        # later (other methods)
        # produce a list of possible tokens / words to mask from a sentence

    def get_idiom_token_list(self, encoding: BatchEncoding):
        offset_to_token_list_map: List[WrappedIdiomWord] = []
        for offset in self.cog_entry.tgt_word_offsets:
            wrapped_idiom = WrappedIdiomWord.wrap_idiom_using_encoding(self.cog_entry, offset, encoding)
            offset_to_token_list_map.append(wrapped_idiom)

        assert len(offset_to_token_list_map) == len(self.cog_entry.tgt_word_offsets)
        return offset_to_token_list_map

# %%
all_wrapped = []
for go in all_outs_clean:
    all_wrapped.append(EntryWrapper(go))

all_wrapped[0].idiom_token_list
# Out:
# [WrappedIdiomWord(offset=(64, 69), idiom_word_chars='binge', tokens=[15], token_words=['binge'], is_multiple_tokens=False, tokens_do_not_exact_match=False),
#  WrappedIdiomWord(offset=(70, 75), idiom_word_chars='after', tokens=[16], token_words=['after'], is_multiple_tokens=False, tokens_do_not_exact_match=False),
#  WrappedIdiomWord(offset=(76, 81), idiom_word_chars='binge', tokens=[17], token_words=['binge'], is_multiple_tokens=False, tokens_do_not_exact_match=False)]

# %%
from proj.cxs_are_revealed.paper.cxns_in_distrib.exp3_magpie import EntryForProcessing
from tqdm import tqdm
from lib.scoring_fns import probability

"""
Accrue results by cx type and word (word or idx)
 - todo: check multitoken, eg
"""
# copied from exp8_cogs
def process_sent_exp8(
        entry_wrapped: EntryWrapper,
        print_preds = False
) -> List[float]:
    scores: List[float] = []
    entry = entry_wrapped.cog_entry
    entry_for_processing = EntryForProcessing(entry.id, entry.sent)
    tgt_words = [entry_wrapped.idiom_token_list[0], entry_wrapped.idiom_token_list[2]]  # skip the preposition
    for word_to_mask in tgt_words:
        assert word_to_mask.is_multiple_tokens is False and word_to_mask.tokens_do_not_exact_match is False
        t_idx = word_to_mask.tokens[0]
        inputs_ids = entry_for_processing.get_inputs_with_mask_for_token_at_idx(
            t_idx)
        # get likely fills
        outputs = mlm_scorer.get_model_outputs_for_input(inputs_ids)
        logits = outputs.logits

        # predictions is vocab_len [logit, logit, ... logit]
        token_logits = logits[0, t_idx]     # batch, idx, then vocab_len shape

        orig_token_id = entry_for_processing.input_ids[0, t_idx]

        # compute surprisal
        surprisal_score = probability(token_logits, orig_token_id)
        if print_preds:
            mlm_scorer._print_preds(token_logits)
        scores.append(surprisal_score.item())
    return scores

def get_all_scores():
    all_scores: List[List[float]] = []
    for cog_wrapped in tqdm(all_wrapped):
        scores = process_sent_exp8(cog_wrapped)
        all_scores.append(scores)
    return all_scores

# %%
# runs in 15 seconds on an m3 mac
all_scores = get_all_scores()
# Out:
# 100%|██████████| 295/295 [00:00<00:00, 377.82it/s]

# %%
print(all_scores[35])
ct = 0
for i, s_list in enumerate(all_scores):
    for s in s_list:
        if s < 0.5:
            print(s_list)
            print(all_wrapped[i].cog_entry.words[0])
            print(all_wrapped[i].cog_entry.sent)
            ct+=1
            break
print(ct)
# Out:
# [0.0007737943669781089, 2.1112222725605534e-07]
# [0.2974763512611389, 0.9923263788223267]
# guard
# In the high-security prison, the inmates were watched guard by guard to ensure maximum vigilance.
# [0.8869944214820862, 0.11219833791255951]
# real
# In this digital era, we must strive for authenticity, living real by real, not through the filtered lens of social media.
# [0.26252731680870056, 0.5224451422691345]
# real
# In the art world, one can observe real upon real, as artists strive to capture the essence of reality in their work.
# [0.18840014934539795, 0.0003085724310949445]
# pen
# The author, lost in his craft, scribbled away pen to pen, endlessly working on his novel.
# [0.032162681221961975, 0.17842085659503937]
# odds
# The team had to fight odds by odds to finally win the championship.
# [0.997226893901825, 8.551950304536149e-05]
# legislation
# The government continued to introduce legislation after legislation, striving to improve the country's economic situation.
# [0.011708199046552181, 0.029575832188129425]
# legislation
# The government painstakingly created legislation by legislation to ensure the protection of the environment.
# [0.0007737943669781089, 2.1112222725605534e-07]
# stink
# Despite his best efforts to clean the place, the kitchen reeked of stink by stink, evidence of the week-old garbage still lurking in the corner.
# [5.1152624109818134e-06, 0.0005802895175293088]
# myriad
# The archaeologist spent a lifetime uncovering myriad by myriad of ancient artifacts, each one telling a unique story of the past.
# [0.2832317054271698, 0.9047900438308716]
# sibling
# Despite their constant bickering, they remained sibling after sibling, inseparable in their bond.
# [0.049344178289175034, 0.608820915222168]
# imagination
# Through his life, he painted scenes of fantasy, building imagination by imagination, into a world of his own.
# [0.0028330509085208178, 0.9497196674346924]
# director
# In the bustling world of film, it's often director by director that unique storytelling styles shape the cinematic landscape.
# [0.6506151556968689, 0.01476652268320322]
# rating
# The film industry, obsessed with success and failure, measures a movie's performance rating by rating, scrutinizing every detail for potential improvements.
# [0.00041393228457309306, 0.15233542025089264]
# cross
# The determined pilgrim traveled cross to cross, marking his journey through the sacred land.
# [0.9977139234542847, 0.0049540335312485695]
# joy
# In his pursuit of happiness, he experienced joy by joy, each one more profound than the last.
# [0.2095777988433838, 0.3869330585002899]
# interior
# The decorator meticulously planned every detail, enhancing the design interior after interior.
# [0.14626531302928925, 0.4387367069721222]
# butt
# In the gym, he performed the strenuous routine of butt after butt exercises, pushing his body to the limits.
# [0.03358156606554985, 7.187471783254296e-05]
# horsepower
# The new model of the car, enhancing horsepower after horsepower, became a sensation among the racing enthusiasts.
# [0.0027761803939938545, 3.9111848309403285e-05]
# horsepower
# The car's engine improved horsepower by horsepower, delighting the auto enthusiasts.
# [0.0075508952140808105, 0.012659210711717606]
# spectacle
# In the heart of New York City, Times Square delivers spectacle by spectacle to the millions of dazzled tourists each year.
# [0.0449506938457489, 0.0025104116648435593]
# ease
# With the gentle melody playing in the background, she felt an ease after ease washing over her, calming her troubled mind.
# [0.005692877806723118, 0.4441970884799957]
# ease
# With practice and patience, she found herself improving, achieving ease by ease in her yoga poses.
# [0.7091502547264099, 0.0015633244765922427]
# felon
# The prison system was overflowing, felon by felon, the numbers kept increasing at an alarming rate.
# [4.529936268227175e-05, 0.00010449022374814376]
# liner
# The shipping company continued to expand its fleet, adding liner by liner to meet the growing demand.
# [0.053388096392154694, 0.9810608625411987]
# tow
# As the storm raged on, the stranded ship was tow after tow, pulling it closer to safety.
# [0.004825191106647253, 0.0074030025862157345]
# tow
# The mechanic worked on the broken down vehicle, arranging for tow by tow to get all the cars off the highway after the massive pile-up.
# [0.23334409296512604, 6.427241169149056e-05]
# tow
# The heavy snowfall resulted in car after car needing a tow upon tow to get them out of the snowdrift.
# [0.01114730630069971, 0.0015229163691401482]
# fat
# In his quest for healthy living, he tirelessly worked out, striving to lose fat after fat.
# [0.00028575651231221855, 0.012927449308335781]
# fat
# He kept eating junk food, gaining fat by fat, until his health began to deteriorate.
# [2.7656948077492416e-05, 0.007340485230088234]
# comp
# She was working on her programming project, writing comp to comp, until she finally found the solution.
# [0.0070897117257118225, 7.152713078539819e-05]
# may
# In this uncertain world, decisions may by may, alter the course of our lives dramatically.
# [0.0011811115546151996, 0.1365383118391037]
# may
# "In the whimsical world of the language poets, one may upon may be piled in their verses, creating a tower of possibilities and interpretations."
# [0.01425733882933855, 1.052798870659899e-05]
# facade
# Behind the cheerful facade to facade, the old building hid a grim history.
# [0.4935460686683655, 0.029589790850877762]
# pudding
# In the dessert competition, she impressed the judges by stacking pudding by pudding, each varying in flavor and color.
# [0.0001991732424357906, 0.006591471377760172]
# retirement
# After diligently saving and planning, he began to envision his retirement to retirement, a leisurely life completely free from work obligations.
# [0.013157444074749947, 0.1398489773273468]
# retirement
# He planned for his golden years meticulously, focusing on retirement after retirement of his various investment portfolios.
# [4.040187559439801e-05, 0.017849238589406013]
# retirement
# He had planned his finances meticulously, ensuring that he would live retirement by retirement without financial worry.
# [6.961996405152604e-05, 0.9671173691749573]
# retirement
# He stacked his savings, retirement upon retirement, to enjoy his golden years comfortably.
# [0.9928398132324219, 0.21130035817623138]
# intolerance
# In a society seemingly fueled by hatred, it was a case of intolerance after intolerance, threatening the unity and peace of the community.
# [2.315059433044553e-08, 0.9958937168121338]
# intolerance
# The society was splintering, intolerance by intolerance, into factions of deep-seated hatred.
# [0.35360732674598694, 0.00018989600357599556]
# introduction
# "After studying the subject for hours, he found himself reading introduction to introduction, attempting to fully grasp the concept."
# [0.001031267223879695, 0.582291305065155]
# pool
# After a long day at work, he sought relaxation pool after pool.
# [9.584424986996964e-08, 0.8065101504325867]
# nobility
# In the royal court, decisions are made nobility by nobility, ensuring that only those of high birth can influence the kingdom's affairs.
# [0.0002491885970812291, 0.024280056357383728]
# retail
# Despite the changing economic landscape, many businesses choose to operate retail to retail, believing in the power of personal customer interaction.
# [0.013568508438766003, 0.001552108209580183]
# retail
# After analyzing the sales data, they noticed a trend of retail after retail showing an increase in revenue.
# [0.00025107295368798077, 0.012110844254493713]
# retail
# The company's growth was a result of retail by retail expansion, establishing a presence in every major city.
# [0.0016120836371555924, 0.9889434576034546]
# table
# In the vast library, she meticulously arranged table by table, ensuring each was ready for the upcoming event.
# [0.9833741188049316, 0.017235493287444115]
# automation
# The factory evolved, implementing automation after automation, becoming a symbol of modern industry.
# [0.0626654252409935, 0.046246789395809174]
# automation
# In the modern technological world, we are seeing automation by automation being implemented in various industries to increase efficiency and productivity.
# [0.052560072392225266, 0.16713908314704895]
# female
# In her pursuit of gender equality, she fought female to female, challenging societal norms and breaking down barriers.
# [0.321355402469635, 0.022438867017626762]
# female
# The company prioritized hiring female after female, striving to balance its workforce.
# [0.03284286707639694, 0.05796412378549576]
# female
# In this organization, we promote equality, treating each individual fairly, female by female, to foster an inclusive environment.
# [0.9960254430770874, 0.3358541429042816]
# railway
# The country's industrial growth, spurred by the construction of railway after railway, transformed the landscape dramatically.
# [3.290103632025421e-05, 0.9897983074188232]
# railway
# The city expanded rapidly, growing railway by railway, until it was a bustling hub of transportation.
# [0.0017770364647731185, 0.05186121165752411]
# rpm
# The engine was running smoothly, maintaining a constant rpm to rpm, ensuring the car's optimal performance.
# [0.0049326056614518166, 0.5039252638816833]
# rpm
# The engine maintained its performance, running smoothly at rpm by rpm, even after hours of continuous use.
# [0.0010766716441139579, 3.0843781132716686e-05]
# rpm
# The mechanic worked diligently, increasing the engine's performance rpm upon rpm.
# [0.002509811893105507, 0.00015806146257091314]
# catching
# As the football game continued, the team kept catching to catching, impressively improving their coordination and execution.
# [0.2834169864654541, 0.22563117742538452]
# catching
# The detective followed the trail tirelessly, catching by catching, until he finally solved the case.
# [0.010361271910369396, 0.0038816798478364944]
# catching
# The baseball coach emphasized the importance of catching upon catching to perfect the team's fielding skills.
# [0.03538670763373375, 0.9985929131507874]
# yacht
# In the high-end marina, you could see yacht by yacht lined up, showcasing the wealth of the area.
# [0.02595101296901703, 0.9979222416877747]
# likeness
# In the art gallery, she studied the portraits, noting how they were arranged likeness by likeness, reflecting the evolution of the artist's style.
# [0.08446753025054932, 1.7434766050428152e-05]
# firm
# Despite the economic turmoil, the company stood firm to firm, demonstrating an unyielding commitment to its core values.
# [0.46133503317832947, 0.0008938264800235629]
# modeling
# In the field of architecture, they focused on modeling upon modeling to perfect their design.
# [0.48845618963241577, 3.0377108487300575e-05]
# jail
# After being incarcerated multiple times, he found himself in jail by jail, understanding the harsh realities of the penal system.
# [0.00392306549474597, 0.003346853656694293]
# duplication
# The scientists were stunned as they observed duplication by duplication in the rapid replication of the virus.
# [0.01270468719303608, 6.399766425602138e-05]
# turnaround
# The company reported a turnaround after turnaround, reflecting its strong recovery from the previous financial crisis.
# [0.5362605452537537, 6.589858116967662e-07]
# turnaround
# The project manager was determined to ensure a turnaround by turnaround progress in the company's failing performance.
# [0.012816269882023335, 0.0015063649043440819]
# turnaround
# The company has been experiencing a significant turnaround upon turnaround, showing impressive recovery in the market.
# [0.0292173121124506, 0.0019392856629565358]
# beginning
# The novel unfolded beginning to beginning, each chapter a new start in the protagonist's life.
# [0.0013955481117591262, 3.97800249629654e-06]
# annoying
# Despite trying to maintain her patience, she found his behavior annoying after annoying, causing her to eventually snap.
# [5.243558553047478e-05, 2.66515817202162e-05]
# lakh
# The charity received a donation of lakh after lakh, considerably boosting their funding for the upcoming project.
# [0.027152040973305702, 0.35741597414016724]
# pretending
# In the drama club, they were pretending after pretending, trying to perfect their roles for the upcoming play.
# [0.015902550891041756, 0.007881333120167255]
# pretending
# In her pursuit of fame, she lived a life of pretending by pretending, creating a facades that fooled everyone around her.
# [0.0011385515099391341, 0.835189163684845]
# pretending
# In the theater world, it was always pretending upon pretending, layering one false identity over another.
# [0.0010070211719721556, 0.0023993076756596565]
# chin
# The barbershop was so busy, with customers waiting chin by chin for their turn.
# [0.993171215057373, 0.20193445682525635]
# chin
# The weary boxer leaned on the ropes, taking hit after hit, chin upon chin, refusing to go down.
# [4.5279441110324115e-05, 0.9987927675247192]
# clergy
# The church continued to grow, clergy by clergy, expanding its reach into new communities.
# [0.42136886715888977, 0.03575298190116882]
# purchasing
# The company continued to expand, purchasing after purchasing, until they dominated the entire market.
# [0.0003774727520067245, 2.8855169148300774e-05]
# purchasing
# The CEO noticed that, despite the company's financial struggles, the trend of purchasing by purchasing continued unabated.
# [0.004942551255226135, 0.3715344965457916]
# purchasing
# The company has been steadily growing, purchasing upon purchasing, expanding their products range exponentially.
# [0.10771138966083527, 0.0003845035971608013]
# rapport
# Building trust within a team requires establishing rapport by rapport, fostering a sense of unity and cooperation.
# [0.9754771590232849, 0.4351418912410736]
# rapport
# In order to foster a positive work environment, it's essential to build rapport upon rapport with colleagues and subordinates alike.
# [0.00212335423566401, 0.9989884495735168]
# cable
# The technician worked tirelessly, connecting cable by cable, to restore the internet service in the entire building.
# [0.002223009243607521, 0.06158478185534477]
# combustion
# The factory continued its operations, causing combustion after combustion, contributing to the worsening air pollution in the city.
# [0.07365889847278595, 0.003807441098615527]
# combustion
# In the field of thermodynamics, they studied the process of combustion by combustion, exploring every minute detail.
# [3.166190865044882e-08, 0.00062637246446684]
# combustion
# In the field of automotive engineering, they tirelessly seek improvements, striving for combustion upon combustion efficiency.
# [4.3100244511151686e-05, 0.02699451893568039]
# serve
# In the restaurant industry, it's always serve to serve, maintaining the high standards of customer service.
# [0.014654602855443954, 6.994762225076556e-05]
# serve
# As a dedicated waiter at the upscale restaurant, I strive to serve after serve, ensuring each guest experiences top-notch service.
# [0.9920589923858643, 0.27119430899620056]
# serve
# In the bustling restaurant, the dedicated waitstaff continue to serve upon serve, tirelessly attending to the needs of the patrons.
# [0.008874775841832161, 0.2367853820323944]
# km
# He ran km to km, challenging himself to increase his distance every day.
# [0.017116496339440346, 6.075436613173224e-05]
# raven
# In the eerie forest, she heard the distinct call of a raven by raven, echoing through the silence.
# [0.3246113061904907, 0.26839354634284973]
# primary
# In the life of a student, it's often a journey from primary to primary, as they transition from primary colors in kindergarten to primary numbers in grade school, and then onto primary sources in high school.
# [0.608818531036377, 0.4487323462963104]
# primary
# The students tackled the task with diligence, revising primary by primary to ensure they had a thorough understanding of the material.
# [0.021621521562337875, 0.5752029418945312]
# primary
# In the heart of the city, she observed primary upon primary school vying for top positions in the national rankings.
# [0.008001833222806454, 0.8292925953865051]
# concentration
# In her intense study regimen, she tackled the complex material concentration by concentration, pushing her knowledge boundaries wider.
# [0.17477023601531982, 0.00010047098476206884]
# conditioning
# The athlete was committed to conditioning after conditioning, constantly pushing his body to its limits.
# [7.532432209700346e-05, 0.6239818930625916]
# conditioning
# The technician worked tirelessly, conditioning by conditioning, to ensure the HVAC system was functioning optimally.
# [0.9390770196914673, 0.08381212502717972]
# scrub
# In the hospital, they maintained strict hygiene protocols, performing scrub after scrub on their hands before each surgical procedure.
# [0.005077031906694174, 0.001016366994008422]
# ambiguity
# In the complex world of modern politics, it's often a case of ambiguity by ambiguity, with each statement seemingly designed to obfuscate rather than clarify.
# [0.10775735974311829, 0.9962406158447266]
# jazz
# He immersed himself in the music scene, experiencing jazz after jazz performance in the heart of the city.
# [5.134481398272328e-06, 0.9950302839279175]
# jazz
# He practiced relentlessly, jazz by jazz, until he mastered the intricate melodies.
# [0.036035675555467606, 0.9135683178901672]
# investor
# The business world is witnessing a new trend, with investor by investor turning towards sustainable investing.
# [1.516321646022334e-07, 0.0002491675259079784]
# retro
# In the vintage shop, she was amazed to find retro by retro items that reminded her of her childhood.
# 104

# %%
for oc, goa in zip(all_outs_clean, gpt_outputs_after):
    print(oc.sent, "\n", goa.output)
# Out:
# After a stressful week of work, she found herself in a cycle of binge after binge, unable to break free from the unhealthy pattern.
#  After a stressful week of work, she found herself in a cycle of binge after binge, unable to break free from the unhealthy pattern.
# His unhealthy eating habits continued, binge by binge, leading to serious health problems.
#  His unhealthy eating habits continued, binge by binge, leading to serious health problems.
# In his struggle with addiction, he found himself in a dangerous cycle of binge upon binge.
#  In his struggle with addiction, he found himself in a dangerous cycle of binge upon binge.
# In the high-security prison, the inmates were watched guard by guard to ensure maximum vigilance.
#  In the high-security prison, the inmates were watched guard by guard to ensure maximum vigilance.
# In the security company, they stacked guard upon guard, ensuring the safety of the high-profile client.
#  In the security company, they stacked guard upon guard, ensuring the safety of the high-profile client.
# In this digital era, we must strive for authenticity, living real by real, not through the filtered lens of social media.
#  In this digital era, we must strive for authenticity, living real by real, not through the filtered lens of social media.
# In the art world, one can observe real upon real, as artists strive to capture the essence of reality in their work.
#  In the art world, one can observe real upon real, as artists strive to capture the essence of reality in their work.
# The artist painstakingly arranged the mosaic, tile by tile, until a beautiful pattern emerged.
#  The artist painstakingly arranged the mosaic, tile by tile, until a beautiful pattern emerged.
# In the grand mosaic masterpiece, he painstakingly placed tile upon tile, ensuring each piece fit perfectly into the intricate design.
#  In the grand mosaic masterpiece, he painstakingly placed tile upon tile, ensuring each piece fit perfectly into the intricate design.
# The author, lost in his craft, scribbled away pen to pen, endlessly working on his novel.
#  The author, lost in his craft, scribbled away pen to pen, endlessly working on his novel.
# As a calligrapher, I practiced pen after pen, seeking the perfect strokes in each character.
#  As a calligrapher, I practiced pen after pen, seeking the perfect strokes in each character.
# As the author meticulously crafted his novel, he worked pen by pen, pouring his soul into each word.
#  As the author meticulously crafted his novel, he worked pen by pen, pouring his soul into each word.
# In the artist's studio, there were sketches scattered everywhere, with pen upon pen used to create the intricate designs.
#  In the artist's studio, there were sketches scattered everywhere, with pen upon pen used to create the intricate designs.
# During the campaign, it was a relentless pursuit of voter after voter, trying to secure every possible vote.
#  During the campaign, it was a relentless pursuit of voter after voter, trying to secure every possible vote.
# In the democratic nation, decisions were made voter by voter, ensuring everyone's voice was heard.
#  In the democratic nation, decisions were made voter by voter, ensuring everyone's voice was heard.
# The community meeting hall began to fill, voter upon voter, eager to cast their ballots in the local election.
#  The community meeting hall began to fill, voter upon voter, eager to cast their ballots in the local election.
# Despite the challenges, he persevered, overcoming odds after odds in his journey towards success.
#  Despite the challenges, he persevered, overcoming odds after odds in his journey towards success.
# The team had to fight odds by odds to finally win the championship.
#  The team had to fight odds by odds to finally win the championship.
# In the world of professional gambling, it's all about stacking odds upon odds to maximize potential profit.
#  In the world of professional gambling, it's all about stacking odds upon odds to maximize potential profit.
# The concert was a spectacle, showcasing singer to singer, each more talented than the last.
#  The concert was a spectacle, showcasing singer to singer, each more talented than the last.
# The talent show featured singer after singer, each delivering a more breathtaking performance than the last.
#  The talent show featured singer after singer, each delivering a more breathtaking performance than the last.
# In the bustling city nightlife, the music industry thrived with singer by singer taking the stage and leaving the crowds in awe.
#  In the bustling city nightlife, the music industry thrived with singer by singer taking the stage and leaving the crowds in awe.
# At the annual music festival, the audience was treated to singer upon singer, each performing their heart out on the grand stage.
#  At the annual music festival, the audience was treated to singer upon singer, each performing their heart out on the grand stage.
# In the world of coding, he found himself navigating through acronym after acronym.
#  In the world of coding, he found himself navigating through acronym after acronym.
# In the world of technology, jargons and abbreviations pile up, acronym by acronym, making it a complicated field for the uninitiated.
#  In the world of technology, jargons and abbreviations pile up, acronym by acronym, making it a complicated field for the uninitiated.
# In the world of computer programming, they were creating acronym upon acronym to simplify complex technical jargon.
#  In the world of computer programming, they were creating acronym upon acronym to simplify complex technical jargon.
# The government continued to introduce legislation after legislation, striving to improve the country's economic situation.
#  The government continued to introduce legislation after legislation, striving to improve the country's economic situation.
# The government painstakingly created legislation by legislation to ensure the protection of the environment.
#  The government painstakingly created legislation by legislation to ensure the protection of the environment.
# The government continued to pile legislation upon legislation, further complicating the legal system.
#  The government continued to pile legislation upon legislation, further complicating the legal system.
# Astronomers have been studying asteroid after asteroid to better understand the composition of our solar system.
#  Astronomers have been studying asteroid after asteroid to better understand the composition of our solar system.
# The space probe maneuvered through the cosmos, dodging asteroid by asteroid in its quest to reach the outer regions of our solar system.
#  The space probe maneuvered through the cosmos, dodging asteroid by asteroid in its quest to reach the outer regions of our solar system.
# In the vast expanse of the cosmos, they discovered asteroid upon asteroid, each with its own unique properties and potential for scientific discovery.
#  In the vast expanse of the cosmos, they discovered asteroid upon asteroid, each with its own unique properties and potential for scientific discovery.
# The suspense in the novel built up climax after climax, leaving the readers on the edge of their seats.
#  The suspense in the novel built up climax after climax, leaving the readers on the edge of their seats.
# The tension in the thriller movie built up climax by climax, keeping the audience on the edge of their seats.
#  The tension in the thriller movie built up climax by climax, keeping the audience on the edge of their seats.
# The novel built up tension, reaching climax upon climax, keeping the readers on the edge of their seats.
#  The novel built up tension, reaching climax upon climax, keeping the readers on the edge of their seats.
# Despite his best efforts to clean the place, the kitchen reeked of stink by stink, evidence of the week-old garbage still lurking in the corner.
#  Despite his best efforts to clean the place, the kitchen reeked of stink by stink, evidence of the week-old garbage still lurking in the corner.
# In the sweltering heat of the city dump, he faced a nauseating pile of garbage, stink upon stink assaulting his senses relentlessly.
#  In the sweltering heat of the city dump, he faced a nauseating pile of garbage, stink upon stink assaulting his senses relentlessly.
# The archaeologist spent a lifetime uncovering myriad by myriad of ancient artifacts, each one telling a unique story of the past.
#  The archaeologist spent a lifetime uncovering myriad by myriad of ancient artifacts, each one telling a unique story of the past.
# In the heart of the city, you could see myriad upon myriad of twinkling lights illuminating the night sky.
#  In the heart of the city, you could see myriad upon myriad of twinkling lights illuminating the night sky.
# The poker player, known for his bold moves, continued to raise the bet, stake after stake, until his opponents folded.
#  The poker player, known for his bold moves, continued to raise the bet, stake after stake, until his opponents folded.
# The company was built stake by stake, each investment carefully considered and meticulously executed.
#  The company was built stake by stake, each investment carefully considered and meticulously executed.
# In his relentless pursuit of success, he laid stake upon stake, risking everything in the process.
#  In his relentless pursuit of success, he laid stake upon stake, risking everything in the process.
# Despite their constant bickering, they remained sibling after sibling, inseparable in their bond.
#  Despite their constant bickering, they remained sibling after sibling, inseparable in their bond.
# In the crowded household, it was always sibling by sibling, each one looking out for the other in a world that often seemed too big and uncaring.
#  In the crowded household, it was always sibling by sibling, each one looking out for the other in a world that often seemed too big and uncaring.
# In the large family reunion, they gathered, sibling upon sibling, creating a heartwarming scene of familial love and unity.
#  In the large family reunion, they gathered, sibling upon sibling, creating a heartwarming scene of familial love and unity.
# In the realm of fantasy literature, authors build world upon world, imagination after imagination, creating a multiverse of enchanting possibilities.
#  In the realm of fantasy literature, authors build world upon world, imagination after imagination, creating a multiverse of enchanting possibilities.
# Through his life, he painted scenes of fantasy, building imagination by imagination, into a world of his own.
#  Through his life, he painted scenes of fantasy, building imagination by imagination, into a world of his own.
# In the realm of creative writing, the author built worlds, crafting imagination upon imagination.
#  In the realm of creative writing, the author built worlds, crafting imagination upon imagination.
# In the world of filmmaking, the role of a director is often seen as pivotal, with director after director emphasizing the importance of a clear vision and strong leadership.
#  In the world of filmmaking, the role of a director is often seen as pivotal, with director after director emphasizing the importance of a clear vision and strong leadership.
# In the bustling world of film, it's often director by director that unique storytelling styles shape the cinematic landscape.
#  In the bustling world of film, it's often director by director that unique storytelling styles shape the cinematic landscape.
# In the competitive world of filmmaking, it was director upon director vying for the top position at the prestigious film festival.
#  In the competitive world of filmmaking, it was director upon director vying for the top position at the prestigious film festival.
# The movie's success was undeniable, earning rating after rating from renowned critics.
#  The movie's success was undeniable, earning rating after rating from renowned critics.
# The film industry, obsessed with success and failure, measures a movie's performance rating by rating, scrutinizing every detail for potential improvements.
#  The film industry, obsessed with success and failure, measures a movie's performance rating by rating, scrutinizing every detail for potential improvements.
# The movie's success piled rating upon rating, catapulting it to the top of the charts.
#  The movie's success piled rating upon rating, catapulting it to the top of the charts.
# The determined pilgrim traveled cross to cross, marking his journey through the sacred land.
#  The determined pilgrim traveled cross to cross, marking his journey through the sacred land.
# In the old church, the priest found cross after cross hidden in the dusty corners.
#  In the old church, the priest found cross after cross hidden in the dusty corners.
# In the old cathedral, the priest arranged the relics cross by cross, paying attention to each detail.
#  In the old cathedral, the priest arranged the relics cross by cross, paying attention to each detail.
# In her art studio, she continued to layer cross upon cross to create a textured masterpiece.
#  In her art studio, she continued to layer cross upon cross to create a textured masterpiece.
# Experiencing joy after joy, the child's laughter filled the room.
#  Experiencing joy after joy, the child's laughter filled the room.
# In his pursuit of happiness, he experienced joy by joy, each one more profound than the last.
#  In his pursuit of happiness, he experienced joy by joy, each one more profound than the last.
# In the heart of the festival, they experienced joy upon joy, creating a memorable atmosphere.
#  In the heart of the festival, they experienced joy upon joy, creating a memorable atmosphere.
# The decorator meticulously planned every detail, enhancing the design interior after interior.
#  The decorator meticulously planned every detail, enhancing the design interior after interior.
# The decorator meticulously arranged the furniture, transforming the space interior by interior, until the entire house was beautifully furnished.
#  The decorator meticulously arranged the furniture, transforming the space interior by interior, until the entire house was beautifully furnished.
# The designer layered interior upon interior, creating a multi-dimensional space that was both intriguing and inviting.
#  The designer layered interior upon interior, creating a multi-dimensional space that was both intriguing and inviting.
# In the gym, he performed the strenuous routine of butt after butt exercises, pushing his body to the limits.
#  In the gym, he performed the strenuous routine of butt after butt exercises, pushing his body to the limits.
# In the gym, he performed exercises that targeted his glutes, doing butt by butt repetitions to strengthen and tone his muscles.
#  In the gym, he performed exercises that targeted his glutes, doing butt by butt repetitions to strengthen and tone his muscles.
# In the gym, he tirelessly worked out, doing butt upon butt exercises to improve his lower body strength.
#  In the gym, he tirelessly worked out, doing butt upon butt exercises to improve his lower body strength.
# The new model of the car, enhancing horsepower after horsepower, became a sensation among the racing enthusiasts.
#  The new model of the car, enhancing horsepower after horsepower, became a sensation among the racing enthusiasts.
# The car's engine improved horsepower by horsepower, delighting the auto enthusiasts.
#  The car's engine improved horsepower by horsepower, delighting the auto enthusiasts.
# The car's engine was improved, adding horsepower upon horsepower, making it a truly powerful machine.
#  The car's engine was improved, adding horsepower upon horsepower, making it a truly powerful machine.
# The government continued to pile on tax after tax, causing an uproar among the citizens.
#  The government continued to pile on tax after tax, causing an uproar among the citizens.
# The government was piling tax by tax on the citizens, leaving them struggling to make ends meet.
#  The government was piling tax by tax on the citizens, leaving them struggling to make ends meet.
# The government was piling tax upon tax, making it increasingly difficult for small businesses to survive.
#  The government was piling tax upon tax, making it increasingly difficult for small businesses to survive.
# In the heart of New York City, Times Square delivers spectacle by spectacle to the millions of dazzled tourists each year.
#  In the heart of New York City, Times Square delivers spectacle by spectacle to the millions of dazzled tourists each year.
# The carnival was a grand extravaganza, with spectacle upon spectacle thrilling the eager crowd.
#  The carnival was a grand extravaganza, with spectacle upon spectacle thrilling the eager crowd.
# With the gentle melody playing in the background, she felt an ease after ease washing over her, calming her troubled mind.
#  With the gentle melody playing in the background, she felt an ease after ease washing over her, calming her troubled mind.
# With practice and patience, she found herself improving, achieving ease by ease in her yoga poses.
#  With practice and patience, she found herself improving, achieving ease by ease in her yoga poses.
# With a deep inhale and a long exhale, he practiced his mindfulness exercise, seeking to layer ease upon ease in his anxiety-ridden mind.
#  With a deep inhale and a long exhale, he practiced his mindfulness exercise, seeking to layer ease upon ease in his anxiety-ridden mind.
# At the turtle sanctuary, it was a fascinating sight to see turtle after turtle slowly making their way towards the ocean.
#  At the turtle sanctuary, it was a fascinating sight to see turtle after turtle slowly making their way towards the ocean.
# In the quiet sanctuary, they watched as the turtles moved, turtle by turtle, towards the ocean.
#  In the quiet sanctuary, they watched as the turtles moved, turtle by turtle, towards the ocean.
# In the vast, untouched wilderness, the ranger observed turtle upon turtle basking in the sun, an unusual sight given their typically solitary nature.
#  In the vast, untouched wilderness, the ranger observed turtle upon turtle basking in the sun, an unusual sight given their typically solitary nature.
# The prison, notorious for its harsh conditions, was filled with felon after felon, all serving lengthy sentences for their crimes.
#  The prison, notorious for its harsh conditions, was filled with felon after felon, all serving lengthy sentences for their crimes.
# The prison system was overflowing, felon by felon, the numbers kept increasing at an alarming rate.
#  The prison system was overflowing, felon by felon, the numbers kept increasing at an alarming rate.
# In the overcrowded prison, it was a distressing sight of felon upon felon, stacked in cramped cells.
#  In the overcrowded prison, it was a distressing sight of felon upon felon, stacked in cramped cells.
# The cruise director meticulously planned liner after liner, ensuring each ship offered a unique experience for the passengers.
#  The cruise director meticulously planned liner after liner, ensuring each ship offered a unique experience for the passengers.
# The shipping company continued to expand its fleet, adding liner by liner to meet the growing demand.
#  The shipping company continued to expand its fleet, adding liner by liner to meet the growing demand.
# The shipping company continued to add to their fleet, stacking liner upon liner in the bustling port.
#  The shipping company continued to add to their fleet, stacking liner upon liner in the bustling port.
# As the storm raged on, the stranded ship was tow after tow, pulling it closer to safety.
#  As the storm raged on, the stranded ship was tow after tow, pulling it closer to safety.
# The mechanic worked on the broken down vehicle, arranging for tow by tow to get all the cars off the highway after the massive pile-up.
#  The mechanic worked on the broken down vehicle, arranging for tow by tow to get all the cars off the highway after the massive pile-up.
# The heavy snowfall resulted in car after car needing a tow upon tow to get them out of the snowdrift.
#  The heavy snowfall resulted in car after car needing a tow upon tow to get them out of the snowdrift.
# The admiral watched as navy after navy sailed across the vast ocean.
#  The admiral watched as navy after navy sailed across the vast ocean.
# The fleet grew steadily, navy by navy, until it was the most formidable in the world.
#  The fleet grew steadily, navy by navy, until it was the most formidable in the world.
# The general tirelessly worked to build his fleet, adding navy upon navy to ensure a formidable maritime presence.
#  The general tirelessly worked to build his fleet, adding navy upon navy to ensure a formidable maritime presence.
# In his quest for healthy living, he tirelessly worked out, striving to lose fat after fat.
#  In his quest for healthy living, he tirelessly worked out, striving to lose fat after fat.
# He kept eating junk food, gaining fat by fat, until his health began to deteriorate.
#  He kept eating junk food, gaining fat by fat, until his health began to deteriorate.
# He continued to eat unhealthy foods, accumulating fat upon fat on his body.
#  He continued to eat unhealthy foods, accumulating fat upon fat on his body.
# The computer technician worked diligently, dealing with disk after disk of corrupted data.
#  The computer technician worked diligently, dealing with disk after disk of corrupted data.
# In the data center, servers were stacked disk by disk, ensuring optimal storage and accessibility.
#  In the data center, servers were stacked disk by disk, ensuring optimal storage and accessibility.
# In the data center, we continued to stack disk upon disk to accommodate the increasing storage needs.
#  In the data center, we continued to stack disk upon disk to accommodate the increasing storage needs.
# She was working on her programming project, writing comp to comp, until she finally found the solution.
#  She was working on her programming project, writing comp to comp, until she finally found the solution.
# The software engineer had to go through comp after comp to find the error in the programming code.
#  The software engineer had to go through comp after comp to find the error in the programming code.
# Working with complex computer systems, he had to troubleshoot comp by comp to ensure they were all running efficiently.
#  Working with complex computer systems, he had to troubleshoot comp by comp to ensure they were all running efficiently.
# As the programmer worked on the project, he found himself dealing with comp upon comp, making the task increasingly complex.
#  As the programmer worked on the project, he found himself dealing with comp upon comp, making the task increasingly complex.
# The church continued to send missionary after missionary to the remote village, hoping to spread their beliefs.
#  The church continued to send missionary after missionary to the remote village, hoping to spread their beliefs.
# The church grew rapidly, missionary by missionary, spreading its message across the globe.
#  The church grew rapidly, missionary by missionary, spreading its message across the globe.
# The church continued to send missionary upon missionary to the remote village, hoping to spread their faith.
#  The church continued to send missionary upon missionary to the remote village, hoping to spread their faith.
# The tailor painstakingly created the intricate wedding dress, stitching linen by linen, until it was a masterpiece.
#  The tailor painstakingly created the intricate wedding dress, stitching linen by linen, until it was a masterpiece.
# In the old farmhouse, they found linen upon linen, stacked neatly in the ancient armoire.
#  In the old farmhouse, they found linen upon linen, stacked neatly in the ancient armoire.
# In this uncertain world, decisions may by may, alter the course of our lives dramatically.
#  In this uncertain world, decisions may by may, alter the course of our lives dramatically.
# "In the whimsical world of the language poets, one may upon may be piled in their verses, creating a tower of possibilities and interpretations."
#  "In the whimsical world of the language poets, one may upon may be piled in their verses, creating a tower of possibilities and interpretations."
# Behind the cheerful facade to facade, the old building hid a grim history.
#  Behind the cheerful facade to facade, the old building hid a grim history.
# The city was changing, facade after facade, as new buildings replaced the old.
#  The city was changing, facade after facade, as new buildings replaced the old.
# In the bustling city, we saw facade by facade of historical buildings, each with its own unique architectural style.
#  In the bustling city, we saw facade by facade of historical buildings, each with its own unique architectural style.
# The architect spent years perfecting his design, building facade upon facade, until he finally achieved the perfect aesthetic.
#  The architect spent years perfecting his design, building facade upon facade, until he finally achieved the perfect aesthetic.
# Her kitchen was a mess, with pudding after pudding lined up on the counters as she practiced for the dessert competition.
#  Her kitchen was a mess, with pudding after pudding lined up on the counters as she practiced for the dessert competition.
# In the dessert competition, she impressed the judges by stacking pudding by pudding, each varying in flavor and color.
#  In the dessert competition, she impressed the judges by stacking pudding by pudding, each varying in flavor and color.
# At the dessert contest, she stacked pudding upon pudding, creating a towering masterpiece that wowed the judges.
#  At the dessert contest, she stacked pudding upon pudding, creating a towering masterpiece that wowed the judges.
# After diligently saving and planning, he began to envision his retirement to retirement, a leisurely life completely free from work obligations.
#  After diligently saving and planning, he began to envision his retirement to retirement, a leisurely life completely free from work obligations.
# He planned for his golden years meticulously, focusing on retirement after retirement of his various investment portfolios.
#  He planned for his golden years meticulously, focusing on retirement after retirement of his various investment portfolios.
# He had planned his finances meticulously, ensuring that he would live retirement by retirement without financial worry.
#  He had planned his finances meticulously, ensuring that he would live retirement by retirement without financial worry.
# He stacked his savings, retirement upon retirement, to enjoy his golden years comfortably.
#  He stacked his savings, retirement upon retirement, to enjoy his golden years comfortably.
# In a society seemingly fueled by hatred, it was a case of intolerance after intolerance, threatening the unity and peace of the community.
#  In a society seemingly fueled by hatred, it was a case of intolerance after intolerance, threatening the unity and peace of the community.
# The society was splintering, intolerance by intolerance, into factions of deep-seated hatred.
#  The society was splintering, intolerance by intolerance, into factions of deep-seated hatred.
# In this deeply divided society, we are unfortunately witnessing intolerance upon intolerance, creating a widening chasm of misunderstanding and hatred.
#  In this deeply divided society, we are unfortunately witnessing intolerance upon intolerance, creating a widening chasm of misunderstanding and hatred.
# In the artist's studio, he layered shade after shade, creating a complex and richly textured painting.
#  In the artist's studio, he layered shade after shade, creating a complex and richly textured painting.
# In the artist's studio, he painted shade by shade, meticulously capturing the nuances of light.
#  In the artist's studio, he painted shade by shade, meticulously capturing the nuances of light.
# In the artist's studio, he meticulously layered shade upon shade to create depth in his monochromatic painting.
#  In the artist's studio, he meticulously layered shade upon shade to create depth in his monochromatic painting.
# The city grew at a rapid pace, erecting landmark after landmark as a testament to its growth and prosperity.
#  The city grew at a rapid pace, erecting landmark after landmark as a testament to its growth and prosperity.
# As we toured through the city, we encountered landmark by landmark, each one more breathtaking than the last.
#  As we toured through the city, we encountered landmark by landmark, each one more breathtaking than the last.
# As they travelled across the country, they encountered landmark upon landmark, each one more breathtaking than the last.
#  As they travelled across the country, they encountered landmark upon landmark, each one more breathtaking than the last.
# "After studying the subject for hours, he found himself reading introduction to introduction, attempting to fully grasp the concept."
#  "After studying the subject for hours, he found himself reading introduction to introduction, attempting to fully grasp the concept."
# In the rigorous academic course, the professor insisted on studying the historical texts introduction by introduction, ensuring a comprehensive understanding of each era.
#  In the rigorous academic course, the professor insisted on studying the historical texts introduction by introduction, ensuring a comprehensive understanding of each era.
# In the library of the philosophy department, he found himself buried under introduction upon introduction, as he sought to understand the complex theories.
#  In the library of the philosophy department, he found himself buried under introduction upon introduction, as he sought to understand the complex theories.
# After a long day at work, he sought relaxation pool after pool.
#  After a long day at work, he sought relaxation pool after pool.
# After a long day of work, he found tranquility pool by pool, finding each more serene than the last.
#  After a long day of work, he found tranquility pool by pool, finding each more serene than the last.
# In the game room, he stacked pool upon pool, creating an impressive tower of billiards.
#  In the game room, he stacked pool upon pool, creating an impressive tower of billiards.
# She cooked meal after meal, pan after pan, tirelessly for the entire family gathering.
#  She cooked meal after meal, pan after pan, tirelessly for the entire family gathering.
# In the bustling restaurant kitchen, the chefs worked tirelessly, moving pan by pan to keep up with the dinner rush.
#  In the bustling restaurant kitchen, the chefs worked tirelessly, moving pan by pan to keep up with the dinner rush.
# In the bustling kitchen, the chef stacked pan upon pan, creating a towering monument of cookware.
#  In the bustling kitchen, the chef stacked pan upon pan, creating a towering monument of cookware.
# In the royal court, decisions are made nobility by nobility, ensuring that only those of high birth can influence the kingdom's affairs.
#  In the royal court, decisions are made nobility by nobility, ensuring that only those of high birth can influence the kingdom's affairs.
# In the vast halls of the royal palace, they found nobility upon nobility, all vying for the king's favor.
#  In the vast halls of the royal palace, they found nobility upon nobility, all vying for the king's favor.
# From viewpoint to viewpoint, her understanding of the complex issue expanded and evolved.
#  From viewpoint to viewpoint, her understanding of the complex issue expanded and evolved.
# From a global perspective, considering viewpoint after viewpoint can lead to a more comprehensive understanding of a complex issue.
#  From a global perspective, considering viewpoint after viewpoint can lead to a more comprehensive understanding of a complex issue.
# In our complex discussions, we must approach each topic from viewpoint by viewpoint, considering each perspective carefully.
#  In our complex discussions, we must approach each topic from viewpoint by viewpoint, considering each perspective carefully.
# In the heat of the debate, they stacked viewpoint upon viewpoint, trying to reach a consensus.
#  In the heat of the debate, they stacked viewpoint upon viewpoint, trying to reach a consensus.
# The campaign gained momentum, drawing supporter after supporter from all corners of the country.
#  The campaign gained momentum, drawing supporter after supporter from all corners of the country.
# The charity event grew in size, supporter by supporter, until it became a national movement.
#  The charity event grew in size, supporter by supporter, until it became a national movement.
# In the passionate political rally, it was a sight to behold, supporter upon supporter, standing together in the crowded square.
#  In the passionate political rally, it was a sight to behold, supporter upon supporter, standing together in the crowded square.
# Despite the changing economic landscape, many businesses choose to operate retail to retail, believing in the power of personal customer interaction.
#  Despite the changing economic landscape, many businesses choose to operate retail to retail, believing in the power of personal customer interaction.
# After analyzing the sales data, they noticed a trend of retail after retail showing an increase in revenue.
#  After analyzing the sales data, they noticed a trend of retail after retail showing an increase in revenue.
# The company's growth was a result of retail by retail expansion, establishing a presence in every major city.
#  The company's growth was a result of retail by retail expansion, establishing a presence in every major city.
# The company continued to expand, stacking retail upon retail, to meet the increasing demand of the consumers.
#  The company continued to expand, stacking retail upon retail, to meet the increasing demand of the consumers.
# The restaurant was packed, with table after table being filled with hungry patrons.
#  The restaurant was packed, with table after table being filled with hungry patrons.
# In the vast library, she meticulously arranged table by table, ensuring each was ready for the upcoming event.
#  In the vast library, she meticulously arranged table by table, ensuring each was ready for the upcoming event.
# In the warehouse, they began stacking table upon table, creating a towering structure of furniture.
#  In the warehouse, they began stacking table upon table, creating a towering structure of furniture.
# The factory evolved, implementing automation after automation, becoming a symbol of modern industry.
#  The factory evolved, implementing automation after automation, becoming a symbol of modern industry.
# In the modern technological world, we are seeing automation by automation being implemented in various industries to increase efficiency and productivity.
#  In the modern technological world, we are seeing automation by automation being implemented in various industries to increase efficiency and productivity.
# In the modern world, we are experiencing automation upon automation, streamlining processes in every industry.
#  In the modern world, we are experiencing automation upon automation, streamlining processes in every industry.
# In her pursuit of gender equality, she fought female to female, challenging societal norms and breaking down barriers.
#  In her pursuit of gender equality, she fought female to female, challenging societal norms and breaking down barriers.
# The company prioritized hiring female after female, striving to balance its workforce.
#  The company prioritized hiring female after female, striving to balance its workforce.
# In this organization, we promote equality, treating each individual fairly, female by female, to foster an inclusive environment.
#  In this organization, we promote equality, treating each individual fairly, female by female, to foster an inclusive environment.
# In the historic women's march, it was inspiring to see female upon female standing together for their rights.
#  In the historic women's march, it was inspiring to see female upon female standing together for their rights.
# The country's industrial growth, spurred by the construction of railway after railway, transformed the landscape dramatically.
#  The country's industrial growth, spurred by the construction of railway after railway, transformed the landscape dramatically.
# The city expanded rapidly, growing railway by railway, until it was a bustling hub of transportation.
#  The city expanded rapidly, growing railway by railway, until it was a bustling hub of transportation.
# The city expanded, building railway upon railway to accommodate the growing population's transportation needs.
#  The city expanded, building railway upon railway to accommodate the growing population's transportation needs.
# The engine was running smoothly, maintaining a constant rpm to rpm, ensuring the car's optimal performance.
#  The engine was running smoothly, maintaining a constant rpm to rpm, ensuring the car's optimal performance.
# The technician carefully monitored the machine, noting the consistency of rpm after rpm.
#  The technician carefully monitored the machine, noting the consistency of rpm after rpm.
# The engine maintained its performance, running smoothly at rpm by rpm, even after hours of continuous use.
#  The engine maintained its performance, running smoothly at rpm by rpm, even after hours of continuous use.
# The mechanic worked diligently, increasing the engine's performance rpm upon rpm.
#  The mechanic worked diligently, increasing the engine's performance rpm upon rpm.
# As the football game continued, the team kept catching to catching, impressively improving their coordination and execution.
#  As the football game continued, the team kept catching to catching, impressively improving their coordination and execution.
# In the world of professional baseball, it's all about catching after catching, each one better than the last.
#  In the world of professional baseball, it's all about catching after catching, each one better than the last.
# The detective followed the trail tirelessly, catching by catching, until he finally solved the case.
#  The detective followed the trail tirelessly, catching by catching, until he finally solved the case.
# The baseball coach emphasized the importance of catching upon catching to perfect the team's fielding skills.
#  The baseball coach emphasized the importance of catching upon catching to perfect the team's fielding skills.
# He admired the marina, where it was yacht after yacht, each more luxurious than the last.
#  He admired the marina, where it was yacht after yacht, each more luxurious than the last.
# In the high-end marina, you could see yacht by yacht lined up, showcasing the wealth of the area.
#  In the high-end marina, you could see yacht by yacht lined up, showcasing the wealth of the area.
# In his extravagant lifestyle, he kept buying yacht upon yacht, filling up all the docks in his private marina.
#  In his extravagant lifestyle, he kept buying yacht upon yacht, filling up all the docks in his private marina.
# As an art critic, I visited gallery after gallery, scrutinizing the finest works of contemporary artists.
#  As an art critic, I visited gallery after gallery, scrutinizing the finest works of contemporary artists.
# In the bustling art district, she visited gallery by gallery, immersing herself in the array of paintings and sculptures.
#  In the bustling art district, she visited gallery by gallery, immersing herself in the array of paintings and sculptures.
# In the bustling city, they built gallery upon gallery, each showcasing unique and awe-inspiring art pieces.
#  In the bustling city, they built gallery upon gallery, each showcasing unique and awe-inspiring art pieces.
# In the art studio, the young sculptor worked diligently, creating likeness after likeness of his beloved muse.
#  In the art studio, the young sculptor worked diligently, creating likeness after likeness of his beloved muse.
# In the art gallery, she studied the portraits, noting how they were arranged likeness by likeness, reflecting the evolution of the artist's style.
#  In the art gallery, she studied the portraits, noting how they were arranged likeness by likeness, reflecting the evolution of the artist's style.
# In the artist's studio, he had created likeness upon likeness, each painting reflecting the subject's personality and mood in a different light.
#  In the artist's studio, he had created likeness upon likeness, each painting reflecting the subject's personality and mood in a different light.
# Despite the economic turmoil, the company stood firm to firm, demonstrating an unyielding commitment to its core values.
#  Despite the economic turmoil, the company stood firm to firm, demonstrating an unyielding commitment to its core values.
# The business grew steadily, firm after firm joining their conglomerate.
#  The business grew steadily, firm after firm joining their conglomerate.
# The company grew steadily, expanding firm by firm, creating a vast empire of interconnected businesses.
#  The company grew steadily, expanding firm by firm, creating a vast empire of interconnected businesses.
# In the corporate world, it's often a case of firm upon firm merging to create industry giants.
#  In the corporate world, it's often a case of firm upon firm merging to create industry giants.
# He continued to deceive us, pretext after pretext, until we could no longer trust his words.
#  He continued to deceive us, pretext after pretext, until we could no longer trust his words.
# He justified his actions with pretext by pretext, each one more elaborate than the last.
#  He justified his actions with pretext by pretext, each one more elaborate than the last.
# In the shady world of political maneuvering, it was pretext upon pretext that kept the corrupt official in power.
#  In the shady world of political maneuvering, it was pretext upon pretext that kept the corrupt official in power.
# In the boxing match, they went jaw to jaw, exchanging fierce punches each round.
#  In the boxing match, they went jaw to jaw, exchanging fierce punches each round.
# The boxer trained intensely, preparing for the fight jaw by jaw, focusing on his biting strength and endurance.
#  The boxer trained intensely, preparing for the fight jaw by jaw, focusing on his biting strength and endurance.
# The boxer took hit after hit, enduring jaw upon jaw impact with unwavering determination.
#  The boxer took hit after hit, enduring jaw upon jaw impact with unwavering determination.
# In the fashion industry, designers often find themselves in a cycle of modeling after modeling, constantly creating and showcasing new designs.
#  In the fashion industry, designers often find themselves in a cycle of modeling after modeling, constantly creating and showcasing new designs.
# In the world of data science, you will find yourself going through modeling by modeling, improving your techniques with each iteration.
#  In the world of data science, you will find yourself going through modeling by modeling, improving your techniques with each iteration.
# In the field of architecture, they focused on modeling upon modeling to perfect their design.
#  In the field of architecture, they focused on modeling upon modeling to perfect their design.
# Despite his efforts to reform, he found himself in jail after jail, seemingly trapped in a cycle of incarceration.
#  Despite his efforts to reform, he found himself in jail after jail, seemingly trapped in a cycle of incarceration.
# After being incarcerated multiple times, he found himself in jail by jail, understanding the harsh realities of the penal system.
#  After being incarcerated multiple times, he found himself in jail by jail, understanding the harsh realities of the penal system.
# The corrupt system seemed to pile jail upon jail, creating a cycle of recidivism that was almost impossible to escape.
#  The corrupt system seemed to pile jail upon jail, creating a cycle of recidivism that was almost impossible to escape.
# To perfect his pronunciation, he practiced vowel after vowel, making sure each one sounded just right.
#  To perfect his pronunciation, he practiced vowel after vowel, making sure each one sounded just right.
# As a linguistics professor, I have to correct students' pronunciation vowel by vowel.
#  As a linguistics professor, I have to correct students' pronunciation vowel by vowel.
# In her linguistics class, she meticulously studied vowel upon vowel, striving to understand the intricacies of pronunciation.
#  In her linguistics class, she meticulously studied vowel upon vowel, striving to understand the intricacies of pronunciation.
# The scientists were stunned as they observed duplication by duplication in the rapid replication of the virus.
#  The scientists were stunned as they observed duplication by duplication in the rapid replication of the virus.
# The scientist meticulously documented the process of DNA replication, recording every instance of duplication upon duplication in the genetic material.
#  The scientist meticulously documented the process of DNA replication, recording every instance of duplication upon duplication in the genetic material.
# The company reported a turnaround after turnaround, reflecting its strong recovery from the previous financial crisis.
#  The company reported a turnaround after turnaround, reflecting its strong recovery from the previous financial crisis.
# The project manager was determined to ensure a turnaround by turnaround progress in the company's failing performance.
#  The project manager was determined to ensure a turnaround by turnaround progress in the company's failing performance.
# The company has been experiencing a significant turnaround upon turnaround, showing impressive recovery in the market.
#  The company has been experiencing a significant turnaround upon turnaround, showing impressive recovery in the market.
# The novel unfolded beginning to beginning, each chapter a new start in the protagonist's life.
#  The novel unfolded beginning to beginning, each chapter a new start in the protagonist's life.
# The new author painstakingly edited his manuscript, making changes beginning after beginning, until he was satisfied with his work.
#  The new author painstakingly edited his manuscript, making changes beginning after beginning, until he was satisfied with his work.
# The project was a monumental task, requiring her to slog through beginning by beginning, each new phase presenting its own challenges.
#  The project was a monumental task, requiring her to slog through beginning by beginning, each new phase presenting its own challenges.
# The novice writer, struggling with his draft, found himself stuck in a loop of beginning upon beginning, never making progress to the middle of his story.
#  The novice writer, struggling with his draft, found himself stuck in a loop of beginning upon beginning, never making progress to the middle of his story.
# Despite trying to maintain her patience, she found his behavior annoying after annoying, causing her to eventually snap.
#  Despite trying to maintain her patience, she found his behavior annoying after annoying, causing her to eventually snap.
# The charity received a donation of lakh after lakh, considerably boosting their funding for the upcoming project.
#  The charity received a donation of lakh after lakh, considerably boosting their funding for the upcoming project.
# The charity managed to raise funds, lakh by lakh, until they reached their target of one crore.
#  The charity managed to raise funds, lakh by lakh, until they reached their target of one crore.
# The charity event was a huge success, raising lakh upon lakh for the local hospital.
#  The charity event was a huge success, raising lakh upon lakh for the local hospital.
# In the drama club, they were pretending after pretending, trying to perfect their roles for the upcoming play.
# ...
#  Despite the laundry pile growing sock after sock, she kept knitting with a smile.
# In the busy laundromat, she sorted through her clothes, placing sock by sock into the washing machine.
#  In the busy laundromat, she sorted through her clothes, placing sock by sock into the washing machine.
# She cleaned her children's room, finding sock upon sock under the bed.
#  She cleaned her children's room, finding sock upon sock under the bed.
# The farmer worked tirelessly, harvesting grain after grain from his abundant fields.
#  The farmer worked tirelessly, harvesting grain after grain from his abundant fields.
# The farmer patiently filled the silo, grain by grain, until it was brimming with the harvest.
#  The farmer patiently filled the silo, grain by grain, until it was brimming with the harvest.
# The diligent farmer tirelessly worked on his fields, stacking grain upon grain, until his silos were brimming with the fruits of his labor.
#  The diligent farmer tirelessly worked on his fields, stacking grain upon grain, until his silos were brimming with the fruits of his labor.
# The church continued to grow, clergy by clergy, expanding its reach into new communities.
#  The church continued to grow, clergy by clergy, expanding its reach into new communities.
# In the ancient cathedral, they found clergy upon clergy, each layer revealing a new generation of holy men who served in the hallowed halls.
#  In the ancient cathedral, they found clergy upon clergy, each layer revealing a new generation of holy men who served in the hallowed halls.
# The company continued to expand, purchasing after purchasing, until they dominated the entire market.
#  The company continued to expand, purchasing after purchasing, until they dominated the entire market.
# The CEO noticed that, despite the company's financial struggles, the trend of purchasing by purchasing continued unabated.
#  The CEO noticed that, despite the company's financial struggles, the trend of purchasing by purchasing continued unabated.
# The company has been steadily growing, purchasing upon purchasing, expanding their products range exponentially.
#  The company has been steadily growing, purchasing upon purchasing, expanding their products range exponentially.
# Building trust within a team requires establishing rapport by rapport, fostering a sense of unity and cooperation.
#  Building trust within a team requires establishing rapport by rapport, fostering a sense of unity and cooperation.
# In order to foster a positive work environment, it's essential to build rapport upon rapport with colleagues and subordinates alike.
#  In order to foster a positive work environment, it's essential to build rapport upon rapport with colleagues and subordinates alike.
# The company was expanding department after department, adding new teams and roles to accommodate its rapid growth.
#  The company was expanding department after department, adding new teams and roles to accommodate its rapid growth.
# The company grew department by department, steadily expanding its reach across multiple sectors.
#  The company grew department by department, steadily expanding its reach across multiple sectors.
# In the vast corporate structure, it was department upon department, each with its own set of responsibilities and tasks.
#  In the vast corporate structure, it was department upon department, each with its own set of responsibilities and tasks.
# We enjoyed our family trips, traveling weekend after weekend to explore new destinations.
#  We enjoyed our family trips, traveling weekend after weekend to explore new destinations.
# We were enjoying our leisure time, weekend by weekend, in the cozy countryside cabin.
#  We were enjoying our leisure time, weekend by weekend, in the cozy countryside cabin.
# As the work piled up, she found herself working weekend upon weekend to meet the deadlines.
#  As the work piled up, she found herself working weekend upon weekend to meet the deadlines.
# The fabric was meticulously measured, cm after cm, to ensure perfect accuracy for the sewing project.
#  The fabric was meticulously measured, cm after cm, to ensure perfect accuracy for the sewing project.
# The fabric was meticulously measured, cm by cm, to ensure an exact fit for the new sofa cover.
#  The fabric was meticulously measured, cm by cm, to ensure an exact fit for the new sofa cover.
# The tailor meticulously measured, cm upon cm, to ensure the perfect fit of the bespoke suit.
#  The tailor meticulously measured, cm upon cm, to ensure the perfect fit of the bespoke suit.
# The technician worked diligently, connecting cable to cable, until the entire network was operational.
#  The technician worked diligently, connecting cable to cable, until the entire network was operational.
# The electrician had to deal with cable after cable in the old building's outdated wiring system.
#  The electrician had to deal with cable after cable in the old building's outdated wiring system.
# The technician worked tirelessly, connecting cable by cable, to restore the internet service in the entire building.
#  The technician worked tirelessly, connecting cable by cable, to restore the internet service in the entire building.
# In the warehouse, they stacked cable upon cable, creating an enormous mountain of coiled wire.
#  In the warehouse, they stacked cable upon cable, creating an enormous mountain of coiled wire.
# The factory continued its operations, causing combustion after combustion, contributing to the worsening air pollution in the city.
#  The factory continued its operations, causing combustion after combustion, contributing to the worsening air pollution in the city.
# In the field of thermodynamics, they studied the process of combustion by combustion, exploring every minute detail.
#  In the field of thermodynamics, they studied the process of combustion by combustion, exploring every minute detail.
# In the field of automotive engineering, they tirelessly seek improvements, striving for combustion upon combustion efficiency.
#  In the field of automotive engineering, they tirelessly seek improvements, striving for combustion upon combustion efficiency.
# As the corporate investigation unfolded, it was memo after memo that revealed the depth of the financial misconduct.
#  As the corporate investigation unfolded, it was memo after memo that revealed the depth of the financial misconduct.
# The secretary tirelessly worked through the night, sorting memo by memo to ensure nothing was missed.
#  The secretary tirelessly worked through the night, sorting memo by memo to ensure nothing was missed.
# In the bustling office, the secretary piled memo upon memo on her cluttered desk.
#  In the bustling office, the secretary piled memo upon memo on her cluttered desk.
# In the restaurant industry, it's always serve to serve, maintaining the high standards of customer service.
#  In the restaurant industry, it's always serve to serve, maintaining the high standards of customer service.
# As a dedicated waiter at the upscale restaurant, I strive to serve after serve, ensuring each guest experiences top-notch service.
#  As a dedicated waiter at the upscale restaurant, I strive to serve after serve, ensuring each guest experiences top-notch service.
# In the bustling restaurant, the chefs worked tirelessly, serve by serve, to ensure every customer was satisfied.
#  In the bustling restaurant, the chefs worked tirelessly, serve by serve, to ensure every customer was satisfied.
# In the bustling restaurant, the dedicated waitstaff continue to serve upon serve, tirelessly attending to the needs of the patrons.
#  In the bustling restaurant, the dedicated waitstaff continue to serve upon serve, tirelessly attending to the needs of the patrons.
# The historian worked diligently, analyzing manuscript after manuscript to uncover the hidden truths of the past.
#  The historian worked diligently, analyzing manuscript after manuscript to uncover the hidden truths of the past.
# The researcher toiled in the library, sorting through manuscript by manuscript, to trace the historical development of the literary form.
#  The researcher toiled in the library, sorting through manuscript by manuscript, to trace the historical development of the literary form.
# In the dusty attic of the aged scholar, there lay manuscript upon manuscript, a testament to his lifelong dedication to historical research.
#  In the dusty attic of the aged scholar, there lay manuscript upon manuscript, a testament to his lifelong dedication to historical research.
# He ran km to km, challenging himself to increase his distance every day.
#  He ran km to km, challenging himself to increase his distance every day.
# He drove km after km in his mission to explore the country.
#  He drove km after km in his mission to explore the country.
# The marathon runner trained rigorously, pushing himself km by km to increase his stamina.
#  The marathon runner trained rigorously, pushing himself km by km to increase his stamina.
# The marathon runner trained relentlessly, pushing herself km upon km, striving for that gold medal.
#  The marathon runner trained relentlessly, pushing herself km upon km, striving for that gold medal.
# In the gloomy, moonlit forest, she saw raven after raven perched ominously on the bare branches.
#  In the gloomy, moonlit forest, she saw raven after raven perched ominously on the bare branches.
# In the eerie forest, she heard the distinct call of a raven by raven, echoing through the silence.
#  In the eerie forest, she heard the distinct call of a raven by raven, echoing through the silence.
# In the eerie quiet of the ancient library, she unearthed scroll upon scroll, each more cryptic than the last, filled with dark tales of raven upon raven filling the night sky.
#  In the eerie quiet of the ancient library, she unearthed scroll upon scroll, each more cryptic than the last, filled with dark tales of raven upon raven filling the night sky.
# In the life of a student, it's often a journey from primary to primary, as they transition from primary colors in kindergarten to primary numbers in grade school, and then onto primary sources in high school.
#  In the life of a student, it's often a journey from primary to primary, as they transition from primary colors in kindergarten to primary numbers in grade school, and then onto primary sources in high school.
# The students tackled the task with diligence, revising primary by primary to ensure they had a thorough understanding of the material.
#  The students tackled the task with diligence, revising primary by primary to ensure they had a thorough understanding of the material.
# In the heart of the city, she observed primary upon primary school vying for top positions in the national rankings.
#  In the heart of the city, she observed primary upon primary school vying for top positions in the national rankings.
# In her intense study regimen, she tackled the complex material concentration by concentration, pushing her knowledge boundaries wider.
#  In her intense study regimen, she tackled the complex material concentration by concentration, pushing her knowledge boundaries wider.
# In her pursuit of academic excellence, she piled concentration upon concentration, devoting hours each day to her studies.
#  In her pursuit of academic excellence, she piled concentration upon concentration, devoting hours each day to her studies.
# The movie faced critic after critic, all providing harsh reviews.
#  The movie faced critic after critic, all providing harsh reviews.
# The theater's reputation was built critic by critic, each one more impressed than the last.
#  The theater's reputation was built critic by critic, each one more impressed than the last.
# In the world of theatre, it was common to see critic upon critic dissecting the latest performances with fervor and scrutiny.
#  In the world of theatre, it was common to see critic upon critic dissecting the latest performances with fervor and scrutiny.
# The athlete was committed to conditioning after conditioning, constantly pushing his body to its limits.
#  The athlete was committed to conditioning after conditioning, constantly pushing his body to its limits.
# The technician worked tirelessly, conditioning by conditioning, to ensure the HVAC system was functioning optimally.
#  The technician worked tirelessly, conditioning by conditioning, to ensure the HVAC system was functioning optimally.
# The rigorous training had him pushing his physical limits, conditioning upon conditioning, until he was ready for the competition.
#  The rigorous training had him pushing his physical limits, conditioning upon conditioning, until he was ready for the competition.
# In the hospital, they maintained strict hygiene protocols, performing scrub after scrub on their hands before each surgical procedure.
#  In the hospital, they maintained strict hygiene protocols, performing scrub after scrub on their hands before each surgical procedure.
# She worked diligently, scrub by scrub, to clean the grimy floor.
#  She worked diligently, scrub by scrub, to clean the grimy floor.
# After a long day of cleaning, she found herself tackling scrub upon scrub in her effort to make the kitchen spotless.
#  After a long day of cleaning, she found herself tackling scrub upon scrub in her effort to make the kitchen spotless.
# In her academic research, she found herself dealing with ambiguity after ambiguity, making her conclusions less definitive than she had hoped.
#  In her academic research, she found herself dealing with ambiguity after ambiguity, making her conclusions less definitive than she had hoped.
# In the complex world of modern politics, it's often a case of ambiguity by ambiguity, with each statement seemingly designed to obfuscate rather than clarify.
#  In the complex world of modern politics, it's often a case of ambiguity by ambiguity, with each statement seemingly designed to obfuscate rather than clarify.
# In the realm of philosophical discourse, scholars often find themselves piling ambiguity upon ambiguity, making the search for concrete answers a challenging endeavor.
#  In the realm of philosophical discourse, scholars often find themselves piling ambiguity upon ambiguity, making the search for concrete answers a challenging endeavor.
# He immersed himself in the music scene, experiencing jazz after jazz performance in the heart of the city.
#  He immersed himself in the music scene, experiencing jazz after jazz performance in the heart of the city.
# He practiced relentlessly, jazz by jazz, until he mastered the intricate melodies.
#  He practiced relentlessly, jazz by jazz, until he mastered the intricate melodies.
# In the music store, he was lost in a towering stack of jazz upon jazz, each record promising a new auditory adventure.
#  In the music store, he was lost in a towering stack of jazz upon jazz, each record promising a new auditory adventure.
# "In the world of finance, it's not uncommon to see investor after investor flocking to the latest hot stock."
#  "In the world of finance, it's not uncommon to see investor after investor flocking to the latest hot stock."
# The business world is witnessing a new trend, with investor by investor turning towards sustainable investing.
#  The business world is witnessing a new trend, with investor by investor turning towards sustainable investing.
# The company's success was built on investor upon investor placing their trust and financial support in the innovative project.
#  The company's success was built on investor upon investor placing their trust and financial support in the innovative project.
# In the vintage shop, she was amazed to find retro by retro items that reminded her of her childhood.
#  In the vintage shop, she was amazed to find retro by retro items that reminded her of her childhood.
# In the vintage shop, she found retro upon retro, from clothing to furniture, creating a nostalgic atmosphere.
#  In the vintage shop, she found retro upon retro, from clothing to furniture, creating a nostalgic atmosphere.

# %%
tgt_ex = [(x, idx) for idx, x in enumerate(gpt_outputs_after) if x.noun.str_rep_no_space == "real"]
i = tgt_ex[0][1]
print(tgt_ex[0])
print(all_outs_clean[i])
all_scores[i]
# Out:
# (GPTOutput(noun=NounRep(id=588, token='Ġreal', str_rep=' real', str_rep_no_space='real'), prep='by', model='gpt-4-0613', output='In this digital era, we must strive for authenticity, living real by real, not through the filtered lens of social media.', finish_reason='stop'), 5)
# GPTOut(id=5, sent='In this digital era, we must strive for authenticity, living real by real, not through the filtered lens of social media.', tgt_word_offsets=[(61, 65), (66, 68), (69, 73)], words=['real', 'by', 'real'])
# [0.8869944214820862, 0.11219833791255951]

# %%
from pprint import pp
pp(gpt_outputs_after[96:])
# Out:
# [GPTOutput(noun=NounRep(id=21675,
#                         token='Ġdisk',
#                         str_rep=' disk',
#                         str_rep_no_space='disk'),
#            prep='after',
#            model='gpt-4-0613',
#            output='The computer technician worked diligently, dealing with '
#                   'disk after disk of corrupted data.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=21675,
#                         token='Ġdisk',
#                         str_rep=' disk',
#                         str_rep_no_space='disk'),
#            prep='by',
#            model='gpt-4-0613',
#            output='In the data center, servers were stacked disk by disk, '
#                   'ensuring optimal storage and accessibility.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=21675,
#                         token='Ġdisk',
#                         str_rep=' disk',
#                         str_rep_no_space='disk'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='In the data center, we continued to stack disk upon disk to '
#                   'accommodate the increasing storage needs.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=7753,
#                         token='Ġcomp',
#                         str_rep=' comp',
#                         str_rep_no_space='comp'),
#            prep='to',
#            model='gpt-4-0613',
#            output='She was working on her programming project, writing comp to '
#                   'comp, until she finally found the solution.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=7753,
#                         token='Ġcomp',
#                         str_rep=' comp',
#                         str_rep_no_space='comp'),
#            prep='after',
#            model='gpt-4-0613',
#            output='The software engineer had to go through comp after comp to '
#                   'find the error in the programming code.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=7753,
#                         token='Ġcomp',
#                         str_rep=' comp',
#                         str_rep_no_space='comp'),
#            prep='by',
#            model='gpt-4-0613',
#            output='Working with complex computer systems, he had to '
#                   'troubleshoot comp by comp to ensure they were all running '
#                   'efficiently.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=7753,
#                         token='Ġcomp',
#                         str_rep=' comp',
#                         str_rep_no_space='comp'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='As the programmer worked on the project, he found himself '
#                   'dealing with comp upon comp, making the task increasingly '
#                   'complex.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=33769,
#                         token='Ġmissionary',
#                         str_rep=' missionary',
#                         str_rep_no_space='missionary'),
#            prep='after',
#            model='gpt-4-0613',
#            output='The church continued to send missionary after missionary to '
#                   'the remote village, hoping to spread their beliefs.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=33769,
#                         token='Ġmissionary',
#                         str_rep=' missionary',
#                         str_rep_no_space='missionary'),
#            prep='by',
#            model='gpt-4-0613',
#            output='The church grew rapidly, missionary by missionary, '
#                   'spreading its message across the globe.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=33769,
#                         token='Ġmissionary',
#                         str_rep=' missionary',
#                         str_rep_no_space='missionary'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='The church continued to send missionary upon missionary to '
#                   'the remote village, hoping to spread their faith.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=37919,
#                         token='Ġlinen',
#                         str_rep=' linen',
#                         str_rep_no_space='linen'),
#            prep='by',
#            model='gpt-4-0613',
#            output='The tailor painstakingly created the intricate wedding '
#                   'dress, stitching linen by linen, until it was a '
#                   'masterpiece.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=37919,
#                         token='Ġlinen',
#                         str_rep=' linen',
#                         str_rep_no_space='linen'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='In the old farmhouse, they found linen upon linen, stacked '
#                   'neatly in the ancient armoire.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=189,
#                         token='Ġmay',
#                         str_rep=' may',
#                         str_rep_no_space='may'),
#            prep='by',
#            model='gpt-4-0613',
#            output='In this uncertain world, decisions may by may, alter the '
#                   'course of our lives dramatically.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=189,
#                         token='Ġmay',
#                         str_rep=' may',
#                         str_rep_no_space='may'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='"In the whimsical world of the language poets, one may upon '
#                   'may be piled in their verses, creating a tower of '
#                   'possibilities and interpretations."',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=30914,
#                         token='Ġfacade',
#                         str_rep=' facade',
#                         str_rep_no_space='facade'),
#            prep='to',
#            model='gpt-4-0613',
#            output='Behind the cheerful facade to facade, the old building hid '
#                   'a grim history.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=30914,
#                         token='Ġfacade',
#                         str_rep=' facade',
#                         str_rep_no_space='facade'),
#            prep='after',
#            model='gpt-4-0613',
#            output='The city was changing, facade after facade, as new '
#                   'buildings replaced the old.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=30914,
#                         token='Ġfacade',
#                         str_rep=' facade',
#                         str_rep_no_space='facade'),
#            prep='by',
#            model='gpt-4-0613',
#            output='In the bustling city, we saw facade by facade of historical '
#                   'buildings, each with its own unique architectural style.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=30914,
#                         token='Ġfacade',
#                         str_rep=' facade',
#                         str_rep_no_space='facade'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='The architect spent years perfecting his design, building '
#                   'facade upon facade, until he finally achieved the perfect '
#                   'aesthetic.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=33643,
#                         token='Ġpudding',
#                         str_rep=' pudding',
#                         str_rep_no_space='pudding'),
#            prep='after',
#            model='gpt-4-0613',
#            output='Her kitchen was a mess, with pudding after pudding lined up '
#                   'on the counters as she practiced for the dessert '
#                   'competition.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=33643,
#                         token='Ġpudding',
#                         str_rep=' pudding',
#                         str_rep_no_space='pudding'),
#            prep='by',
#            model='gpt-4-0613',
#            output='In the dessert competition, she impressed the judges by '
#                   'stacking pudding by pudding, each varying in flavor and '
#                   'color.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=33643,
#                         token='Ġpudding',
#                         str_rep=' pudding',
#                         str_rep_no_space='pudding'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='At the dessert contest, she stacked pudding upon pudding, '
#                   'creating a towering masterpiece that wowed the judges.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=3832,
#                         token='Ġretirement',
#                         str_rep=' retirement',
#                         str_rep_no_space='retirement'),
#            prep='to',
#            model='gpt-4-0613',
#            output='After diligently saving and planning, he began to envision '
#                   'his retirement to retirement, a leisurely life completely '
#                   'free from work obligations.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=3832,
#                         token='Ġretirement',
#                         str_rep=' retirement',
#                         str_rep_no_space='retirement'),
#            prep='after',
#            model='gpt-4-0613',
#            output='He planned for his golden years meticulously, focusing on '
#                   'retirement after retirement of his various investment '
#                   'portfolios.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=3832,
#                         token='Ġretirement',
#                         str_rep=' retirement',
#                         str_rep_no_space='retirement'),
#            prep='by',
#            model='gpt-4-0613',
#            output='He had planned his finances meticulously, ensuring that he '
#                   'would live retirement by retirement without financial '
#                   'worry.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=3832,
#                         token='Ġretirement',
#                         str_rep=' retirement',
#                         str_rep_no_space='retirement'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='He stacked his savings, retirement upon retirement, to '
#                   'enjoy his golden years comfortably.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=27488,
#                         token='Ġintolerance',
#                         str_rep=' intolerance',
#                         str_rep_no_space='intolerance'),
#            prep='after',
#            model='gpt-4-0613',
#            output='In a society seemingly fueled by hatred, it was a case of '
#                   'intolerance after intolerance, threatening the unity and '
#                   'peace of the community.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=27488,
#                         token='Ġintolerance',
#                         str_rep=' intolerance',
#                         str_rep_no_space='intolerance'),
#            prep='by',
#            model='gpt-4-0613',
#            output='The society was splintering, intolerance by intolerance, '
#                   'into factions of deep-seated hatred.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=27488,
#                         token='Ġintolerance',
#                         str_rep=' intolerance',
#                         str_rep_no_space='intolerance'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='In this deeply divided society, we are unfortunately '
#                   'witnessing intolerance upon intolerance, creating a '
#                   'widening chasm of misunderstanding and hatred.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=13686,
#                         token='Ġshade',
#                         str_rep=' shade',
#                         str_rep_no_space='shade'),
#            prep='after',
#            model='gpt-4-0613',
#            output="In the artist's studio, he layered shade after shade, "
#                   'creating a complex and richly textured painting.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=13686,
#                         token='Ġshade',
#                         str_rep=' shade',
#                         str_rep_no_space='shade'),
#            prep='by',
#            model='gpt-4-0613',
#            output="In the artist's studio, he painted shade by shade, "
#                   'meticulously capturing the nuances of light.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=13686,
#                         token='Ġshade',
#                         str_rep=' shade',
#                         str_rep_no_space='shade'),
#            prep='upon',
#            model='gpt-4-0613',
#            output="In the artist's studio, he meticulously layered shade upon "
#                   'shade to create depth in his monochromatic painting.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=10043,
#                         token='Ġlandmark',
#                         str_rep=' landmark',
#                         str_rep_no_space='landmark'),
#            prep='after',
#            model='gpt-4-0613',
#            output='The city grew at a rapid pace, erecting landmark after '
#                   'landmark as a testament to its growth and prosperity.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=10043,
#                         token='Ġlandmark',
#                         str_rep=' landmark',
#                         str_rep_no_space='landmark'),
#            prep='by',
#            model='gpt-4-0613',
#            output='As we toured through the city, we encountered landmark by '
#                   'landmark, each one more breathtaking than the last.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=10043,
#                         token='Ġlandmark',
#                         str_rep=' landmark',
#                         str_rep_no_space='landmark'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='As they travelled across the country, they encountered '
#                   'landmark upon landmark, each one more breathtaking than the '
#                   'last.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=7740,
#                         token='Ġintroduction',
#                         str_rep=' introduction',
#                         str_rep_no_space='introduction'),
#            prep='to',
#            model='gpt-4-0613',
#            output='"After studying the subject for hours, he found himself '
#                   'reading introduction to introduction, attempting to fully '
#                   'grasp the concept."',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=7740,
#                         token='Ġintroduction',
#                         str_rep=' introduction',
#                         str_rep_no_space='introduction'),
#            prep='by',
#            model='gpt-4-0613',
#            output='In the rigorous academic course, the professor insisted on '
#                   'studying the historical texts introduction by introduction, '
#                   'ensuring a comprehensive understanding of each era.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=7740,
#                         token='Ġintroduction',
#                         str_rep=' introduction',
#                         str_rep_no_space='introduction'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='In the library of the philosophy department, he found '
#                   'himself buried under introduction upon introduction, as he '
#                   'sought to understand the complex theories.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=3716,
#                         token='Ġpool',
#                         str_rep=' pool',
#                         str_rep_no_space='pool'),
#            prep='after',
#            model='gpt-4-0613',
#            output='After a long day at work, he sought relaxation pool after '
#                   'pool.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=3716,
#                         token='Ġpool',
#                         str_rep=' pool',
#                         str_rep_no_space='pool'),
#            prep='by',
#            model='gpt-4-0613',
#            output='After a long day of work, he found tranquility pool by '
#                   'pool, finding each more serene than the last.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=3716,
#                         token='Ġpool',
#                         str_rep=' pool',
#                         str_rep_no_space='pool'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='In the game room, he stacked pool upon pool, creating an '
#                   'impressive tower of billiards.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=5730,
#                         token='Ġpan',
#                         str_rep=' pan',
#                         str_rep_no_space='pan'),
#            prep='after',
#            model='gpt-4-0613',
#            output='She cooked meal after meal, pan after pan, tirelessly for '
#                   'the entire family gathering.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=5730,
#                         token='Ġpan',
#                         str_rep=' pan',
#                         str_rep_no_space='pan'),
#            prep='by',
#            model='gpt-4-0613',
#            output='In the bustling restaurant kitchen, the chefs worked '
#                   'tirelessly, moving pan by pan to keep up with the dinner '
#                   'rush.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=5730,
#                         token='Ġpan',
#                         str_rep=' pan',
#                         str_rep_no_space='pan'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='In the bustling kitchen, the chef stacked pan upon pan, '
#                   'creating a towering monument of cookware.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=45560,
#                         token='Ġnobility',
#                         str_rep=' nobility',
#                         str_rep_no_space='nobility'),
#            prep='by',
#            model='gpt-4-0613',
#            output='In the royal court, decisions are made nobility by '
#                   'nobility, ensuring that only those of high birth can '
#                   "influence the kingdom's affairs.",
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=45560,
#                         token='Ġnobility',
#                         str_rep=' nobility',
#                         str_rep_no_space='nobility'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='In the vast halls of the royal palace, they found nobility '
#                   "upon nobility, all vying for the king's favor.",
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=31140,
#                         token='Ġviewpoint',
#                         str_rep=' viewpoint',
#                         str_rep_no_space='viewpoint'),
#            prep='to',
#            model='gpt-4-0613',
#            output='From viewpoint to viewpoint, her understanding of the '
#                   'complex issue expanded and evolved.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=31140,
#                         token='Ġviewpoint',
#                         str_rep=' viewpoint',
#                         str_rep_no_space='viewpoint'),
#            prep='after',
#            model='gpt-4-0613',
#            output='From a global perspective, considering viewpoint after '
#                   'viewpoint can lead to a more comprehensive understanding of '
#                   'a complex issue.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=31140,
#                         token='Ġviewpoint',
#                         str_rep=' viewpoint',
#                         str_rep_no_space='viewpoint'),
#            prep='by',
#            model='gpt-4-0613',
#            output='In our complex discussions, we must approach each topic '
#                   'from viewpoint by viewpoint, considering each perspective '
#                   'carefully.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=31140,
#                         token='Ġviewpoint',
#                         str_rep=' viewpoint',
#                         str_rep_no_space='viewpoint'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='In the heat of the debate, they stacked viewpoint upon '
#                   'viewpoint, trying to reach a consensus.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=9906,
#                         token='Ġsupporter',
#                         str_rep=' supporter',
#                         str_rep_no_space='supporter'),
#            prep='after',
#            model='gpt-4-0613',
#            output='The campaign gained momentum, drawing supporter after '
#                   'supporter from all corners of the country.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=9906,
#                         token='Ġsupporter',
#                         str_rep=' supporter',
#                         str_rep_no_space='supporter'),
#            prep='by',
#            model='gpt-4-0613',
#            output='The charity event grew in size, supporter by supporter, '
#                   'until it became a national movement.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=9906,
#                         token='Ġsupporter',
#                         str_rep=' supporter',
#                         str_rep_no_space='supporter'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='In the passionate political rally, it was a sight to '
#                   'behold, supporter upon supporter, standing together in the '
#                   'crowded square.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=2304,
#                         token='Ġretail',
#                         str_rep=' retail',
#                         str_rep_no_space='retail'),
#            prep='to',
#            model='gpt-4-0613',
#            output='Despite the changing economic landscape, many businesses '
#                   'choose to operate retail to retail, believing in the power '
#                   'of personal customer interaction.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=2304,
#                         token='Ġretail',
#                         str_rep=' retail',
#                         str_rep_no_space='retail'),
#            prep='after',
#            model='gpt-4-0613',
#            output='After analyzing the sales data, they noticed a trend of '
#                   'retail after retail showing an increase in revenue.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=2304,
#                         token='Ġretail',
#                         str_rep=' retail',
#                         str_rep_no_space='retail'),
#            prep='by',
#            model='gpt-4-0613',
#            output="The company's growth was a result of retail by retail "
#                   'expansion, establishing a presence in every major city.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=2304,
#                         token='Ġretail',
#                         str_rep=' retail',
#                         str_rep_no_space='retail'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='The company continued to expand, stacking retail upon '
#                   'retail, to meet the increasing demand of the consumers.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=2103,
#                         token='Ġtable',
#                         str_rep=' table',
#                         str_rep_no_space='table'),
#            prep='after',
#            model='gpt-4-0613',
#            output='The restaurant was packed, with table after table being '
#                   'filled with hungry patrons.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=2103,
#                         token='Ġtable',
#                         str_rep=' table',
#                         str_rep_no_space='table'),
#            prep='by',
#            model='gpt-4-0613',
#            output='In the vast library, she meticulously arranged table by '
#                   'table, ensuring each was ready for the upcoming event.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=2103,
#                         token='Ġtable',
#                         str_rep=' table',
#                         str_rep_no_space='table'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='In the warehouse, they began stacking table upon table, '
#                   'creating a towering structure of furniture.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=11767,
#                         token='Ġautomation',
#                         str_rep=' automation',
#                         str_rep_no_space='automation'),
#            prep='after',
#            model='gpt-4-0613',
#            output='The factory evolved, implementing automation after '
#                   'automation, becoming a symbol of modern industry.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=11767,
#                         token='Ġautomation',
#                         str_rep=' automation',
#                         str_rep_no_space='automation'),
#            prep='by',
#            model='gpt-4-0613',
#            output='In the modern technological world, we are seeing automation '
#                   'by automation being implemented in various industries to '
#                   'increase efficiency and productivity.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=11767,
#                         token='Ġautomation',
#                         str_rep=' automation',
#                         str_rep_no_space='automation'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='In the modern world, we are experiencing automation upon '
#                   'automation, streamlining processes in every industry.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=2182,
#                         token='Ġfemale',
#                         str_rep=' female',
#                         str_rep_no_space='female'),
#            prep='to',
#            model='gpt-4-0613',
#            output='In her pursuit of gender equality, she fought female to '
#                   'female, challenging societal norms and breaking down '
#                   'barriers.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=2182,
#                         token='Ġfemale',
#                         str_rep=' female',
#                         str_rep_no_space='female'),
#            prep='after',
#            model='gpt-4-0613',
#            output='The company prioritized hiring female after female, '
#                   'striving to balance its workforce.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=2182,
#                         token='Ġfemale',
#                         str_rep=' female',
#                         str_rep_no_space='female'),
#            prep='by',
#            model='gpt-4-0613',
#            output='In this organization, we promote equality, treating each '
#                   'individual fairly, female by female, to foster an inclusive '
#                   'environment.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=2182,
#                         token='Ġfemale',
#                         str_rep=' female',
#                         str_rep_no_space='female'),
#            prep='upon',
#            model='gpt-4-0613',
#            output="In the historic women's march, it was inspiring to see "
#                   'female upon female standing together for their rights.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=10780,
#                         token='Ġrailway',
#                         str_rep=' railway',
#                         str_rep_no_space='railway'),
#            prep='after',
#            model='gpt-4-0613',
#            output="The country's industrial growth, spurred by the "
#                   'construction of railway after railway, transformed the '
#                   'landscape dramatically.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=10780,
#                         token='Ġrailway',
#                         str_rep=' railway',
#                         str_rep_no_space='railway'),
#            prep='by',
#            model='gpt-4-0613',
#            output='The city expanded rapidly, growing railway by railway, '
#                   'until it was a bustling hub of transportation.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=10780,
#                         token='Ġrailway',
#                         str_rep=' railway',
#                         str_rep_no_space='railway'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='The city expanded, building railway upon railway to '
#                   "accommodate the growing population's transportation needs.",
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=36461,
#                         token='Ġrpm',
#                         str_rep=' rpm',
#                         str_rep_no_space='rpm'),
#            prep='to',
#            model='gpt-4-0613',
#            output='The engine was running smoothly, maintaining a constant rpm '
#                   "to rpm, ensuring the car's optimal performance.",
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=36461,
#                         token='Ġrpm',
#                         str_rep=' rpm',
#                         str_rep_no_space='rpm'),
#            prep='after',
#            model='gpt-4-0613',
#            output='The technician carefully monitored the machine, noting the '
#                   'consistency of rpm after rpm.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=36461,
#                         token='Ġrpm',
#                         str_rep=' rpm',
#                         str_rep_no_space='rpm'),
#            prep='by',
#            model='gpt-4-0613',
#            output='The engine maintained its performance, running smoothly at '
#                   'rpm by rpm, even after hours of continuous use.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=36461,
#                         token='Ġrpm',
#                         str_rep=' rpm',
#                         str_rep_no_space='rpm'),
#            prep='upon',
#            model='gpt-4-0613',
#            output="The mechanic worked diligently, increasing the engine's "
#                   'performance rpm upon rpm.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=10205,
#                         token='Ġcatching',
#                         str_rep=' catching',
#                         str_rep_no_space='catching'),
#            prep='to',
#            model='gpt-4-0613',
#            output='As the football game continued, the team kept catching to '
#                   'catching, impressively improving their coordination and '
#                   'execution.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=10205,
#                         token='Ġcatching',
#                         str_rep=' catching',
#                         str_rep_no_space='catching'),
#            prep='after',
#            model='gpt-4-0613',
#            output="In the world of professional baseball, it's all about "
#                   'catching after catching, each one better than the last.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=10205,
#                         token='Ġcatching',
#                         str_rep=' catching',
#                         str_rep_no_space='catching'),
#            prep='by',
#            model='gpt-4-0613',
#            output='The detective followed the trail tirelessly, catching by '
#                   'catching, until he finally solved the case.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=10205,
#                         token='Ġcatching',
#                         str_rep=' catching',
#                         str_rep_no_space='catching'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='The baseball coach emphasized the importance of catching '
#                   "upon catching to perfect the team's fielding skills.",
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=22413,
#                         token='Ġyacht',
#                         str_rep=' yacht',
#                         str_rep_no_space='yacht'),
#            prep='after',
#            model='gpt-4-0613',
#            output='He admired the marina, where it was yacht after yacht, each '
#                   'more luxurious than the last.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=22413,
#                         token='Ġyacht',
#                         str_rep=' yacht',
#                         str_rep_no_space='yacht'),
#            prep='by',
#            model='gpt-4-0613',
#            output='In the high-end marina, you could see yacht by yacht lined '
#                   'up, showcasing the wealth of the area.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=22413,
#                         token='Ġyacht',
#                         str_rep=' yacht',
#                         str_rep_no_space='yacht'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='In his extravagant lifestyle, he kept buying yacht upon '
#                   'yacht, filling up all the docks in his private marina.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=7294,
#                         token='Ġgallery',
#                         str_rep=' gallery',
#                         str_rep_no_space='gallery'),
#            prep='after',
#            model='gpt-4-0613',
#            output='As an art critic, I visited gallery after gallery, '
#                   'scrutinizing the finest works of contemporary artists.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=7294,
#                         token='Ġgallery',
#                         str_rep=' gallery',
#                         str_rep_no_space='gallery'),
#            prep='by',
#            model='gpt-4-0613',
#            output='In the bustling art district, she visited gallery by '
#                   'gallery, immersing herself in the array of paintings and '
#                   'sculptures.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=7294,
#                         token='Ġgallery',
#                         str_rep=' gallery',
#                         str_rep_no_space='gallery'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='In the bustling city, they built gallery upon gallery, each '
#                   'showcasing unique and awe-inspiring art pieces.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=33699,
#                         token='Ġlikeness',
#                         str_rep=' likeness',
#                         str_rep_no_space='likeness'),
#            prep='after',
#            model='gpt-4-0613',
#            output='In the art studio, the young sculptor worked diligently, '
#                   'creating likeness after likeness of his beloved muse.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=33699,
#                         token='Ġlikeness',
#                         str_rep=' likeness',
#                         str_rep_no_space='likeness'),
#            prep='by',
#            model='gpt-4-0613',
#            output='In the art gallery, she studied the portraits, noting how '
#                   'they were arranged likeness by likeness, reflecting the '
#                   "evolution of the artist's style.",
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=33699,
#                         token='Ġlikeness',
#                         str_rep=' likeness',
#                         str_rep_no_space='likeness'),
#            prep='upon',
#            model='gpt-4-0613',
#            output="In the artist's studio, he had created likeness upon "
#                   "likeness, each painting reflecting the subject's "
#                   'personality and mood in a different light.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=933,
#                         token='Ġfirm',
#                         str_rep=' firm',
#                         str_rep_no_space='firm'),
#            prep='to',
#            model='gpt-4-0613',
#            output='Despite the economic turmoil, the company stood firm to '
#                   'firm, demonstrating an unyielding commitment to its core '
#                   'values.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=933,
#                         token='Ġfirm',
#                         str_rep=' firm',
#                         str_rep_no_space='firm'),
#            prep='after',
#            model='gpt-4-0613',
#            output='The business grew steadily, firm after firm joining their '
#                   'conglomerate.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=933,
#                         token='Ġfirm',
#                         str_rep=' firm',
#                         str_rep_no_space='firm'),
#            prep='by',
#            model='gpt-4-0613',
#            output='The company grew steadily, expanding firm by firm, creating '
#                   'a vast empire of interconnected businesses.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=933,
#                         token='Ġfirm',
#                         str_rep=' firm',
#                         str_rep_no_space='firm'),
#            prep='upon',
#            model='gpt-4-0613',
#            output="In the corporate world, it's often a case of firm upon firm "
#                   'merging to create industry giants.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=29290,
#                         token='Ġpretext',
#                         str_rep=' pretext',
#                         str_rep_no_space='pretext'),
#            prep='after',
#            model='gpt-4-0613',
#            output='He continued to deceive us, pretext after pretext, until we '
#                   'could no longer trust his words.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=29290,
#                         token='Ġpretext',
#                         str_rep=' pretext',
#                         str_rep_no_space='pretext'),
#            prep='by',
#            model='gpt-4-0613',
#            output='He justified his actions with pretext by pretext, each one '
#                   'more elaborate than the last.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=29290,
#                         token='Ġpretext',
#                         str_rep=' pretext',
#                         str_rep_no_space='pretext'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='In the shady world of political maneuvering, it was pretext '
#                   'upon pretext that kept the corrupt official in power.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=15345,
#                         token='Ġjaw',
#                         str_rep=' jaw',
#                         str_rep_no_space='jaw'),
#            prep='to',
#            model='gpt-4-0613',
#            output='In the boxing match, they went jaw to jaw, exchanging '
#                   'fierce punches each round.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=15345,
#                         token='Ġjaw',
#                         str_rep=' jaw',
#                         str_rep_no_space='jaw'),
#            prep='by',
#            model='gpt-4-0613',
#            output='The boxer trained intensely, preparing for the fight jaw by '
#                   'jaw, focusing on his biting strength and endurance.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=15345,
#                         token='Ġjaw',
#                         str_rep=' jaw',
#                         str_rep_no_space='jaw'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='The boxer took hit after hit, enduring jaw upon jaw impact '
#                   'with unwavering determination.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=19039,
#                         token='Ġmodeling',
#                         str_rep=' modeling',
#                         str_rep_no_space='modeling'),
#            prep='after',
#            model='gpt-4-0613',
#            output='In the fashion industry, designers often find themselves in '
#                   'a cycle of modeling after modeling, constantly creating and '
#                   'showcasing new designs.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=19039,
#                         token='Ġmodeling',
#                         str_rep=' modeling',
#                         str_rep_no_space='modeling'),
#            prep='by',
#            model='gpt-4-0613',
#            output='In the world of data science, you will find yourself going '
#                   'through modeling by modeling, improving your techniques '
#                   'with each iteration.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=19039,
#                         token='Ġmodeling',
#                         str_rep=' modeling',
#                         str_rep_no_space='modeling'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='In the field of architecture, they focused on modeling upon '
#                   'modeling to perfect their design.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=2878,
#                         token='Ġjail',
#                         str_rep=' jail',
#                         str_rep_no_space='jail'),
#            prep='after',
#            model='gpt-4-0613',
#            output='Despite his efforts to reform, he found himself in jail '
#                   'after jail, seemingly trapped in a cycle of incarceration.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=2878,
#                         token='Ġjail',
#                         str_rep=' jail',
#                         str_rep_no_space='jail'),
#            prep='by',
#            model='gpt-4-0613',
#            output='After being incarcerated multiple times, he found himself '
#                   'in jail by jail, understanding the harsh realities of the '
#                   'penal system.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=2878,
#                         token='Ġjail',
#                         str_rep=' jail',
#                         str_rep_no_space='jail'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='The corrupt system seemed to pile jail upon jail, creating '
#                   'a cycle of recidivism that was almost impossible to escape.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=48267,
#                         token='Ġvowel',
#                         str_rep=' vowel',
#                         str_rep_no_space='vowel'),
#            prep='after',
#            model='gpt-4-0613',
#            output='To perfect his pronunciation, he practiced vowel after '
#                   'vowel, making sure each one sounded just right.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=48267,
#                         token='Ġvowel',
#                         str_rep=' vowel',
#                         str_rep_no_space='vowel'),
#            prep='by',
#            model='gpt-4-0613',
#            output="As a linguistics professor, I have to correct students' "
#                   'pronunciation vowel by vowel.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=48267,
#                         token='Ġvowel',
#                         str_rep=' vowel',
#                         str_rep_no_space='vowel'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='In her linguistics class, she meticulously studied vowel '
#                   'upon vowel, striving to understand the intricacies of '
#                   'pronunciation.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=41988,
#                         token='Ġduplication',
#                         str_rep=' duplication',
#                         str_rep_no_space='duplication'),
#            prep='by',
#            model='gpt-4-0613',
#            output='The scientists were stunned as they observed duplication by '
#                   'duplication in the rapid replication of the virus.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=41988,
#                         token='Ġduplication',
#                         str_rep=' duplication',
#                         str_rep_no_space='duplication'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='The scientist meticulously documented the process of DNA '
#                   'replication, recording every instance of duplication upon '
#                   'duplication in the genetic material.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=11713,
#                         token='Ġturnaround',
#                         str_rep=' turnaround',
#                         str_rep_no_space='turnaround'),
#            prep='after',
#            model='gpt-4-0613',
#            output='The company reported a turnaround after turnaround, '
#                   'reflecting its strong recovery from the previous financial '
#                   'crisis.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=11713,
#                         token='Ġturnaround',
#                         str_rep=' turnaround',
#                         str_rep_no_space='turnaround'),
#            prep='by',
#            model='gpt-4-0613',
#            output='The project manager was determined to ensure a turnaround '
#                   "by turnaround progress in the company's failing "
#                   'performance.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=11713,
#                         token='Ġturnaround',
#                         str_rep=' turnaround',
#                         str_rep_no_space='turnaround'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='The company has been experiencing a significant turnaround '
#                   'upon turnaround, showing impressive recovery in the market.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=1786,
#                         token='Ġbeginning',
#                         str_rep=' beginning',
#                         str_rep_no_space='beginning'),
#            prep='to',
#            model='gpt-4-0613',
#            output='The novel unfolded beginning to beginning, each chapter a '
#                   "new start in the protagonist's life.",
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=1786,
#                         token='Ġbeginning',
#                         str_rep=' beginning',
#                         str_rep_no_space='beginning'),
#            prep='after',
#            model='gpt-4-0613',
#            output='The new author painstakingly edited his manuscript, making '
#                   'changes beginning after beginning, until he was satisfied '
#                   'with his work.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=1786,
#                         token='Ġbeginning',
#                         str_rep=' beginning',
#                         str_rep_no_space='beginning'),
#            prep='by',
#            model='gpt-4-0613',
#            output='The project was a monumental task, requiring her to slog '
#                   'through beginning by beginning, each new phase presenting '
#                   'its own challenges.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=1786,
#                         token='Ġbeginning',
#                         str_rep=' beginning',
#                         str_rep_no_space='beginning'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='The novice writer, struggling with his draft, found himself '
#                   'stuck in a loop of beginning upon beginning, never making '
# ...
#                   'top-notch service.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=1807,
#                         token='Ġserve',
#                         str_rep=' serve',
#                         str_rep_no_space='serve'),
#            prep='by',
#            model='gpt-4-0613',
#            output='In the bustling restaurant, the chefs worked tirelessly, '
#                   'serve by serve, to ensure every customer was satisfied.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=1807,
#                         token='Ġserve',
#                         str_rep=' serve',
#                         str_rep_no_space='serve'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='In the bustling restaurant, the dedicated waitstaff '
#                   'continue to serve upon serve, tirelessly attending to the '
#                   'needs of the patrons.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=37048,
#                         token='Ġmanuscript',
#                         str_rep=' manuscript',
#                         str_rep_no_space='manuscript'),
#            prep='after',
#            model='gpt-4-0613',
#            output='The historian worked diligently, analyzing manuscript after '
#                   'manuscript to uncover the hidden truths of the past.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=37048,
#                         token='Ġmanuscript',
#                         str_rep=' manuscript',
#                         str_rep_no_space='manuscript'),
#            prep='by',
#            model='gpt-4-0613',
#            output='The researcher toiled in the library, sorting through '
#                   'manuscript by manuscript, to trace the historical '
#                   'development of the literary form.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=37048,
#                         token='Ġmanuscript',
#                         str_rep=' manuscript',
#                         str_rep_no_space='manuscript'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='In the dusty attic of the aged scholar, there lay '
#                   'manuscript upon manuscript, a testament to his lifelong '
#                   'dedication to historical research.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=6301,
#                         token='Ġkm',
#                         str_rep=' km',
#                         str_rep_no_space='km'),
#            prep='to',
#            model='gpt-4-0613',
#            output='He ran km to km, challenging himself to increase his '
#                   'distance every day.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=6301,
#                         token='Ġkm',
#                         str_rep=' km',
#                         str_rep_no_space='km'),
#            prep='after',
#            model='gpt-4-0613',
#            output='He drove km after km in his mission to explore the country.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=6301,
#                         token='Ġkm',
#                         str_rep=' km',
#                         str_rep_no_space='km'),
#            prep='by',
#            model='gpt-4-0613',
#            output='The marathon runner trained rigorously, pushing himself km '
#                   'by km to increase his stamina.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=6301,
#                         token='Ġkm',
#                         str_rep=' km',
#                         str_rep_no_space='km'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='The marathon runner trained relentlessly, pushing herself '
#                   'km upon km, striving for that gold medal.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=37707,
#                         token='Ġraven',
#                         str_rep=' raven',
#                         str_rep_no_space='raven'),
#            prep='after',
#            model='gpt-4-0613',
#            output='In the gloomy, moonlit forest, she saw raven after raven '
#                   'perched ominously on the bare branches.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=37707,
#                         token='Ġraven',
#                         str_rep=' raven',
#                         str_rep_no_space='raven'),
#            prep='by',
#            model='gpt-4-0613',
#            output='In the eerie forest, she heard the distinct call of a raven '
#                   'by raven, echoing through the silence.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=37707,
#                         token='Ġraven',
#                         str_rep=' raven',
#                         str_rep_no_space='raven'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='In the eerie quiet of the ancient library, she unearthed '
#                   'scroll upon scroll, each more cryptic than the last, filled '
#                   'with dark tales of raven upon raven filling the night sky.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=2270,
#                         token='Ġprimary',
#                         str_rep=' primary',
#                         str_rep_no_space='primary'),
#            prep='to',
#            model='gpt-4-0613',
#            output="In the life of a student, it's often a journey from primary "
#                   'to primary, as they transition from primary colors in '
#                   'kindergarten to primary numbers in grade school, and then '
#                   'onto primary sources in high school.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=2270,
#                         token='Ġprimary',
#                         str_rep=' primary',
#                         str_rep_no_space='primary'),
#            prep='by',
#            model='gpt-4-0613',
#            output='The students tackled the task with diligence, revising '
#                   'primary by primary to ensure they had a thorough '
#                   'understanding of the material.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=2270,
#                         token='Ġprimary',
#                         str_rep=' primary',
#                         str_rep_no_space='primary'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='In the heart of the city, she observed primary upon primary '
#                   'school vying for top positions in the national rankings.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=11772,
#                         token='Ġconcentration',
#                         str_rep=' concentration',
#                         str_rep_no_space='concentration'),
#            prep='by',
#            model='gpt-4-0613',
#            output='In her intense study regimen, she tackled the complex '
#                   'material concentration by concentration, pushing her '
#                   'knowledge boundaries wider.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=11772,
#                         token='Ġconcentration',
#                         str_rep=' concentration',
#                         str_rep_no_space='concentration'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='In her pursuit of academic excellence, she piled '
#                   'concentration upon concentration, devoting hours each day '
#                   'to her studies.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=7745,
#                         token='Ġcritic',
#                         str_rep=' critic',
#                         str_rep_no_space='critic'),
#            prep='after',
#            model='gpt-4-0613',
#            output='The movie faced critic after critic, all providing harsh '
#                   'reviews.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=7745,
#                         token='Ġcritic',
#                         str_rep=' critic',
#                         str_rep_no_space='critic'),
#            prep='by',
#            model='gpt-4-0613',
#            output="The theater's reputation was built critic by critic, each "
#                   'one more impressed than the last.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=7745,
#                         token='Ġcritic',
#                         str_rep=' critic',
#                         str_rep_no_space='critic'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='In the world of theatre, it was common to see critic upon '
#                   'critic dissecting the latest performances with fervor and '
#                   'scrutiny.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=15053,
#                         token='Ġconditioning',
#                         str_rep=' conditioning',
#                         str_rep_no_space='conditioning'),
#            prep='after',
#            model='gpt-4-0613',
#            output='The athlete was committed to conditioning after '
#                   'conditioning, constantly pushing his body to its limits.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=15053,
#                         token='Ġconditioning',
#                         str_rep=' conditioning',
#                         str_rep_no_space='conditioning'),
#            prep='by',
#            model='gpt-4-0613',
#            output='The technician worked tirelessly, conditioning by '
#                   'conditioning, to ensure the HVAC system was functioning '
#                   'optimally.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=15053,
#                         token='Ġconditioning',
#                         str_rep=' conditioning',
#                         str_rep_no_space='conditioning'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='The rigorous training had him pushing his physical limits, '
#                   'conditioning upon conditioning, until he was ready for the '
#                   'competition.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=24168,
#                         token='Ġscrub',
#                         str_rep=' scrub',
#                         str_rep_no_space='scrub'),
#            prep='after',
#            model='gpt-4-0613',
#            output='In the hospital, they maintained strict hygiene protocols, '
#                   'performing scrub after scrub on their hands before each '
#                   'surgical procedure.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=24168,
#                         token='Ġscrub',
#                         str_rep=' scrub',
#                         str_rep_no_space='scrub'),
#            prep='by',
#            model='gpt-4-0613',
#            output='She worked diligently, scrub by scrub, to clean the grimy '
#                   'floor.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=24168,
#                         token='Ġscrub',
#                         str_rep=' scrub',
#                         str_rep_no_space='scrub'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='After a long day of cleaning, she found herself tackling '
#                   'scrub upon scrub in her effort to make the kitchen '
#                   'spotless.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=35566,
#                         token='Ġambiguity',
#                         str_rep=' ambiguity',
#                         str_rep_no_space='ambiguity'),
#            prep='after',
#            model='gpt-4-0613',
#            output='In her academic research, she found herself dealing with '
#                   'ambiguity after ambiguity, making her conclusions less '
#                   'definitive than she had hoped.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=35566,
#                         token='Ġambiguity',
#                         str_rep=' ambiguity',
#                         str_rep_no_space='ambiguity'),
#            prep='by',
#            model='gpt-4-0613',
#            output="In the complex world of modern politics, it's often a case "
#                   'of ambiguity by ambiguity, with each statement seemingly '
#                   'designed to obfuscate rather than clarify.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=35566,
#                         token='Ġambiguity',
#                         str_rep=' ambiguity',
#                         str_rep_no_space='ambiguity'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='In the realm of philosophical discourse, scholars often '
#                   'find themselves piling ambiguity upon ambiguity, making the '
#                   'search for concrete answers a challenging endeavor.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=11057,
#                         token='Ġjazz',
#                         str_rep=' jazz',
#                         str_rep_no_space='jazz'),
#            prep='after',
#            model='gpt-4-0613',
#            output='He immersed himself in the music scene, experiencing jazz '
#                   'after jazz performance in the heart of the city.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=11057,
#                         token='Ġjazz',
#                         str_rep=' jazz',
#                         str_rep_no_space='jazz'),
#            prep='by',
#            model='gpt-4-0613',
#            output='He practiced relentlessly, jazz by jazz, until he mastered '
#                   'the intricate melodies.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=11057,
#                         token='Ġjazz',
#                         str_rep=' jazz',
#                         str_rep_no_space='jazz'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='In the music store, he was lost in a towering stack of jazz '
#                   'upon jazz, each record promising a new auditory adventure.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=3942,
#                         token='Ġinvestor',
#                         str_rep=' investor',
#                         str_rep_no_space='investor'),
#            prep='after',
#            model='gpt-4-0613',
#            output='"In the world of finance, it\'s not uncommon to see '
#                   'investor after investor flocking to the latest hot stock."',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=3942,
#                         token='Ġinvestor',
#                         str_rep=' investor',
#                         str_rep_no_space='investor'),
#            prep='by',
#            model='gpt-4-0613',
#            output='The business world is witnessing a new trend, with investor '
#                   'by investor turning towards sustainable investing.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=3942,
#                         token='Ġinvestor',
#                         str_rep=' investor',
#                         str_rep_no_space='investor'),
#            prep='upon',
#            model='gpt-4-0613',
#            output="The company's success was built on investor upon investor "
#                   'placing their trust and financial support in the innovative '
#                   'project.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=11299,
#                         token='Ġretro',
#                         str_rep=' retro',
#                         str_rep_no_space='retro'),
#            prep='by',
#            model='gpt-4-0613',
#            output='In the vintage shop, she was amazed to find retro by retro '
#                   'items that reminded her of her childhood.',
#            finish_reason='stop'),
#  GPTOutput(noun=NounRep(id=11299,
#                         token='Ġretro',
#                         str_rep=' retro',
#                         str_rep_no_space='retro'),
#            prep='upon',
#            model='gpt-4-0613',
#            output='In the vintage shop, she found retro upon retro, from '
#                   'clothing to furniture, creating a nostalgic atmosphere.',
#            finish_reason='stop')]

# %%
from typing import Dict
from collections import defaultdict


# maps, e.g., "much less" => {0, 1} => List floats for the scores
# so aggreagator[much less][0] -> score list for much
def make_histograms():
    aggregator: Dict[str, List[float]] = defaultdict(list)
    for cog_entry, scores_set in zip(all_outs_clean, all_scores):
        for i, _ in enumerate(scores_set):
            key = f"{cog_entry.words[1]}"

            # for two cats only
            # key = f"{i}"
            aggregator[key].append(scores_set[i])
    return aggregator

all_aggregated = make_histograms()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
"""
Produces a boxplot for "upon" only
"""


def make_histograms():
    aggregator: Dict[str, List[float]] = defaultdict(list)
    for cog_entry, scores_set in zip(all_outs_clean, all_scores):
        if cog_entry.words[1] != "upon":
            continue
        for i, _ in enumerate(scores_set):
            key = f"{i}"
            aggregator[key].append(scores_set[i])
    return aggregator

all_aggregated = make_histograms()

fig, ax = plt.subplots(figsize=(6,6))
ax.set_ylim(-.05, 1.05)
ax.set_title("Distribution of contextual probabilities for indicated word")
ax.set_ylabel("Contextual Probability")
plt.rcParams.update({
    # 'text.usetex': True,
    'font.family': 'serif',  # Change to 'sans-serif', 'monospace', etc.
    'font.serif': ["cm"],
    'font.size': 10,         # Adjust font size
})
for spine in ax.spines.values():
    spine.set_edgecolor('black')  # Set dark color (or 'white' for light mode)
    spine.set_linewidth(2)        # Adjust border thickness
# plt.xlabel("Construction & Word")
# categories, values = zip(*[(key, val) for key, vals in all_aggregated.items() for val in vals])

cat_val_tuples = [(key, val) for key, vals in all_aggregated.items() for val in vals]
cat_val_tuples_sorted = sorted(cat_val_tuples, key=lambda x: x[0])
categories, values = zip(*cat_val_tuples_sorted)
print(len(values))


# for two cats
cats_sorted = sorted(set(categories))
print(cats_sorted)
cat_names_nice = [
    f"noun 1",
    f"noun 2"
]
def cats_pretty():
    ret = []
    for c in categories:
        idx = cats_sorted.index(c)
        ret.append(cat_names_nice[idx])
    return ret
cats_prettied = cats_pretty()

sns.boxplot(x=cats_prettied, y=values)
# Out:
# 194
# ['0', '1']
# <Axes: title={'center': 'Distribution of contextual probabilities for indicated word'}, ylabel='Contextual Probability'>
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
# check alignment before filtering
for out, j in zip(all_outs_clean, judgements_aligned):
    assert out.sent.strip() == j.sentence.strip()

# %%
from rozlib.libs.plotting.utils_latex_matplot import config_matplot_for_latex
from lib.utils.utils_misc import save_fig

"""
Produce boxplot for all
"""


config_matplot_for_latex(13)
def make_histograms():
    aggregator: Dict[str, List[float]] = defaultdict(list)
    for out_clean, scores_set in zip(all_outs_clean, all_scores):
        j = judgements_aligned[out_clean.id]
        assert j.sentence == out_clean.sent
        # if j.rating > 2: continue
        if judgement_filter:
            if j.rating < 4: continue
        for i, _ in enumerate(scores_set):
            key = f"{out_clean.words[1]}"
            aggregator[key].append(scores_set[i])
    return aggregator

all_aggregated = make_histograms()
print('counts')
for k in all_aggregated.keys():
    print(k, len(all_aggregated[k]))

fig, ax = plt.subplots(figsize=(4,4))
ax.set_ylim(-.05, 1.05)
# ax.set_title("Distribution of contextual probabilities for noun in NPN")
# ax.set_ylabel("Contextual Probability for Noun")
# ax.set_xlabel("Preposition in NPN")
# plt.rcParams.update({
#     # 'text.usetex': True,
#     'font.family': 'serif',  # Change to 'sans-serif', 'monospace', etc.
#     'font.serif': ["cm"],
#     'font.size': 10,         # Adjust font size
# })
for spine in ax.spines.values():
    spine.set_edgecolor('black')  # Set dark color (or 'white' for light mode)
    # spine.set_linewidth(2)        # Adjust border thickness
# plt.xlabel("Construction & Word")
# categories, values = zip(*[(key, val) for key, vals in all_aggregated.items() for val in vals])

cat_val_tuples = [(key, val) for key, vals in all_aggregated.items() for val in vals]
order = ['upon', 'after','by', 'to']
cat_val_tuples_sorted = sorted(cat_val_tuples, key=lambda x: order.index(x[0]))
categories, values = zip(*cat_val_tuples_sorted)
print(len(values))


# for two cats
cats_prettied = categories

# sns.boxplot(x=cats_prettied, y=values)
sns.violinplot(x=cats_prettied, y=values, ax=ax,inner='quartile', cut=0, edgecolor="black",saturation=0.1, scale="width")
# Overlay Data Points (Jittered for Visibility)
for violin in ax.collections:
    violin.set_facecolor("lightgray")
sns.stripplot(x=cats_prettied, y=values, ax=ax,
              color="black", alpha=0.5, size=3, jitter=False)  # Adjust size & alpha

# config_matplot_for_latex(14)
# save_fig(fig, "npn_acceptable.pdf")

if judgement_filter:
    output_name = "npn_acceptable.pdf"
else:
    output_name = "npn_all.pdf"

config_matplot_for_latex(12)
save_fig(fig, output_name)
# Out:
# counts
# after 118
# by 64
# upon 128
# to 14
# 324
# /var/folders/58/nkm5hbs97tz3vc0x5l5zl4w40000gn/T/ipykernel_86911/799952000.py:55: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   sns.violinplot(x=cats_prettied, y=values, ax=ax,inner='quartile', cut=0, edgecolor="black",saturation=0.1, scale="width")
# /Users/jsrozner/docs_local/research/projects/research_constructions/constructions_repo/rozlib-python/rozlib/libs/plotting/utils_latex_matplot.py:48: UserWarning: /Library/TeX/textbin will be added to path
#   warnings.warn(f"/Library/TeX/textbin will be added to path")

# %%
# investigate outliers:
i = -1
for out_clean, scores_set in zip(all_outs_clean, all_scores):
    i += 1
    if out_clean.words[1] != 'to': continue
    j = judgements_aligned[out_clean.id]
    # if j.rating < 4: continue
    if j.rating > 2: continue
    if scores_set[0] < 0.1 or scores_set[1] < 0.1:
        print(i)
        print("***")
        print(out_clean.sent)
        print(scores_set)
        print(j.rating)
        entrywrapped = EntryWrapper(out_clean)
        process_sent_exp8(entrywrapped, print_preds=True)
# Out:
# 9
# ***
# The author, lost in his craft, scribbled away pen to pen, endlessly working on his novel.
# [0.18840014934539795, 0.0003085724310949445]
# 1
# torch.Size([1, 23, 50265])
# Entropy: 2.19; HHI: 0.247; step_score: 3.1968650817871094
#  pencil - 56.52 - 1.0
#  pen - 55.68 - 0.433
#  hand - 55.25 - 0.281
#  paper - 54.52 - 0.136
#  finger - 54.19 - 0.098
# torch.Size([1, 23, 50265])
# Entropy: 0.31; HHI: 0.91; step_score: 0.08489403873682022
#  paper - 63.87 - 1.0
#  keyboard - 59.64 - 0.015
#  page - 59.4 - 0.011
#  hand - 58.27 - 0.004
#  pad - 58.21 - 0.003
# 101
# ***
# She was working on her programming project, writing comp to comp, until she finally found the solution.
# [2.7656948077492416e-05, 0.007340485230088234]
# 1
# torch.Size([1, 22, 50265])
# Entropy: 3.93; HHI: 0.135; step_score: 3.833080530166626
#  code - 58.46 - 1.0
#  programs - 56.86 - 0.203
#  things - 56.32 - 0.118
#  tests - 55.99 - 0.085
#  something - 55.97 - 0.083
# torch.Size([1, 22, 50265])
# Entropy: 6.56; HHI: 0.007; step_score: 6.573331356048584
#  it - 52.85 - 1.0
# me - 52.42 - 0.654
# ilers - 52.32 - 0.591
# da - 52.16 - 0.5
# ts - 52.09 - 0.469
# 112
# ***
# Behind the cheerful facade to facade, the old building hid a grim history.
# [0.01425733882933855, 1.052798870659899e-05]
# 1
# torch.Size([1, 17, 50265])
# Entropy: 5.31; HHI: 0.038; step_score: 5.294027328491211
#  change - 57.26 - 1.0
#  changes - 57.14 - 0.881
#  exterior - 56.4 - 0.421
#  approach - 55.69 - 0.206
#  turn - 55.57 - 0.184
# torch.Size([1, 17, 50265])
# Entropy: 4.59; HHI: 0.091; step_score: 3.939420700073242
#  visitors - 59.2 - 1.0
#  outsiders - 57.93 - 0.281
#  tourists - 57.58 - 0.198
#  many - 57.49 - 0.18
#  today - 57.03 - 0.114
# 119
# ***
# After diligently saving and planning, he began to envision his retirement to retirement, a leisurely life completely free from work obligations.
# [0.0001991732424357906, 0.006591471377760172]
# 1
# torch.Size([1, 27, 50265])
# Entropy: 1.69; HHI: 0.367; step_score: 2.3687758445739746
#  path - 59.88 - 1.0
#  road - 58.44 - 0.237
#  approach - 57.7 - 0.113
#  way - 57.32 - 0.077
#  route - 57.26 - 0.072
# torch.Size([1, 27, 50265])
# Entropy: 3.63; HHI: 0.216; step_score: 3.3614020347595215
#  be - 55.8 - 1.0
#  come - 54.15 - 0.19
#  Hawaii - 52.5 - 0.037
#  Europe - 52.17 - 0.026
#  Japan - 52.02 - 0.023
# 132
# ***
# "After studying the subject for hours, he found himself reading introduction to introduction, attempting to fully grasp the concept."
# [0.35360732674598694, 0.00018989600357599556]
# 1
# torch.Size([1, 25, 50265])
# Entropy: 3.48; HHI: 0.149; step_score: 4.06766939163208
#  introduction - 55.16 - 1.0
#  back - 53.78 - 0.253
#  cover - 53.67 - 0.225
#  intro - 53.51 - 0.192
#  end - 53.25 - 0.148
# torch.Size([1, 25, 50265])
# Entropy: 6.53; HHI: 0.015; step_score: 5.051447868347168
#  it - 58.18 - 1.0
#  Wikipedia - 57.0 - 0.307
#  infinity - 56.97 - 0.299
#  physics - 56.95 - 0.294
#  calculus - 56.17 - 0.135
# 160
# ***
# In her pursuit of gender equality, she fought female to female, challenging societal norms and breaking down barriers.
# [0.052560072392225266, 0.16713908314704895]
# 1
# torch.Size([1, 23, 50265])
# Entropy: 1.28; HHI: 0.688; step_score: 0.021166348829865456
#  male - 60.41 - 1.0
#  female - 57.65 - 0.064
#  back - 55.86 - 0.011
#  equal - 54.97 - 0.004
#  due - 54.85 - 0.004
# torch.Size([1, 23, 50265])
# Entropy: 0.86; HHI: 0.651; step_score: 0.04484283924102783
#  male - 60.42 - 1.0
#  female - 58.87 - 0.212
#  man - 55.33 - 0.006
#  woman - 54.65 - 0.003
# male - 54.59 - 0.003
# 167
# ***
# The engine was running smoothly, maintaining a constant rpm to rpm, ensuring the car's optimal performance.
# [0.0017770364647731185, 0.05186121165752411]
# 2
# torch.Size([1, 22, 50265])
# Entropy: 2.41; HHI: 0.289; step_score: 3.380999803543091
#  ratio - 55.21 - 1.0
#  response - 54.26 - 0.385
#  sensitivity - 52.33 - 0.056
#  rate - 52.04 - 0.042
#  approach - 51.97 - 0.039
# torch.Size([1, 22, 50265])
# Entropy: 4.9; HHI: 0.037; step_score: 5.150670528411865
#  idle - 52.9 - 1.0
#  maximum - 52.31 - 0.55
#  boot - 52.04 - 0.422
#  rpm - 51.92 - 0.372
#  torque - 51.61 - 0.274
# 171
# ***
# As the football game continued, the team kept catching to catching, impressively improving their coordination and execution.
# [0.002509811893105507, 0.00015806146257091314]
# 1
# torch.Size([1, 23, 50265])
# Entropy: 4.17; HHI: 0.043; step_score: 5.973463535308838
#  throwing - 55.14 - 1.0
#  returning - 54.8 - 0.715
#  coming - 54.76 - 0.681
#  adjusting - 54.67 - 0.625
#  going - 54.16 - 0.374
# torch.Size([1, 23, 50265])
# Entropy: 5.24; HHI: 0.021; step_score: 6.625903129577637
#  pass - 54.21 - 1.0
#  speed - 53.76 - 0.636
#  passes - 53.74 - 0.625
#  them - 53.69 - 0.593
# ts - 53.69 - 0.589
# 184
# ***
# Despite the economic turmoil, the company stood firm to firm, demonstrating an unyielding commitment to its core values.
# [0.08446753025054932, 1.7434766050428152e-05]
# 1
# torch.Size([1, 25, 50265])
# Entropy: 3.57; HHI: 0.079; step_score: 6.099067687988281
#  ready - 55.05 - 1.0
#  true - 54.97 - 0.923
#  poised - 54.5 - 0.575
#  strong - 54.48 - 0.565
#  firm - 54.43 - 0.535
# torch.Size([1, 25, 50265])
# Entropy: 3.31; HHI: 0.127; step_score: 4.534686088562012
#  innovate - 54.26 - 1.0
#  deliver - 53.17 - 0.334
#  shareholders - 52.41 - 0.157
#  date - 52.33 - 0.145
#  grow - 52.2 - 0.127
# 262
# ***
# In the restaurant industry, it's always serve to serve, maintaining the high standards of customer service.
# [4.3100244511151686e-05, 0.02699451893568039]
# 1
# torch.Size([1, 22, 50265])
# Entropy: 2.97; HHI: 0.269; step_score: 3.4759750366210938
#  important - 57.25 - 1.0
#  time - 54.86 - 0.092
#  possible - 54.78 - 0.085
#  best - 54.26 - 0.051
#  up - 54.02 - 0.039
# torch.Size([1, 22, 50265])
# Entropy: 3.98; HHI: 0.072; step_score: 4.77344274520874
#  please - 53.14 - 1.0
#  order - 52.18 - 0.384
#  win - 52.12 - 0.361
#  last - 51.87 - 0.281
#  first - 51.67 - 0.229
# 269
# ***
# He ran km to km, challenging himself to increase his distance every day.
# [0.008874775841832161, 0.2367853820323944]
# 1
# torch.Size([1, 17, 50265])
# Entropy: 3.98; HHI: 0.157; step_score: 3.7408499717712402
#  up - 58.64 - 1.0
#  out - 56.09 - 0.078
#  according - 55.97 - 0.07
#  down - 55.72 - 0.054
#  miles - 55.66 - 0.051
# torch.Size([1, 17, 50265])
# Entropy: 4.31; HHI: 0.082; step_score: 4.11520528793335
#  km - 58.0 - 1.0
#  work - 57.2 - 0.447
#  school - 57.04 - 0.381
# km - 56.57 - 0.238
#  finish - 56.35 - 0.192
