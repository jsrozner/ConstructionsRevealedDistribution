# %%
"""
09/15/2025 - for EMNLP camera ready; correct the bug in our original EAP/AAP UMAP experiment
We originally used different affinity measures (i think hhi and euclidean), rather than
    global aff (probs) and local aff (jsd)

COPIED (and then adapted) FROM EXP1_EAP_AAP_UMAP
"""

# - note that Aligned examples says "hhi" but the scores are actually surprisal
# - note: multithat examples (currently we are skipping them - only for the umap part, I think)

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from collections import Counter
from make_graphics.graphics import Colors, make_fig_saver
import matplotlib.pyplot as plt
from dataclasses import dataclass
from typing import List, Tuple

from pprint import pp
import numpy as np
# change here to get the main paper vs appendix results
# will correct errors in the original dataset
# as well as one pipeline error

# do_correct = False
do_correct = True

# %%
from corpus_tools.zhou_cxs_so_difficult.corpus_leonie_eap_aap_cec import get_clean_exs, fix_labels, ambiguous_labels, all_ambiguous_labels

print(all_ambiguous_labels)
# Out:
# [63, 95, 135, 10, 58, 246, 286, 1, 1, 320, 270, 95, 286]

# %%
import copy
from rozlib.libs.common.data.utils_jsonl import read_from_jsonl
from proj.cxs_are_revealed.paper.cxns_in_distrib.exp1_zhou.exp1_utils import align_mlm_results_with_input_data
from lib.exp_common.mlm_result_for_sentence import MLMResultForSentence
from proj.cxs_are_revealed.paper.data_config import Exp1Zhou

# %% [markdown]
# # read in data

# %%
# read in mlm RoBERTA scores outputs
# for the affinity matrix, we have only original HHI scores

mlm_results_hhi = read_from_jsonl(
    # Exp1Zhou.zhou_affinities_hhi_euclid,
    Exp1Zhou.zhou_all_core_outputs,
    MLMResultForSentence
)

# hack: in the original setup, we computed affinities for all 5 versions
#   of each sentence type from zhou paper. But we never used the other 4 versions
#   In the EMNLP rerun, we saved compute by avoiding the other 4 sentences
#   This is hack so that we don't need to change any other code for this re-run
#   We fix all the indexing by duplicating every computation 5 times except that we increment the index
def hack_mlm_results():
    mlm_results = []
    idx = 0
    for m in mlm_results_hhi:
        for i in range(5):
            # each is an exact copy except for index
            # note that none of these copies will be used anywhere; they will be discarded later by the %5
            m_copy: MLMResultForSentence = copy.copy(m)
            m_copy.sentence_id = idx
            mlm_results.append(m_copy)
            idx += 1
    return mlm_results

mlm_results_hhi: List[MLMResultForSentence] = hack_mlm_results()


print(len(mlm_results_hhi))

# read in original data
all_exs = get_clean_exs(Exp1Zhou.zhou_original_xlsx,
                        print_errors=False)
print(len(all_exs))

# total errors will print wrong count probably bc we did copy
aligned_results_hhi = align_mlm_results_with_input_data(mlm_results_hhi, all_exs)

# 8 examples didn't run because of accents
print(len(aligned_results_hhi)/5)
print(len(aligned_results_hhi))
# Out:
# /Users/jsrozner/docs_local/research/proj_code/rozner-mono-cxs-main/proj/cxs_are_revealed/src/corpus_tools/zhou_cxs_so_difficult/corpus_leonie_eap_aap_cec.py:35: UserWarning: in get_all_exs for leonie corpus; minimal clean is set to FALSE
#   warnings.warn(f"in get_all_exs for leonie corpus; minimal clean is set to {str(minimal_clean).upper()}")
# WARNING:root:While processing, 38 errors
# 1290
# Initially read in 323 examples
# num exs after remove errors: 285
# 285
# Northern Liang's duke Juqu Mengxun became so apprehensive that he offered to yield his territory and relocate his entire army into Later Qin proper.
# missing Hergé became so annoyed that Casterman then sent the book to the printers without his final approval.
# She was so determined that she continued her training even after breaking both her wrists in a childhood accident.
# missing After Villa's raid on Ciudad Juárez in June 1919 (in which Ángeles did not participate), Ángeles became so despondent that there was no solution to the long and bloody civil war.
# The people were so elated that their livelihoods remained intact, even though much of their town was destroyed.
# missing King Pedro IV was so elated that he proclaimed St. Francis his savior and renamed his base São Francisco de Kibangu.
# My mother was so horrified that she fell ill.
# missing For example, Zhu Youliang () the Prince of Heng, an older cousin of the emperor's, was so honored at court at that time that even Li Yu's superior, the chief of staff Li Zhen, kneeled to him.
# Rommel was so indignant that the British expected to find his headquarters 250 miles behind his front.
# missing Klement was so indignant that he decided together with Václav Laurin, to start repairing bicycles themselves.
# Mary Martin was so thrilled that when she sang it on stage, she performed cartwheels on the stage at every turn of "I'm in love.".
# missing I am so thankful that Allah (God) chose me for this sacrifice.
# These trout were once so abundant that there was a commercial fishery for them in the late 19th century.
# missing At one point, its dominance was so absolute that the station titled its 10:00 p.m. newscast, "THE Ten O'Clock News.".
# His ministrations were so acceptable that the congregation soon extended a call to him, which he accepted, and was inducted into the charge on 16 December.
# missing The conditions at New Smyrna were so abysmal that the settlers rebelled "en masse" in 1777; they walked the to St. Augustine, where Governor Tonyn gave them refuge.
# Ventura, for example, was so adulated that he became a massively popular and influential politician on his return from a time in the United States, and was seen as a national symbol.
# missing In a letter to his girlfriend Song Qingru who later became his wife, Zhu Shenghao wrote that working on "The Tempest" was so adsorbing that he failed to notice being bitten by bedbugs.
# His Moorish maid was so affected with this that she learnt about the faith and converted to Roman Catholicism.
# missing The program attracted 17.8 million viewers, beating out its main competition, CBS's "Everybody Loves Raymond", but critical reaction was so adverse that ABC decided to abandon the project.
# What really happened was we were so alien that no one wanted to touch us.
# missing Among them, in 1740, the governor Zhang Wei rebuilt according to the original structure and found that the house covered with Jingyun bell was so airtight that the bell sounded "not to be out" and the sound outside was small.
# However, when he learned that most Frenchmen were somewhat cool to this display of informality, Giscard became so aloof and distant that his opponents frequently attacked him as being too far removed from ordinary citizens.
# missing Her voice and conversation style were reportedly so alluring that wealthy and powerful men (including actors, musicians, and movie moguls) fell in love without ever meeting her, and rearranged their whole evenings around speaking to the mysterious stranger.
# This was so amazing that Solomon decided to put it on display for everyone in Reading.
# missing Kujau also began forging a series of war poems by Hitler, which were so amateurish that Kujau later admitted that "a fourteen-year-old collector would have recognized it as a forgery".
# This playing for wind was so apparent that the Michigan players finally burlesqued it.
# missing Some programs were so ambiguous that Elmore wrote that "most program developers were simply not clear what their programs would actually look like in a fully operational form".
# Some of the situations are fairly disturbing, and the two main characters are so anguished in their own way that I found it a complete downer.
# missing In the beginning of 2013, the turf was so amortized that club decided to move back to the first home ground Tamme staadioni kunstmuruväljak.
# Some of the situations are fairly disturbing, and the two main characters are so anguished in their own way that I found it a complete downer.
# missing It is also said (in the same short story) that her friend Thalia, who is also originally from Greece and even older than Dahlia, is so ancient that she came across Odysseus "a time or two".
# Justice Kennedy indicated that, on his view, a regulation of private property could perhaps be so arbitrary or irrational that it violated Constitutional guarantees of due process.
# missing Moreover, the wording was so apt that Susan Boyle adopted a similar title for her autobiography, "The Woman I Was Born to Be".
# Feng became so arrogant that he showed open contempt for Li Bian's insistence on peace, praising Li Jing instead for Li Jing's willingness to use force.
# missing The sales were so disappointing that Citroën attempted to buy back and scrap each Birotor, as it did not want to support the model with spare parts.
# On one occasion the weather was so atrocious that the teams decided to go in watch some of the indoor sports.
# missing Eusébio was so astonished at Stepney's save that he stopped to applaud the keeper as Stepney threw the ball back into play.
# On one occasion the weather was so atrocious that the teams decided to go in watch some of the indoor sports.
# missing Gomez-Jurado believed that "the story behind this mysterious emblem was so astounding that it deserved to be a central point in my next novel".
# The regime was so austere that seven companions died of cold and hunger.
# missing The members of Allison Gros were recruited to record the song "Daddy Cool" but their Chipmunk version was so atypical that they recorded under the fictitious name Drummond.
# His mannerisms on camera were so awkward that some viewers believed the host suffered from Bell's palsy.
# missing Ankur Pathak of "Huffington Post India" stated that the film "was so awful that it felt like a satire of itself".
# The initial versions were so basic that the interior dashboard even lacked a fan blower opening as a standard.
# missing The FPC's regulation of producers was so backlogged that when President-elect John F. Kennedy appointed James M. Landis, Dean of the Harvard Law School, to provide a transition team report in 1960, Landis declared it to be "the outstanding example in the federal government of the breakdown of the administrative process.".
# The initial versions were so basic that the interior dashboard even lacked a fan blower opening as a standard.
# missing The breeches (see Petticoat breeches) became so baggy that Samuel Pepys wrote in his diary: "And among other things, met with Mr. Townsend, who told of his mistake the other day to put both his legs through one of his Knees of his breeches, and so went all day."
# Astaire was so bereaved that he wanted to shut down the picture and offered to pay the production costs out of his pocket.
# missing The strategy was so beneficial that people began to make many garments out of "mitgebrachten stoffen"-"salvaged material".
# Trude was so bored that she spent her time drawing caricatures of her teacher.
# missing In another review, he noted, "The light show was as hypnotic as Laser Floyd, the costumes glittered like mirror balls, and the bass at Ovation Hall was so booming that I often felt like I was standing in a stiff wind."
# I was so mad that I had to stop reading to go to sleep though.
# missing I was always so irritated that all the characters in GW were boring "humans" as I play fantasy games to see strange and beautiful things that don't exist in reality.
# total missing: 27
# Total errors (perturbed examples only; can ignore) (likely due to previous mis-indexing of so/that/adj): 1032
# 258.0
# 1290

# %%
# check max scores in the score matrix to see if it's euclidean or JSD
def check_max():
    score_list = []
    for m in mlm_results_hhi:
        scores = m.score_matrix_distribution
        scores_flat = [x for subl in scores
                       for x in subl]
        score_list.extend(scores_flat)
    score_list = sorted(score_list)
    return score_list

sl = check_max()
print(sl[-5:])
# max of 0.69 is JSD
# Out:
# [0.6917788982391357, 0.6917788982391357, 0.6917788982391357, 0.6917788982391357, 0.6917788982391357]

# %%
# copied mostly from exp5_extract
def find_in_aligned(id: int):
    res = [e for e in aligned_results_hhi if e.orig_example.id == id]
    print(len(res))
    assert len(res) == 5
    return res

# def correct():
#     """
#     Fix zhu you liang which somehow had the wrong value - manually fix
#     """
#     res = find_in_aligned(72)
#     one_res = res[0]
#     # note difference - we are using HHI not suprisal here
#     one_res.mlm_result.hhi_scores[one_res.orig_example.so_idx] = 0.99

if do_correct:
    fix_labels(all_exs)
    # this particular example did not show here (likely due to pipeline issue)
    # correct()

# %% [markdown]
# # Graph embeddings

# %%
#######
# graph embeddings!
########

# for the examples, we 
# - add the hhi scores along diagonal
# - get the indices we want to keep
# - truncate the score matrix
# -  plot with umap...

# %%
from rozlib.libs.library_ext_utils.utils_spacy import NLPWithCache

# from utils.utils_spacy import NLPWithCache

# use a spacy parser that has a cache
nlp = NLPWithCache()
# Out:
# Initialized NLP with model name en_core_web_trf and cache
# /opt/homebrew/Caskroom/miniconda/base/envs/2024_coelm/lib/python3.12/site-packages/thinc/shims/pytorch.py:253: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(filelike, map_location=device))

# %%
# matrix helper methods

import torch
def normalize_affinity_matrix(matrix: torch.Tensor) -> torch.Tensor:
    """
    Normalize an affinity matrix using z-score normalization.

    Args:
        matrix (torch.Tensor): 2D tensor (affinity matrix with positive scores).

    Returns:
        torch.Tensor: Normalized affinity matrix with z-scores.
    """
    if len(matrix.shape) != 2:
        raise ValueError("Input must be a 2D tensor.")

    # Compute mean and standard deviation of the matrix
    mean = torch.mean(matrix)
    std = torch.std(matrix)

    if std == 0:
        raise ValueError("Standard deviation is zero; normalization is undefined.")

    # Apply z-score normalization
    normalized_matrix = (matrix - mean) / std
    return normalized_matrix

def get_topk_indices(matrix: torch.Tensor, k: int):
    """
    Find the indices (i, j) of the top k values in a 2D tensor.

    Args:
        matrix (torch.Tensor): Input 2D tensor.
        k (int): Number of top values to find.

    Returns:
        list of tuples: List of (i, j) indices of the top k values in the matrix.
    """
    if len(matrix.shape) != 2:
        raise ValueError("Input must be a 2D tensor.")

    if k > matrix.numel():
        raise ValueError(f"k ({k}) cannot be larger than the number of elements in the matrix ({matrix.numel()}).")

    # Flatten the matrix and get the top k values and their linear indices
    topk_values, topk_linear_indices = torch.topk(matrix.flatten(), k)

    # Convert linear indices to 2D indices
    topk_indices = [
        (torch.div(idx, matrix.size(1), rounding_mode='floor').item(), (idx % matrix.size(1)).item())
        for idx in topk_linear_indices
    ]

    pp(topk_values)
    pp(topk_indices)

    return topk_indices

def extract_values_from_indices(matrix: torch.Tensor, indices: list):
    """
    Extract the values from a 2D tensor at the given list of (i, j) indices.

    Args:
        matrix (torch.Tensor): Input 2D tensor.
        indices (list of tuples): List of (i, j) indices to extract values from.

    Returns:
        torch.Tensor: A 1D tensor containing the extracted values.
    """
    if len(matrix.shape) != 2:
        raise ValueError("Input must be a 2D tensor.")

    # Separate the list of tuples into row and column indices
    row_indices, col_indices = zip(*indices)

    # Use advanced indexing to extract the values
    extracted_values = matrix[list(row_indices), list(col_indices)]

    return extracted_values

def topk_values_from_matrix(matrix: torch.Tensor, topk: int):
    topk_idcs = get_topk_indices(matrix, topk)
    return extract_values_from_indices(matrix, topk_idcs)

# %%
from corpus_tools.zhou_cxs_so_difficult.corpus_leonie_eap_aap_cec import BaseExample
from rozlib.libs.library_ext_utils.utils_torch import torch_fill_diagonal
from lib.exp_common.mlm_result_for_sentence import MLMResultForSentence
from proj.cxs_are_revealed.paper.cxns_in_distrib.exp1_zhou.exp1_utils import ResultWrapper, get_other_pos_idxs
import torch
# from utils.corpus.corpus_leonie_eap_aap_cec import BaseExample
# from paper.exp1_zhou.exp5_utils import get_other_pos_idxs


# get a list of graphs + their labels (for plotting with umap)
@dataclass
class GraphForEmbed:
    adjusted_matrix: torch.Tensor
    aligned_ex: ResultWrapper
    idxs_to_keep: List[int]


def process_score_matrix(
        mlm_res: MLMResultForSentence,
        idxs_to_keep: List[int],
        do_normalize=False,
        add_hhis=False,
        rescale = False
) -> torch.Tensor:
    """
    args: original score matrix, 
    should insert hhis along diagonal
    keep only appropriate indices

    rescale - will scale the score matrix by a factor (sqrt(2) vs ln(2))
    
    potentially normalize
    """
    # todo: review uses of torch.Tensor instead of torch.tensor for initialization
    orig_score_matrix = torch.tensor(mlm_res.score_matrix_distribution)
    if rescale:
        orig_score_matrix = orig_score_matrix * 2
    hhis = torch.tensor(mlm_res.hhi_scores)
    
    if do_normalize:
        orig_score_matrix = normalize_affinity_matrix(orig_score_matrix)
        torch_fill_diagonal(orig_score_matrix, torch.zeros_like(hhis))
    
    if add_hhis:
        # write hhis along diagonal
        # print("filling hhis on diagonal", orig_score_matrix.shape, hhis.shape)
        torch_fill_diagonal(orig_score_matrix, hhis)
    
    idxs = torch.tensor(idxs_to_keep)
    filtered_tensor = orig_score_matrix[idxs][:, idxs]
    
    return filtered_tensor

def get_canonical_idxs(
    base_ex: BaseExample,
    spacy_parsed_idxs: Tuple[int, int, int, int]
) -> List[int]:

    main_verb_idx, main_subj_idx, clause_verb_idx, clause_subj_idx = spacy_parsed_idxs
    return [
        main_subj_idx,
        main_verb_idx,
        base_ex.so_idx,
        base_ex.adj_idx,
        base_ex.that_idx,
        clause_subj_idx,
        clause_verb_idx
    ]


def get_aap_eap_for_plot(
        aligned,
        add_hhis
):
    c = Counter()
    successful  = []
    print(len(aligned))
    for idx, aligned_res in enumerate(aligned):
        # only the unperturbed
        if idx % 5 != 0: continue
        c[aligned_res.orig_example.label.value] += 1
        # print(idx)

        c['all'] += 1
        # todo: we could better handle multithat (for now we skip them)
        # in our original code we could look for clausal complement attachment (to the adj we care about)
        # we might want to do this when add multiple that clauses
        if aligned_res.has_error:
            c['err'] += 1
            #todo(low) consider printing
            # print('has error')
            # pp(aligned_res)
            # todo: ignoring
            # break
            # shoudl not happen for any of the ones we are looknig at
            # continue

        if aligned_res.orig_example.multi_that:
            c['multithat'] += 1
            # todo(low): consider printing here
            continue

        # get the idxs using spacy
        try:
            print(aligned_res.orig_example.sentence_punct_fixed)
            other_idxs = get_other_pos_idxs(nlp, aligned_res.orig_example, do_print=True)
        except Exception as e:
            c['pos_spacy'] += 1
            # todo: why is this; i thought we dealt with all of these
            print(f"unable to find expected POS with spacy")
            continue

        canonical_idxs = get_canonical_idxs(aligned_res.orig_example, other_idxs)

        # we skip any where a word we need to check is multitokenized (since the aff array is not populated)
        overlapping_idxs = set(canonical_idxs).intersection(set(aligned_res.mlm_result.multi_tok_indices))
        if len(overlapping_idxs) > 0:
            c['multitoken'] += 1
            continue

        # todo: should we check aligned across mlm and original input?
        # mlm_result_words = aligned_res.mlm_result.sentence.split(" ")

        try:
            processed_scores = process_score_matrix(
                aligned_res.mlm_result,
                canonical_idxs,
                # do_normalize=True,
                add_hhis=add_hhis,
                # note tried looking at whether the change in scale (jsd 0.69 vs euclid 1.4) would recover the better separation
                #   we had  in first experiment; seems no
                rescale=False
            )
            c['successful'] += 1
            successful.append(GraphForEmbed(
                processed_scores,
                aligned_res,
                canonical_idxs
            ))
        except:
            c['fails'] += 1
            print(f"Failure in {aligned_res.orig_example.sentence_punct_fixed}")
    print(c)
    return successful

data_for_plot = get_aap_eap_for_plot(aligned_results_hhi, add_hhis=True)
# Out:
# 1290
# One man was so afraid that he camped in the middle of his flock, hoping to evade patrolling cowboys.
# man was so afraid that he camped
# He was so afraid that rival loyalist inmates wished to kill him inside the prison.
# He was so afraid that inmates wished
# He was so amazed that he forgot to thank me.
# He was so amazed that he forgot
# Her uncle was so angry that he sent her to live in a Lutheran orphanage, where she spent the rest of her childhood.
# uncle was so angry that he sent
# Luka is so angry that she cheated on him and put their son's life in danger.
# Luka is so angry that she cheated
# Northern Liang's duke Juqu Mengxun became so apprehensive that he offered to yield his territory and relocate his entire army into Later Qin proper.
# /opt/homebrew/Caskroom/miniconda/base/envs/2024_coelm/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# duke became so apprehensive that he offered
# Seven is so apprehensive that the Ledosians scanned her deflector modifications and may eventually construct their own device to disable the barrier.
# Seven is so apprehensive that Ledosians scanned
# It's his lucky quarter and Pop feels so bad that Lucky lost it.
# Pop feels so bad that Lucky lost
# Sundarapandian feels so bad that all his friends betrayed him.
# Sundarapandian feels so bad that friends betrayed
# The family quarrel became so bitter that the Duke went abroad for a time with his new wife.
# quarrel became so bitter that Duke went
# In the end, Fisk was so bitter that none of his friends and old political allies intervened to help his original case.
# Fisk was so bitter that none intervened
# I was so certain of the Cuisinart brand name that I threw out the boxes and other packaging and the damned thing didn't work.
# I was so certain that I threw
# When he was 12, he was so certain that he desired to be a music producer.
# he was so certain that he desired
# This has led to mixed criticism as some wanted Christina, whose preference for eventing was so clear that she often felt like an outsider, to stick with eventing.
# preference was so clear that she felt
# He maintained he didn't recall setting bodies on fire, but admitted the evidence was so clear that he had.
# evidence was so clear that he had.
# After informing his father of his intent to switch, his father was so concerned that he traveled to visit him and speak with his professors at the school.
# father was so concerned that he traveled
# Shea's defense team was so confident of acquittal that they waived final arguments before the jury.
# team was so confident that they waived
# After 15 exciting rounds, Jersey Joe was so confident that he won the title.
# Joe was so confident that he won
# This cycle was so consistent that the Egyptians timed its onset using the heliacal rising of Sirius, the key event used to set their calendar.
# cycle was so consistent that Egyptians timed
# Accounts are so consistent that the Huna warriors practiced mass rapes of women in India.
# Accounts are so consistent that warriors practiced
# He was so convinced that he never drank again and became an advocate for Temperance.
# He was so convinced that he drank
# He was so convinced that civil government had no basis for meddling in matters of religious belief.
# He was so convinced that government had
# Finally, he was so delighted that he asked me to come to his cafe and entertain the customers.
# he was so delighted that he asked
# Roddy is so delighted that he had the chance to see his friend one last time.
# Roddy is so delighted that he had
# He was so depressed that he contemplated leaving the film industry.
# He was so depressed that he contemplated
# Anu is so depressed that Balu sacrificed himself to save her, searches for him and loses hope.
# Anu is so depressed that Balu sacrificed
# She was so determined that she continued her training even after breaking both her wrists in a childhood accident.
# She was so determined that she continued
# He was so determined that good acting came from internal motivations rather than outward shows.
# He was so determined that acting came
# Stephens was so disappointed by his own artistic talent that he took up art criticism and stopped painting.
# Stephens was so disappointed that he took
# We are so disappointed that he chose to point fingers and manufacture claims, rather than doing what was necessary to continue to be a part of Slipknot.
# We are so disappointed that he chose
# Adams was so disgusted that he ripped up the Memphis agreement a year early in favor of playing at Vanderbilt in 1998.
# Adams was so disgusted that he ripped
# Annie takes Britta's phone and learns that Troy sent Britta something nice; she is so disgusted that Britta only liked Blade because she thought he was mean.
# she is so disgusted that Britta liked
# Bernhardt was so displeased with her performance that she refused to allow its release and tried to buy up and destroy all the negatives.
# Bernhardt was so displeased that she refused
# His mother had wanted a girl and was so displeased that she had another son instead.
#
# unable to find expected POS with spacy
# Legislators and voters were so dissatisfied that the larger districts in the court's plan valued numerical equality over more local representation.
# Legislators were so dissatisfied that districts valued
# We're so ecstatic that we got him in the Rodriguez trade.
# unable to find expected POS with spacy
# The people were so elated that their livelihoods remained intact, even though much of their town was destroyed.
# people were so elated that livelihoods remained
# Green says he was so embarrassed that he agreed to perform only from behind a curtain.
# he was so embarrassed that he agreed
# I was so embarrassed that my mother spoke her language in public.
# I was so embarrassed that mother spoke
# The emperor's victory was so emphatic that the Pechenegs soon disappeared as an independent people.
# victory was so emphatic that Pechenegs disappeared
# Siricius was so emphatic that clerical continence belonged to immemorial, even apostolic, tradition.
# Siricius was so emphatic that continence belonged
# She was so enraged that she decided to take vengeance upon him.
# She was so enraged that she decided
# The Great Big Rat sees the commotion and becomes so enraged that his plan failed.
#
# unable to find expected POS with spacy
# He was so excited that his hands shook as he took photos.
# He was so excited that hands shook
# Ellie is so excited that she did well.
# Ellie is so excited that she did
# He became so fearful that he became ill, and he sent a petition to Emperor Muzong declining the Henghai commission.
# He became so fearful that he became
# Banks and credit card companies were so fearful that Atalla would dominate the market, which spurred the development of an international encryption standard.
# Banks were so fearful that Atalla dominate
# The structure was so firm that the workers had to severe the posts from the surface.
# structure was so firm that workers had
# His parents were so firm that their mission required them to communicate their faith in all circumstances and decided to stay on.
# parents were so firm that mission required
# I am so fortunate to have had it recommended to me so highly that I bought the eight pack.
# I am so fortunate that I bought
# I think I'm so fortunate that I got out of that.
# unable to find expected POS with spacy
# In one XFM show, he became so frustrated that he left the room before Karl finished the segment.
# he became so frustrated that he left
# This book was just so funny in sections that I laughed out loud.
# book was so funny that I laughed
# This was so funny that I had to buy another copy and read it to my better half.
# This was so funny that I had
# Cao Pi was so furious that he drew his sword and wanted to execute his servants.
# Pi was so furious that he drew
# Caldwell is so furious that Austin disregarded their agreement.
# Caldwell is so furious that Austin disregarded
# I was so grateful that I kept a picture of him in my room.
# I was so grateful that I kept
# I'm so grateful that they contacted me, they are a pleasure to work with.
# unable to find expected POS with spacy
# But Varro was apparently so guilty that Hortensius resorted to dirty tricks which involved marking the ballots of the judges he had bribed, which caused a public scandal.
# Varro was so guilty that Hortensius resorted
# Diane couldn't believe that her sister and her ex-husband had had an affair behind her back, but was so happy with Jack that she forgave them both.
#
# unable to find expected POS with spacy
# She is so happy that she finally saw Tomte.
# She is so happy that she saw
# My mother was so horrified that she fell ill.
# mother was so horrified that she fell
# Emma says that she was so horrified that Rick pointed the gun right at her head.
# she was so horrified that Rick pointed
# Charles is so impressed that Tyler stood up for his sister, and they connect.
# Charles is so impressed that Tyler stood
# I am so indebted that even in sorrow u heard me.
# I am so indebted that u heard
# Rommel was so indignant that the British expected to find his headquarters 250 miles behind his front.
# Rommel was so indignant that British expected
# His pleas were so insistent that they virtually amounted to insubordination.
# pleas were so insistent that they amounted
# Black columnists were so irate that some black men willingly took these kinds of jobs.
# columnists were so irate that men took
# Lian Po was so jealous that he swore enmity between the two of them.
# Po was so jealous that he swore
# The Timucua chiefs were so outraged that they organized a revolt against the Spanish in 1656.
# chiefs were so outraged that they organized
# Elaine is so outraged that he stole her idea.
# Elaine is so outraged that he stole
# Duvall eventually became so overwhelmed by the stress of her role that she became physically ill for months.
# Duvall became so overwhelmed that she became
# When the news reached Chang'an, Emperor Dezong was so panicked that he considered fleeing Chang'an, but remained due to Li Sheng's advice.
# Dezong was so panicked that he considered
# After a series of fires in 1741, the city became so panicked that blacks planned to burn the city in conspiracy with some poor whites.
# city became so panicked that blacks planned
# The monk was so pleased that he thereafter followed Pramati wherever he went.
# monk was so pleased that he followed
# I really enjoyed doing it and I'm so pleased that I took the opportunity when it came my way.
# unable to find expected POS with spacy
# The response was so positive that she scheduled a game between the freshman and sophomore classes.
# response was so positive that she scheduled
# An hour later, however, they're still alive which confuses Elijah and Rebekah, as they were so positive that Klaus originated their bloodline and were sure it wasn't Kol Mikaelson (Nathaniel Buzolic).
# they were so positive that Klaus originated
# In November 1907, rumors were so prevalent that Baird and Fitzpatrick intended to resign unless Michigan withdrew from the conference.
# rumors were so prevalent that Baird intended
# Mandhata had dominated the whole planet and he became so proud that he wanted to rule heaven also.
# he became so proud that he wanted
# My dad was so proud that his son made "aliyah".
# dad was so proud that son made
# Some of his children were so resentful that he gave them no special privileges and treated their mothers poorly.
# Some were so resentful that he gave
# Her mother Demeter, the goddess of the harvest, was so sad that she struck the world with fall and winter.
# mother was so sad that she struck
# Although he had mixed feelings with his dad, he still felt so sad that he died.
# he felt so sad that he died.
# It has also been noted that he was so satisfied that he did this without fee or reward and was publicly thanked.
# he was so satisfied that he did
# The main character designer noted he was so satisfied that fans enjoyed this look.
# he was so satisfied that fans enjoyed
# Hu was so scared that he fell and fainted.
# Hu was so scared that he fell
# Kkusum's phone rings and Abhay and Esha are so scared that someone heard them.
# Abhay are so scared that someone heard
# Sima Yi was so shocked that he immediately apologised to his wife and reconciled with her.
# Yi was so shocked that he apologised
# In the police court, Mrs. Jones says she was so shocked that her husband had the box.
# she was so shocked that husband had
# Its tone he employed was so strong that the king disavowed him and so Niebuhr retired from politics.
# tone was so strong that king disavowed
# Charlie is so stunned that Mary won.
# Charlie is so stunned that Mary won.
# The Russians by now were so sure of victory that they brought up trains from Warsaw to transport the expected prisoners.
# Russians were so sure that they brought
# I am so sure that the lack of men on stage made some men feel excluded.
# I am so sure that lack made
# The judges were so surprised that one of them had a "spasm," one leaned against the wall for support, and the other fell backwards into a barrel of flour!
# judges were so surprised that one had
# The fans were so surprised that El General (Franco) sang a salsa song.
# fans were so surprised that General sang
# Mary Martin was so thrilled that when she sang it on stage, she performed cartwheels on the stage at every turn of "I'm in love.".
# Martin was so thrilled that she performed
# But I was so thrilled that my mother typed them.
# I was so thrilled that mother typed
# She was so unhappy in this environment that she left school at fifteen despite the pleasure she gained from studying.
# She was so unhappy that she left
# Though the negative attention fades away, Marge is so unhappy that Max changed his name without consulting her.
# Marge is so unhappy that Max changed
# When he merely sailed down a rope wearing a pair of wings and attached to a pulley, the spectators were so unimpressed that he had to escape into the maze to get away from them.
# spectators were so unimpressed that he had
# They were so unimpressed that a fundamental functional change to the default behaviour of Net-Lib occurred without more than a passing mention in an unrelated document.
# They were so unimpressed that change occurred
# One woman was so unnerved by their presence that she left shortly after arrival.
# woman was so unnerved that she left
# He found that many of the punters enjoyed his performances, although was so unnerved that some of them made sexual advances toward him.
#
# unable to find expected POS with spacy
# Mendelssohn was so upset that he immediately went to get a haircut to differentiate himself.
# Mendelssohn was so upset that he went
# He was so upset that Emma exhibited greater control of his powers than he had.
# He was so upset that Emma exhibited
# This rumor was so widespread that it lived long until the 1950s.
# rumor was so widespread that it lived
# In Burma, the belief was once so widespread that the Sumatran rhino ate fire.
# belief was so widespread that rhino ate
# He was so worried that he spent an evening memorising two dozen riders he did not know.
# He was so worried that he spent
# Matthews was so worried that his career had only four years left and wanted to end it near his business.
# Matthews was so worried that career had
# By the 1st century BC the Celts had become so Hellenized that some Greek writers called them "Hellenogalatai" (Ἑλληνογαλάται).
# Celts become so Hellenized that writers called
# By 2007, the district had become so Republican that a lone Democratic House candidate received less than 12 percent of the vote.
# district become so Republican that candidate received
# The growth was so abrupt that a village sprang.
# growth was so abrupt that village sprang.
# These trout were once so abundant that there was a commercial fishery for them in the late 19th century.
# trout were so abundant that there was
# Many threats were so abusive that police had to conduct an investigation of them.
# threats were so abusive that police had
# His ministrations were so acceptable that the congregation soon extended a call to him, which he accepted, and was inducted into the charge on 16 December.
# ministrations were so acceptable that congregation extended
# By 1844, he was so accomplished that his father gathered together as much money as he could (apparently even selling the family piano) and sent him to study in Rome at the Accademia di San Luca.
# he was so accomplished that father gathered
# The stench was so acrid that some Swiss Guards fainted, and had to be rotated every 15 minutes.
# stench was so acrid that Guards fainted,
# The government's relationship with Bowen became so acrimonious that in 1938, Bowen threatened to use his reserve power to dismiss Aberhart.
# relationship became so acrimonious that Bowen threatened
# However she became so addicted that it killed her within 10 years.
# she became so addicted that it killed
# A VR shooting game, it became so addictive that the government assigned a young secret agent to investigate the arcade phenomenon in order to question its true purpose and to perform the impossible: to beat the game by taking control of the NA-00 space fighter craft, as those who played and lost against it were abducted as a result.
# it became so addictive that government assigned
# His death, one history noted "deprived the Order of a leader whose career had been so admirable that it gave the promise of remarkable fruition.".
# career been so admirable that it gave
# Ventura, for example, was so adulated that he became a massively popular and influential politician on his return from a time in the United States, and was seen as a national symbol.
# Ventura, was so adulated that he became
# The location soon turned out to be so advantageous that the government decided to develop the village into a major industrial center.
#
# unable to find expected POS with spacy
# His Moorish maid was so affected with this that she learnt about the faith and converted to Roman Catholicism.
# maid was so affected that she learnt
# The chairman Cui Yi and the Yiteng Group were so aggrieved that they decided to pull out of the competition the following season and sold their squad to Dalian Shide F.C. for 8 million Yuan.
# chairman were so aggrieved that they decided
# What really happened was we were so alien that no one wanted to touch us.
# we were so alien that one wanted
# Overseas Vietnamese soldiers could become so alienated with their experiences that they became soft targets for communist propaganda.
# soldiers become so alienated that they became
# However, when he learned that most Frenchmen were somewhat cool to this display of informality, Giscard became so aloof and distant that his opponents frequently attacked him as being too far removed from ordinary citizens.
# Giscard became so aloof that opponents attacked
# This was so amazing that Solomon decided to put it on display for everyone in Reading.
# This was so amazing that Solomon decided
# This playing for wind was so apparent that the Michigan players finally burlesqued it.
# playing was so apparent that players burlesqued
# Some of the situations are fairly disturbing, and the two main characters are so anguished in their own way that I found it a complete downer.
# characters are so anguished that I found
# The latter was so annoying to the occupying German authorities that it became illegal to stand on a bus if seats were available.
# latter was so annoying that it became
# Connor was so antagonistic towards the Civil Rights Movement that his actions galvanized support for black Americans.
# Connor was so antagonistic that actions galvanized
# The law library in Montreal was so antiquated that Crown Attorneys sometimes had to ask defense lawyers for information on the current jurisprudence.
# library was so antiquated that Attorneys had
# The performance by Fosse players was so appalling that The Football League ordered an enquiry, although no further action was taken after it turned out several of the already relegated Leicester side were hungover from a player's wedding the night before.
# performance was so appalling that League ordered
# His masterclasses were so appreciated that he had hundreds of students from all the continents.
# masterclasses were so appreciated that he had
# Justice Kennedy indicated that, on his view, a regulation of private property could perhaps be so arbitrary or irrational that it violated Constitutional guarantees of due process.
# regulation be so arbitrary that it violated
# He is also said to have taught Asclepiodotus, until Asclepiodotus became so argumentative that Domninus no longer admitted him into his company.
# Asclepiodotus became so argumentative that Domninus admitted
# Under the Servian Organization, the assembly was so aristocratic that the officer class and the first class of enlisted soldiers controlled enough centuries for an outright majority.
# assembly was so aristocratic that class controlled
# Feng became so arrogant that he showed open contempt for Li Bian's insistence on peace, praising Li Jing instead for Li Jing's willingness to use force.
# Feng became so arrogant that he showed
# a critic on one occasion spoke of his performance being so artistic that he seemed like a professional in a company of amateurs.
# performance being so artistic that he seemed
# Physicists at one time were so assured of the deceleration of the universe's expansion that they introduced a so-called deceleration parameter.
# Physicists were so assured that they introduced
# On one occasion the weather was so atrocious that the teams decided to go in watch some of the indoor sports.
# weather was so atrocious that teams decided
# Some of the residents like Cookie Lewis are so attached to the nun that she adopted her surname.
# Some are so attached that she adopted
# Linton's letters are so attractive that most likely Heathcliff wrote them to draw Cathy to the Heights.
# letters are so attractive that Heathcliff wrote
# The regime was so austere that seven companions died of cold and hunger.
# regime was so austere that companions died
# His mannerisms on camera were so awkward that some viewers believed the host suffered from Bell's palsy.
# mannerisms were so awkward that viewers believed
# The initial versions were so basic that the interior dashboard even lacked a fan blower opening as a standard.
# versions were so basic that dashboard lacked
# The palace was so beautiful that the king of Mengwi heard of Tan Cin Jin.
# palace was so beautiful that king heard
# The deceptive plan was so believable that a mob of angry American patriots raided Honeyman's house in Griggstown.
# plan was so believable that mob raided
# For this reason a remonstrance was prepared, penned by William Aspinwall, but the initial version was so belligerent that further edits had to be made to tone down the rhetoric.
# version was so belligerent that edits had
# Bishop Apollinaris was so beloved that the news of his first illness filled the city with consternation.
# Apollinaris was so beloved that news filled
# Astaire was so bereaved that he wanted to shut down the picture and offered to pay the production costs out of his pocket.
# Astaire was so bereaved that he wanted
# This became so evident that the Ottoman authorities prohibited the postcard distribution at a certain point.
# This became so evident that authorities prohibited
# His exploits were so bizarre that the geographer Sir Henry Yule disbelieved them.
# exploits were so bizarre that geographer disbelieved
# Clues actually missed Risman but the attempt was so blatant that the referee had to send Clues off.
# attempt was so blatant that referee had
# If the area around the school became so blighted that parents feared to send their children, the school would cease to be effective.
# area became so blighted that parents feared
# Nigel is so blind that he actually thought he was saving a beautiful damsel in distress at the time.
# Nigel is so blind that he thought
# Secondly, with the exception of the commander-in-chief and a handful of others, everyone was greedy to profit from the war itself and their conversation was so bloodthirsty that I shuddered at the prospect of victory.
# conversation was so bloodthirsty that I shuddered
# The scene was so bloody that it made Cranston's daughter faint during a screening.
# scene was so bloody that it made
# He was so blunt that he reported a serious crime to the emperor despite of his own life.
# He was so blunt that he reported
# Foxe was so bookish that he ruined his health by his persistent study.
# Foxe was so bookish that he ruined
# Trude was so bored that she spent her time drawing caricatures of her teacher.
# Trude was so bored that she spent
# In fact, after I'd sold three novels, I felt so brave that I gave up my advertising job.
# I felt so brave that I gave
# However, they were so brazen that Massachusetts briefly became the arson capital of the entire United States, attracting the attention of Federal BATF investigators, who unravelled the plot. U.S. Attorney William F. Weld began handing down indictments in July 1984.
# they were so brazen that Massachusetts became
# His stay was so brief that no credit known for his work there survived.
# stay was so brief that credit survived.
# They were so brilliant that the press assumed they were new.
# They were so brilliant that press assumed
# The ranking Democrat on the Armed Services Committee, Sen. Carl Levin of Michigan, thought the program was so ridiculous that he thought initial reports of it were the result of a hoax.
# program was so ridiculous that he thought
# But, a friend was so adamant that I tried it.
# friend was so adamant that I tried
# The actor was so apologetic that it made me cringe.
# actor was so apologetic that it made
# Christine immediately responded and was so apologetic that something broke.
#
# unable to find expected POS with spacy
# Though in one books instance I was so appalled that I stopped reading it and never read the author again.
# I was so appalled that I stopped
# Which is why I'm so appalled that she had the audacity to release such an album.
# unable to find expected POS with spacy
# I'm so ashamed that I bought it.
# unable to find expected POS with spacy
# I am so ashamed of myself that I ignored other reviewers and paid money for this book.
# I am so ashamed that I ignored
# I am so astounded that anyone liked this film.
# I am so astounded that anyone liked
# Faulks was so aware and so stunned by the horrific loss in WW1 that he wanted to write about it.
# Faulks was so aware that he wanted
# I was so aware that this bottle required a separate purchase to be able to mount it to your bike.
# I was so aware that bottle required
# After watching the 4th season on tv, I was so awed that I bought the Deluxe Edition with the faith it would be as good if not better than the 4th season.
# I was so awed that I bought
# My daughter was so bugged that after all the beads were strung there was still about a third of the string left.
# daughter was so bugged that there was
# I was so bugged throughout this lame movie that I felt quite angry I lost 2 hours of my life.
# I was so bugged that I felt
# I was so bummed that Scarlet was abducted so early on.
# unable to find expected POS with spacy
# I was so bummed that I cried.
# I was so bummed that I cried.
# I was so confident that I made changes on my own.
# I was so confident that I made
# I am so confident that I purchased the perfect dryer!
# I am so confident that I purchased
# I was so confused that I almost sent it back.
# I was so confused that I sent
# Okay, I am so confused that the HD collecion made it onto Xbox 360.
# I am so confused that collecion made
# I was so disapointed in this CD that I gave it to my roommate, but I do play it once every few months.
# I was so disapointed that I gave
# I was so discouraged that there was no OtterBox and then I got this.
# I was so discouraged that there was
# I was so discouraged that I gave up.
# I was so discouraged that I gave
# I was so dissapointed that it shut down.
# I was so dissapointed that it shut
# I was so dissapointed that i wrote this review.
# I was so dissapointed that i wrote
# I was so distressed that I tried to catch up with them, forgetting the purpose of learning.
# I was so distressed that I tried
# I was so disturbed that it took me this long.
# I was so disturbed that it took
# I'm so doubtful that the author even used an editor.
# unable to find expected POS with spacy
# I was so doubtful these would compare well to my Rockport Perths that I also ordered more of them, but I now actually prefer them.
# I was so doubtful that I ordered
# I bought one for my nephew's birthday and his brother was so envious that I bought him one a few months later.
# brother was so envious that I bought
# I am so envious that Jill Kargman put all of my best rock and roll thoughts on paper.
# I am so envious that Kargman put
# In the middle of the book, I was so fascinated that I also purchased the mini-series from Amazon for a song.
# I was so fascinated that I purchased
# My teacher was so frightened that I used these to cut metal, but I showed her how easy it was!
# teacher was so frightened that I used
# However, April was so frightened that she fainted.
# April was so frightened that she fainted.
# Billy tells us about the unusual neighbors that live on his street such as Mr. Grumpy who is so grumpy that butchers banned him from entering their shops because he always gives them grief when he goes to get some beef.
# who is so grumpy that butchers banned
# I was so heartbroken that I sent my husband to retrieve it.
# I was so heartbroken that I sent
# He was so honoured that upon upon his death he lay in state where thousands filed past to pay their last respects.
# He was so honoured that he lay
# We were so hopeful that we ordered the tables for when we traveled etc. of this same stuff.
# We were so hopeful that we ordered
# Seeing this in a jar, I was so hopeful that it had it's own well sealed jar protecting the powder from hardenin
# I was so hopeful that it had
# I gave this book as a Christmas gift and then the recipent was so intrigued that they ignored me for the next couple of hours.
# recipent was so intrigued that they ignored
# Trust me-I was so irritated that I went and looked it up.
# unable to find expected POS with spacy
# I was so mad that I had to stop reading to go to sleep though.
# I was so mad that I had
# I was so mad that I threw them in the trash.
# I was so mad that I threw
# I wanted to feel empathy for Elizabeth but she was so miserable that I felt nothing.
# she was so miserable that I felt
# I went to see it, and was so moved that I went back and saw it next week.
#
# unable to find expected POS with spacy
# Having also grown up with a similar mother, I was so moved that someone else felt exactly as I did towards a parent, especially in her latter days.
# I was so moved that someone felt
# She was so nervous that she crapped in it.
# She was so nervous that she crapped
# Years back a friend told me he saw the film in a theatre with his then-girlfriend, and they were so offended that they walked out 15 minutes before it was over.
# they were so offended that they walked
# I am so optimistic that I made the best choice.
# I am so optimistic that I made
# Like Napoleon, Hitler was so optimistic that he falsely believed he'd make it to Moscow before Winter.
# Hitler was so optimistic that he believed
# I was so overjoyed that Rachel found her mate.
# I was so overjoyed that Rachel found
# I searched on Amazon and was able to locate the identical Remote and was so overjoyed that I purchased two just in case.
#
# unable to find expected POS with spacy
# I was so peeved that I put them away and basically forgot about them.
# I was so peeved that I put
# Yet, I was so peeved that one of Anna and St. Clair's other friends was hurt in the process of the two becoming a couple.
# unable to find expected POS with spacy
# A smoker would already be so pissed that she took his smoke and chucked it.
# smoker be so pissed that she took
# Xan was so pissed that he went into the cage to fight off some steam.
# Xan was so pissed that he went
# I am so relieved that I finally finished this book.
# I am so relieved that I finished
# I am so relieved that I wanted to share this with others who only want their cat to be back to normal and purring in their lap.
# I am so relieved that I wanted
# I was so right that everything was saturated.
# I was so right that everything was
# There are a couple of false notes along the way, such as a dreadful rendition in front of a room of people of "You're So Vain," but so many moments are so right that I had no trouble forgiving them the few missteps.
# moments are so right that I had
# ok Mz. Sole, you got me hooked on Cain, i'm so salty that the book ended but i am so ready for part 2.
# unable to find expected POS with spacy
# One bag was so salty that my joints swelled, thereby inflaming my arthritis.
# bag was so salty that joints swelled,
# Madonna might not seem like a writer, so I was so sceptical that she even wrote these books at all.
# I was so sceptical that she wrote
# First, I was so sceptical that I contacted the company personally to get a better feeling of how their customer service would go after I purchased it.
# I was so sceptical that I contacted
# I was so skeptical that it would do much, but being it wasn't particularly expensive I gave it a try.
# I was so skeptical that it do
# I was so skeptical that I used frozen blueberries and strawberries because I didn't want to waste my fresh ones in case this was a bust.
# I was so skeptical that I used
# I was so startled that I began to laugh and almost became a statistic.
# I was so startled that I began
# I am so startled that no one seemed to have a problem with the stage being held up, the women passengers being kidnapped and sold.
# I am so startled that one seemed
# The character Kate was so uncertain that her back and forth personality drove me crazy.
# character was so uncertain that personality drove
# Counter({'all': 258, 'successful': 129, 3: 100, 'multitoken': 89, 1: 68, 4: 64, 'multithat': 21, 2: 21, 'pos_spacy': 19, 5: 5})

# %%
def print_counts():
    c = Counter()
    for s in data_for_plot:
        c[s.aligned_ex.orig_example.label.value] += 1
    print(c)
print_counts()
# Out:
# Counter({3: 58, 4: 29, 1: 26, 2: 12, 5: 4})

# %%
successful_idxs = [x.aligned_ex.orig_example.id for x in data_for_plot]
print(sorted(successful_idxs))
# Out:
# [1, 2, 4, 10, 12, 14, 15, 16, 17, 18, 20, 21, 22, 24, 25, 26, 28, 32, 33, 35, 36, 46, 47, 50, 52, 54, 56, 57, 58, 60, 62, 63, 64, 66, 71, 74, 75, 77, 79, 86, 88, 95, 96, 98, 99, 101, 102, 103, 106, 107, 108, 109, 110, 112, 113, 117, 118, 119, 120, 121, 124, 125, 126, 133, 134, 136, 141, 143, 145, 146, 150, 156, 157, 159, 164, 167, 168, 173, 179, 182, 187, 193, 200, 212, 213, 214, 220, 222, 227, 228, 234, 235, 236, 237, 238, 240, 243, 246, 250, 257, 258, 259, 263, 264, 268, 270, 272, 275, 277, 283, 285, 286, 291, 292, 294, 296, 299, 301, 302, 307, 309, 310, 311, 312, 317, 318, 319, 320, 321]

# %%
from corpus_tools.zhou_cxs_so_difficult.corpus_leonie_eap_aap_cec import CxType
from rozlib.libs.statistics.utils_sklearn import fit_svm
# from utils.utils_sklearn import fit_svm
# from utils.utils_latex_matplot import save_fig
from matplotlib.colors import ListedColormap
from typing import List, Optional
from lib.utils.utils_misc import save_fig

import umap


# todo: move to plots
def plot_2d_tensors_umap(
        objects: List[GraphForEmbed],
        metric: str,
        nneighbors: int,
        min_dist: float,
        title: str = None,
        aggregate =False,
        label_points = False,
        random_state=4,
        ax: Optional = None,
        add_ax_titles=False,
        figsize=(5,5),
        s=50,
        savefigname: str = None,
        add_svm = False,
        add_legend = False,
        add_markers = True,
        colors = None
):
    """
    Embeds and plots a collection of 2D torch tensors using UMAP.

    Each tensor is flattened row-wise to create a 1D vector before embedding.
    The dots in the UMAP plot are colored based on the labels of the objects.

    Parameters:
    - objects: List of objects with the following properties:
        - `matrix`: 2D torch.Tensor to be embedded.
        - `label`: Label for coloring the corresponding point in the UMAP plot.
    """
    # Flatten each 2D tensor row-wise to create 1D vectors
    # data = [obj.adjusted_matrix.flatten().numpy() for obj in objects]

    data = [extract_values_from_indices(obj.adjusted_matrix, _topk_idcs).flatten().numpy() for obj in objects]
    # data = [compute_normalized_laplacian(obj.adjusted_matrix).flatten().numpy() for obj in objects]
    # data = [compute_column_dot_products(obj.adjusted_matrix).flatten().numpy() for obj in objects]
    labels = [obj.aligned_ex.orig_example.label.value for obj in objects]

    def label_map(l_in: int):
        if l_in in [1,2]:
            return 1
        else:
            return 2
    if aggregate:
        labels = [label_map(l) for l in labels]

    # Convert to numpy array for UMAP
    data = np.array(data)
    labels = np.array(labels)

    # Apply UMAP for dimensionality reduction
    reducer = umap.UMAP(n_neighbors=nneighbors, min_dist=min_dist, metric=metric, random_state=random_state)
    embedding = reducer.fit_transform(data)

    # Generate a discrete colormap
    unique_labels = np.unique(labels)
    # cmap = ListedColormap(plt.cm.tab10.colors[:len(unique_labels)])

    if colors is None:
        # swap first two colors to match histogram
        # colors = plt.cm.Dark2.colors[:len(unique_labels)][::-1]
        colors = Colors.cec_clist[:len(unique_labels)][::-1]

    cmap = ListedColormap(colors)

    # Plot the UMAP embedding
    if not ax:
        fig, ax = plt.subplots(figsize=figsize)
    else:
        fig = None

    marker_labels = [i-1 for i in labels]
    if add_markers:
        markers = ['o', '^']
        marker_list = np.choose(marker_labels, markers)
    else:
        markers = ['o']
        marker_list = np.array(['o'] * len(labels))

    # plot based on marker
    for i, marker in enumerate(markers):
        mask = marker_list == marker
        scatter = ax.scatter(
            embedding[mask, 0],
            embedding[mask, 1],
            # note that just using c and cmap won't work bc each group gets the same color
            c=cmap(i),
            # c=labels[mask],
            # cmap=cmap,
            s=s,
            alpha=0.7,
            # edgecolor="k",
            marker=marker
        )
    # scatter = ax.scatter(
    #     embedding[:, 0], embedding[:, 1], c=labels, cmap=cmap, s=s, alpha=0.7, edgecolor="k",
    # )
    if add_svm:
        xx, yy, Z = fit_svm(embedding, labels)
        plt.contour(xx, yy, Z, levels=[0], linewidths=1, colors="black", linestyles="dashed")  # Decision boundary

    if add_legend:
        ax.legend(
            handles=scatter.legend_elements()[0],
            labels=[CxType.pretty_name_for_value(label) for label in unique_labels],
            loc="lower left",
            frameon=False,
            handletextpad=0,
            borderpad=0,
            labelspacing=0,
            # bbox_to_anchor=(0,1)
            # title="Labels",
        )

    # Add labels to each point
    if label_points:
        for i, obj in enumerate(objects):
            # if not obj.aligned_ex.orig_example.id in [1, 320, 270, 95, 286]: continue
            # if not obj.aligned_ex.orig_example.id in [1, 320, 270, 95, 286, 113, 10, 301]: continue
            # if not obj.aligned_ex.orig_example.id in [286, 113, 10, 301]: continue
            if not obj.aligned_ex.orig_example.id in [10, 113, 301, 99, 119]: continue
            # if not obj.aligned_ex.orig_example.id in [10, 113, 301, 99, 119, 1, 95, 286]: continue
            # if not obj.aligned_ex.orig_example.id in all_ambiguous_labels: continue
            ax.annotate(
                # r"\textbf{" + str(obj.aligned_ex.orig_example.id) + "}",
                obj.aligned_ex.orig_example.id,
                        (embedding[i, 0], embedding[i, 1]),
                        textcoords="offset points",
                        xytext=(3, 3),
                        ha='center',
                        fontsize=12
                        )

    # ax.add_artist(legend)
    # plt.title("UMAP: EAP vs AAP", fontsize=14)
    if title:
        ax.set_title(title, fontsize=14)
    if add_ax_titles:
        ax.set_xlabel("Embedding dimension 1")
        ax.set_ylabel("Embedding dimension 2")
    # ax.grid(True, which="both", alpha=0.3, linewidth=0.5)
    ax.grid(False, which="both")
    ax.set_xticks([])
    ax.set_yticks([])

    # todo
    if savefigname and fig:
        save_fig(fig, f"{savefigname}")
    return fig
    # ax.show()

# %%
def aap_filter(g: GraphForEmbed):
    if g.aligned_ex.orig_example.label.value == 1:
        return True
    return False

def eap_filter(g: GraphForEmbed):
    if g.aligned_ex.orig_example.label.value == 2:
        return True
    return False

def non_causal_filter(g: GraphForEmbed):
    if g.aligned_ex.orig_example.label.value < 3:
        return True
    else:
        return False

non_causal_exs: List[GraphForEmbed] = list(filter(non_causal_filter, data_for_plot))

aaps = list(filter(aap_filter, data_for_plot))
eaps = list(filter(eap_filter, data_for_plot))

aap_matrices = list(map(lambda x: x.adjusted_matrix, aaps))
eap_matrices = list(map(lambda x: x.adjusted_matrix, eaps))

def matrix_avg(matrix_list):
    return sum(matrix_list)/len(matrix_list)

aap_avg = matrix_avg(aap_matrices)
eap_avg = matrix_avg(eap_matrices)

# %%
from rozlib.libs.plotting.utils_latex_matplot import config_matplot_for_latex, FigSaver

# aap, eap -- note reversed from other orderings
leonie_colors = ['#785EF0', '#DC267F',]

config_matplot_for_latex(14)

# note that this global variable _topk_idcs passes info about
#  which positions to use in the umap projection
pp(aap_avg-eap_avg)
_topk_idcs = get_topk_indices(abs(aap_avg-eap_avg), 5)
pp(_topk_idcs)
# run do_correct first
do_label = True
f = plot_2d_tensors_umap(non_causal_exs, 'euclidean',
                         10,
                         0.1,
                         aggregate=False,
                     random_state=2,
                     # title=f"dims: {d}",
                     label_points=do_label,
                     ax=None,
                     add_ax_titles=False,
                     figsize=(3,3),
                     s=30,
                     savefigname=f"fig_3_eap_aap_umap_{do_correct}.pdf",
                     add_svm=True,
                     add_markers=True,
                     # colors=leonie_colors
                    colors=None
                     )
figsaver = make_fig_saver()
# figsaver.save(f, f"fig3_eap_aap_umap_{do_correct}.pdf")
figsaver.save(f, f"fig3_eap_aap_umap_{do_correct}_label_{do_label}.pdf")
# Out:
# tensor([[-4.1425e-02, -4.4070e-02, -1.0286e-01, -3.1205e-01,  2.1887e-02,
#           4.8793e-02,  2.9134e-02],
#         [-9.5237e-02, -1.1991e-01, -1.5352e-01, -1.5076e-01,  6.7727e-02,
#           4.6042e-02,  1.3394e-01],
#         [-3.3240e-01, -3.3951e-01,  1.5334e-01, -5.2611e-01, -1.1187e-03,
#          -4.6024e-04, -1.5112e-01],
#         [-2.7788e-01, -9.4856e-02, -3.1530e-01,  4.8118e-02,  6.3187e-03,
#           4.2497e-02, -1.4815e-03],
#         [-7.2422e-03,  5.1167e-02,  2.3387e-02, -5.2443e-02, -3.2438e-01,
#           6.6622e-02,  1.8485e-01],
#         [ 3.7504e-02,  3.7945e-02,  5.0645e-02,  1.9630e-02,  2.0118e-02,
#           1.5131e-02, -6.2097e-02],
#         [-3.2978e-02, -8.0944e-02,  9.5710e-03,  1.1519e-02,  2.5486e-01,
#          -2.5761e-01,  9.9314e-02]])
# tensor([0.5261, 0.3395, 0.3324, 0.3244, 0.3153])
# [(2, 3), (2, 1), (2, 0), (4, 4), (3, 2)]
# [(2, 3), (2, 1), (2, 0), (4, 4), (3, 2)]
# Initializing fig saver at dir /Users/jsrozner/docs_local/research/proj_code/rozner-mono-cxs-main/proj/cxs_are_revealed/supplemental/figs
# /Users/jsrozner/docs_local/research/proj_code/rozner-mono-cxs-main/rozlib-python/rozlib/libs/plotting/utils_latex_matplot.py:44: UserWarning: /Library/TeX/textbin will be added to path
#   warnings.warn(f"/Library/TeX/textbin will be added to path")
# /opt/homebrew/Caskroom/miniconda/base/envs/2024_coelm/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /var/folders/58/nkm5hbs97tz3vc0x5l5zl4w40000gn/T/ipykernel_91482/1392903272.py:95: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   scatter = ax.scatter(

# %%
from corpus_tools.zhou_cxs_so_difficult.corpus_leonie_eap_aap_cec import find_in_example_list

find_in_example_list(all_exs, 301)
# Out:
# BaseExample(id=301, adj='optimistic', label=<CxType.eap_noncausal: 2>, sentence_orig='I am so optimistic that I made the best choice .', _sentence_punct_fixed='I am so optimistic that I made the best choice.', has_error=False, multi_that=False, so_idx=2, adj_idx=3, that_idx=4)

# %%
# 4 with random seed 2
# _topk_idcs = get_topk_indices(abs(aap_avg-eap_avg), 20)
# print(_topk_idcs)

def make_multi_plot():
    dims = list(range(2,7))
    plots = list(range(0,3))
    fig, axes = plt.subplots(len(dims), len(plots), figsize=(8, 11))
    i = 0

    # make reproducible
    rng = np.random.default_rng(42)

    # higher dpi looks bad
    config_matplot_for_latex(14, legend_font_change=2, dpi=100)
    for i, d in enumerate(dims):
        for j,p in enumerate(plots):
            _topk_idcs = get_topk_indices(abs(aap_avg-eap_avg), d)
            ax = axes[i, j]
            plot_2d_tensors_umap(non_causal_exs, 'euclidean', 10, 0.1, aggregate=False,
                                 random_state=rng.integers(0, 1000000),
                                 # title=f"dims: {d}",
                                 label_points=True,
                                 ax=ax,
                                 figsize=(8/len(plots),11/len(dims)),
                                 s=20
                                 )
            # todo not sure why we needed
            ax.grid = False
            for spine in ax.spines.values():
                spine.set_color('black')
    for d, ax in zip(dims, axes[:,0]):
        ax.set_ylabel(d, rotation=0, labelpad=20)
    return fig
# todo
# save_fig(fig, f"umap_appendix_multi_{do_correct}.pdf")
# plot_2d_tensors_umap(data_for_plot, 'euclidean', 10, 0.1, aggregate=True)
f = make_multi_plot()
config_matplot_for_latex(dpi=500)
figsaver.save(f, f"fig12_umap_appendix_{do_correct}.pdf")
# Out:
# /Users/jsrozner/docs_local/research/proj_code/rozner-mono-cxs-main/rozlib-python/rozlib/libs/plotting/utils_latex_matplot.py:44: UserWarning: /Library/TeX/textbin will be added to path
#   warnings.warn(f"/Library/TeX/textbin will be added to path")
# /opt/homebrew/Caskroom/miniconda/base/envs/2024_coelm/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /var/folders/58/nkm5hbs97tz3vc0x5l5zl4w40000gn/T/ipykernel_91482/1392903272.py:95: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   scatter = ax.scatter(
# /opt/homebrew/Caskroom/miniconda/base/envs/2024_coelm/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /var/folders/58/nkm5hbs97tz3vc0x5l5zl4w40000gn/T/ipykernel_91482/1392903272.py:95: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   scatter = ax.scatter(
# /opt/homebrew/Caskroom/miniconda/base/envs/2024_coelm/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /var/folders/58/nkm5hbs97tz3vc0x5l5zl4w40000gn/T/ipykernel_91482/1392903272.py:95: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   scatter = ax.scatter(
# /opt/homebrew/Caskroom/miniconda/base/envs/2024_coelm/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /var/folders/58/nkm5hbs97tz3vc0x5l5zl4w40000gn/T/ipykernel_91482/1392903272.py:95: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   scatter = ax.scatter(
# /opt/homebrew/Caskroom/miniconda/base/envs/2024_coelm/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /var/folders/58/nkm5hbs97tz3vc0x5l5zl4w40000gn/T/ipykernel_91482/1392903272.py:95: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   scatter = ax.scatter(
# /opt/homebrew/Caskroom/miniconda/base/envs/2024_coelm/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /var/folders/58/nkm5hbs97tz3vc0x5l5zl4w40000gn/T/ipykernel_91482/1392903272.py:95: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   scatter = ax.scatter(
# /opt/homebrew/Caskroom/miniconda/base/envs/2024_coelm/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /var/folders/58/nkm5hbs97tz3vc0x5l5zl4w40000gn/T/ipykernel_91482/1392903272.py:95: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   scatter = ax.scatter(
# /opt/homebrew/Caskroom/miniconda/base/envs/2024_coelm/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# tensor([0.5261, 0.3395])
# [(2, 3), (2, 1)]
# tensor([0.5261, 0.3395])
# [(2, 3), (2, 1)]
# tensor([0.5261, 0.3395])
# [(2, 3), (2, 1)]
# tensor([0.5261, 0.3395, 0.3324])
# [(2, 3), (2, 1), (2, 0)]
# tensor([0.5261, 0.3395, 0.3324])
# [(2, 3), (2, 1), (2, 0)]
# tensor([0.5261, 0.3395, 0.3324])
# [(2, 3), (2, 1), (2, 0)]
# tensor([0.5261, 0.3395, 0.3324, 0.3244])
# [(2, 3), (2, 1), (2, 0), (4, 4)]
# tensor([0.5261, 0.3395, 0.3324, 0.3244])
# [(2, 3), (2, 1), (2, 0), (4, 4)]
# /var/folders/58/nkm5hbs97tz3vc0x5l5zl4w40000gn/T/ipykernel_91482/1392903272.py:95: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   scatter = ax.scatter(
# /opt/homebrew/Caskroom/miniconda/base/envs/2024_coelm/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /var/folders/58/nkm5hbs97tz3vc0x5l5zl4w40000gn/T/ipykernel_91482/1392903272.py:95: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   scatter = ax.scatter(
# /opt/homebrew/Caskroom/miniconda/base/envs/2024_coelm/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /var/folders/58/nkm5hbs97tz3vc0x5l5zl4w40000gn/T/ipykernel_91482/1392903272.py:95: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   scatter = ax.scatter(
# /opt/homebrew/Caskroom/miniconda/base/envs/2024_coelm/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /var/folders/58/nkm5hbs97tz3vc0x5l5zl4w40000gn/T/ipykernel_91482/1392903272.py:95: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   scatter = ax.scatter(
# /opt/homebrew/Caskroom/miniconda/base/envs/2024_coelm/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /var/folders/58/nkm5hbs97tz3vc0x5l5zl4w40000gn/T/ipykernel_91482/1392903272.py:95: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   scatter = ax.scatter(
# /opt/homebrew/Caskroom/miniconda/base/envs/2024_coelm/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /var/folders/58/nkm5hbs97tz3vc0x5l5zl4w40000gn/T/ipykernel_91482/1392903272.py:95: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   scatter = ax.scatter(
# /opt/homebrew/Caskroom/miniconda/base/envs/2024_coelm/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /var/folders/58/nkm5hbs97tz3vc0x5l5zl4w40000gn/T/ipykernel_91482/1392903272.py:95: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   scatter = ax.scatter(
# /opt/homebrew/Caskroom/miniconda/base/envs/2024_coelm/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /var/folders/58/nkm5hbs97tz3vc0x5l5zl4w40000gn/T/ipykernel_91482/1392903272.py:95: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   scatter = ax.scatter(
# /Users/jsrozner/docs_local/research/proj_code/rozner-mono-cxs-main/rozlib-python/rozlib/libs/plotting/utils_latex_matplot.py:44: UserWarning: /Library/TeX/textbin will be added to path
#   warnings.warn(f"/Library/TeX/textbin will be added to path")
# tensor([0.5261, 0.3395, 0.3324, 0.3244])
# [(2, 3), (2, 1), (2, 0), (4, 4)]
# tensor([0.5261, 0.3395, 0.3324, 0.3244, 0.3153])
# [(2, 3), (2, 1), (2, 0), (4, 4), (3, 2)]
# tensor([0.5261, 0.3395, 0.3324, 0.3244, 0.3153])
# [(2, 3), (2, 1), (2, 0), (4, 4), (3, 2)]
# tensor([0.5261, 0.3395, 0.3324, 0.3244, 0.3153])
# [(2, 3), (2, 1), (2, 0), (4, 4), (3, 2)]
# tensor([0.5261, 0.3395, 0.3324, 0.3244, 0.3153, 0.3121])
# [(2, 3), (2, 1), (2, 0), (4, 4), (3, 2), (0, 3)]
# tensor([0.5261, 0.3395, 0.3324, 0.3244, 0.3153, 0.3121])
# [(2, 3), (2, 1), (2, 0), (4, 4), (3, 2), (0, 3)]
# tensor([0.5261, 0.3395, 0.3324, 0.3244, 0.3153, 0.3121])
# [(2, 3), (2, 1), (2, 0), (4, 4), (3, 2), (0, 3)]

# %% [markdown]
# # heatmap
# adapted from exp1_extract_umap_including_other_approaches for Leonie's job talk 4/30 (dunno why we hadn't ported it over originally)

# %%
from pathlib import Path
from lib.plotting.plot_corr_matrix import plot_heatmap
config_matplot_for_latex(12, legend_font_change=0, dpi=500)
labels = [
    "subj",
    "verb",
    # r"\textbf{so}",
    "so",
    "adj",
    # r"\textbf{that}",
    "that",
    "subj",
    "verb"
]
# plot_heatmap(abs(aap_avg-eap_avg), labels, labels, cmap='coolwarm')
fig = plot_heatmap(
    # abs(aap_avg-eap_avg),
    aap_avg-eap_avg,
    labels,
    None,
    # cmap='Grays',
    cmap='RdBu',
    # add_colorbar=False,
    add_colorbar=True,
    fig_size=(4,4),
    return_fig=True,
    xlabel_rotation=45
    # title="Abs(avg(aap) - avg(eap))"
)

def label_color_bar(fig):
    ax = fig.axes[0]       # first Axes: main heatmap
    cbar_ax = fig.axes[1]  # second Axes: colorbar

    # Remove ticks from colorbar
    cbar_ax.tick_params(size=0, labelleft=False, labelright=False, labelbottom=False, labeltop=False)

    # Add label to colorbar
    # cbar_ax.set_ylabel("avg(AAP) - avg(EAP)", rotation=270, labelpad=15,
    #                    # , fontsize=12
    #                    )
    cbar_ax.text(1.1, 0.85, "higher\nin\nAAP", ha='left', va='bottom', transform=cbar_ax.transAxes)
    cbar_ax.text(1.1, 0.15, "higher\nin\nEAP", ha='left', va='top', transform=cbar_ax.transAxes)

label_color_bar(fig)
fig.show()

# note that this heatmap has differeent slopes in positive and negative regimes so that white is 0
# fs = FigSaver(Path(""))
fs = make_fig_saver()
fs.save(fig, "fig11_eap_aap_heatmap_color_legend.png")
# Out:
# /var/folders/58/nkm5hbs97tz3vc0x5l5zl4w40000gn/T/ipykernel_91482/2829394264.py:46: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# Initializing fig saver at dir /Users/jsrozner/docs_local/research/proj_code/rozner-mono-cxs-main/proj/cxs_are_revealed/supplemental/figs
