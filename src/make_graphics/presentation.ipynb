# %%
# %load_ext autoreload
# %autoreload 2

# %%
from lib.common.mlm_singleton import init_singleton_scorer
import os

# make sure we init the scorer for all modules first
mlm_scorer = init_singleton_scorer('roberta-large', output_attentions=True)


# make the warnings shut up (likely bc of latex call)
os.environ["TOKENIZERS_PARALLELISM"] = "true"
# Out:
# WARN: singleton already initialized; will not re-init

# %%
from pathlib import Path
from rozlib.libs.plotting.utils_latex_matplot import config_matplot_for_latex, FigSaver

# from utils.utils_latex_matplot import save_fig, config_matplot_for_latex, FigSaver

config_matplot_for_latex(12, dpi=500)
figs_dir = Path("/proj/cxs_are_revealed/supplemental/figs")
# fs = FigSaver()
if not "fs" in locals():
    # avoid redefine
    fs = FigSaver(figs_dir)
# Out:
# /Users/jsrozner/docs_local/research/projects/research_constructions/constructions_repo/rozlib-python/rozlib/libs/plotting/utils_latex_matplot.py:48: UserWarning: /Library/TeX/textbin will be added to path
#   warnings.warn(f"/Library/TeX/textbin will be added to path")

# %%
from pprint import pp
from affinity.tokenization import Sentence
s1 = "I saw my favorite band Green Day in concert."
s1_s = Sentence(s1)
s2 = "I saw my favorite band, Green Day, in concert."
s2_s = Sentence(s2)

pp(s2_s.word_encodings)
# Out:
# [WordEncoding(offset=(0, 1),
#               word_chars='I',
#               token_indices_in_tokenized_sent=[1],
#               token_words=['I'],
#               token_ids=[tensor(100)],
#               is_multiple_tokens=False),
#  WordEncoding(offset=(2, 5),
#               word_chars='saw',
#               token_indices_in_tokenized_sent=[2],
#               token_words=['saw'],
#               token_ids=[tensor(794)],
#               is_multiple_tokens=False),
#  WordEncoding(offset=(6, 8),
#               word_chars='my',
#               token_indices_in_tokenized_sent=[3],
#               token_words=['my'],
#               token_ids=[tensor(127)],
#               is_multiple_tokens=False),
#  WordEncoding(offset=(9, 17),
#               word_chars='favorite',
#               token_indices_in_tokenized_sent=[4],
#               token_words=['favorite'],
#               token_ids=[tensor(2674)],
#               is_multiple_tokens=False),
#  WordEncoding(offset=(18, 22),
#               word_chars='band',
#               token_indices_in_tokenized_sent=[5],
#               token_words=['band'],
#               token_ids=[tensor(1971)],
#               is_multiple_tokens=False),
#  WordEncoding(offset=(24, 29),
#               word_chars='Green',
#               token_indices_in_tokenized_sent=[7],
#               token_words=['Green'],
#               token_ids=[tensor(1628)],
#               is_multiple_tokens=False),
#  WordEncoding(offset=(30, 33),
#               word_chars='Day',
#               token_indices_in_tokenized_sent=[8],
#               token_words=['Day'],
#               token_ids=[tensor(1053)],
#               is_multiple_tokens=False),
#  WordEncoding(offset=(35, 37),
#               word_chars='in',
#               token_indices_in_tokenized_sent=[10],
#               token_words=['in'],
#               token_ids=[tensor(11)],
#               is_multiple_tokens=False),
#  WordEncoding(offset=(38, 45),
#               word_chars='concert',
#               token_indices_in_tokenized_sent=[11],
#               token_words=['concert'],
#               token_ids=[tensor(4192)],
#               is_multiple_tokens=False)]

# %%
from lib.plotting.plots import full_plot_single_sentence
from affinity.plots_new import full_plot_single_sentence_new

"""Green day examples"""
# from utils.plotting.plots import full_plot_single_sentence

# s1 = "I took a walk down memory lane."
s1 = "My favorite band is Green Day."
s1 = "I was so happy that I cried."
s1 = "I was so full that my stomach hurt."
s1 = "It was so big that it fell over."
config_matplot_for_latex(8, dpi=500)
s1 = "In the boxing match, they went jaw to jaw, exchanging fierce punches each round."
# s1 = "I took a trip down memory lane."
# s1 = "I bought a red shirt at the store."
s1 = "I was so sad that I had cried."
s1 = "In the bustling kitchen, the chef stacked pan upon pan, creating a towering monument of cookware."
s1 = "John is not playing his freshman year; he's red shirting."
s1 = "Nervous though he was, he still managed to do okay."
s1 = "That disaster, bad as it was, still pales in comparison to the hurricane of 1950."
s1 = ("Handsome though everyone expects me to try to force Bill to make Mom agree "
      "that Dick is, I'm still going to marry Herman.")

s1 = "I saw my favorite band Green Day in concert."
s1 = "I saw my favorite band , Green Day , in concert"
s1 = "That was so easy; it was a piece of cake."
s1 = "I don't like this topic; it is not my cup of tea."
# s1 = "Alice went to the hardware store and she bought a hammer."
# s1 = "My favorite is Green Day."
f = full_plot_single_sentence_new(s1,
                                  do_print=True,
                                  plot_local=True,
                                  use_euclid=False,
                                  num_preds=5,
                                  # normalize =False
                                  )
# fs.save(f)

# use save_fig to save these
# gaf1 = plot_everything(s1, plot_heamap=False)
# gaf1.insert(2, 0)   # for band
# gaf2 = plot_everything(s2, plot_heamap=False)
# Out:
# /Users/jsrozner/docs_local/research/projects/research_constructions/constructions_repo/rozlib-python/rozlib/libs/plotting/utils_latex_matplot.py:48: UserWarning: /Library/TeX/textbin will be added to path
#   warnings.warn(f"/Library/TeX/textbin will be added to path")
# Warning: multitoken
# (0, 1): (I, don't
# skipping multitok
# (0, 2): (I, like
# (0, 3): (I, this
# (0, 4): (I, topic
# (0, 5): (I, it
# (0, 6): (I, is
# (0, 7): (I, not
# (0, 8): (I, my
# (0, 9): (I, cup
# (0, 10): (I, of
# (0, 11): (I, tea
# (1, 0): (don't, I
# skipping multitok
# (1, 2): (don't, like
# skipping multitok
# (1, 3): (don't, this
# skipping multitok
# (1, 4): (don't, topic
# skipping multitok
# (1, 5): (don't, it
# skipping multitok
# (1, 6): (don't, is
# skipping multitok
# (1, 7): (don't, not
# skipping multitok
# (1, 8): (don't, my
# skipping multitok
# (1, 9): (don't, cup
# skipping multitok
# (1, 10): (don't, of
# skipping multitok
# (1, 11): (don't, tea
# skipping multitok
# (2, 0): (like, I
# (2, 1): (like, don't
# skipping multitok
# (2, 3): (like, this
# (2, 4): (like, topic
# (2, 5): (like, it
# (2, 6): (like, is
# (2, 7): (like, not
# (2, 8): (like, my
# (2, 9): (like, cup
# (2, 10): (like, of
# (2, 11): (like, tea
# (3, 0): (this, I
# (3, 1): (this, don't
# skipping multitok
# (3, 2): (this, like
# (3, 4): (this, topic
# (3, 5): (this, it
# (3, 6): (this, is
# (3, 7): (this, not
# (3, 8): (this, my
# (3, 9): (this, cup
# (3, 10): (this, of
# (3, 11): (this, tea
# (4, 0): (topic, I
# (4, 1): (topic, don't
# skipping multitok
# (4, 2): (topic, like
# (4, 3): (topic, this
# (4, 5): (topic, it
# (4, 6): (topic, is
# (4, 7): (topic, not
# (4, 8): (topic, my
# (4, 9): (topic, cup
# (4, 10): (topic, of
# (4, 11): (topic, tea
# (5, 0): (it, I
# (5, 1): (it, don't
# skipping multitok
# (5, 2): (it, like
# (5, 3): (it, this
# (5, 4): (it, topic
# (5, 6): (it, is
# (5, 7): (it, not
# (5, 8): (it, my
# (5, 9): (it, cup
# (5, 10): (it, of
# (5, 11): (it, tea
# (6, 0): (is, I
# (6, 1): (is, don't
# skipping multitok
# (6, 2): (is, like
# (6, 3): (is, this
# (6, 4): (is, topic
# (6, 5): (is, it
# (6, 7): (is, not
# (6, 8): (is, my
# (6, 9): (is, cup
# (6, 10): (is, of
# (6, 11): (is, tea
# (7, 0): (not, I
# (7, 1): (not, don't
# skipping multitok
# (7, 2): (not, like
# (7, 3): (not, this
# (7, 4): (not, topic
# (7, 5): (not, it
# (7, 6): (not, is
# (7, 8): (not, my
# (7, 9): (not, cup
# (7, 10): (not, of
# (7, 11): (not, tea
# (8, 0): (my, I
# (8, 1): (my, don't
# skipping multitok
# (8, 2): (my, like
# (8, 3): (my, this
# (8, 4): (my, topic
# (8, 5): (my, it
# (8, 6): (my, is
# (8, 7): (my, not
# (8, 9): (my, cup
# (8, 10): (my, of
# (8, 11): (my, tea
# (9, 0): (cup, I
# (9, 1): (cup, don't
# skipping multitok
# (9, 2): (cup, like
# (9, 3): (cup, this
# (9, 4): (cup, topic
# (9, 5): (cup, it
# (9, 6): (cup, is
# (9, 7): (cup, not
# (9, 8): (cup, my
# (9, 10): (cup, of
# (9, 11): (cup, tea
# (10, 0): (of, I
# (10, 1): (of, don't
# skipping multitok
# (10, 2): (of, like
# (10, 3): (of, this
# (10, 4): (of, topic
# (10, 5): (of, it
# (10, 6): (of, is
# (10, 7): (of, not
# (10, 8): (of, my
# (10, 9): (of, cup
# (10, 11): (of, tea
# (11, 0): (tea, I
# (11, 1): (tea, don't
# skipping multitok
# (11, 2): (tea, like
# (11, 3): (tea, this
# (11, 4): (tea, topic
# (11, 5): (tea, it
# (11, 6): (tea, is
# (11, 7): (tea, not
# (11, 8): (tea, my
# (11, 9): (tea, cup
# (11, 10): (tea, of
# ********************
# [0.9976012110710144, 0, 0.7302483320236206, 0.8387841582298279, 0.003611879190430045, 0.8420212268829346, 0.11474519968032837, 0.9917940497398376, 0.9910336136817932, 0.997393012046814, 0.9991164803504944, 0.994045078754425]
# multitoken indices are [1]
# [['I', 'We', 'You', 'People', 'They'],
#  ['</s>', '.', '<s>', '<pad>', '<unk>'],
#  [' like', ' enjoy', ' understand', ' love', ' follow'],
#  [' this', ' the', ' that', ' my', ' his'],
#  [' place', ' book', ' movie', ' game', ' one'],
#  [' it', ' this', ' religion', ' politics', ' sex'],
#  ["'s", ' is', ' was', ' just', ' s'],
#  [' not', ' just', ' hardly', ' NOT', ' never'],
#  [' my', ' our', ' your', ' a', ' their'],
#  [' cup', ' pot', ' kind', ' bag', ' type'],
#  [' of', ' o', ' or', ' if', ' fo'],
#  [' tea', ' coffee', ' water', ' Tea', ' cocoa']]

# %%
s = "My favorite is Green Day."
# all_words = s1.strip(".").split(" ")
# print(all_words)
# plot_single(gaf1, all_words, [])
full_plot_single_sentence(s)

# %%
config_matplot_for_latex(14)

words_1 = all_words.copy()
words_1[2] = (r"\dots .")
# plot_new([gaf1], words_1)
# plot_new([gaf2], all_words)

fig = plot_mult([
    ([gaf1], words_1),
    ([gaf2], all_words),
],
    overall_fig_size=(3,3),
    x_locs=[[2], []]
)
save_fig(fig, "gaf_green_day_band.pdf")
# Out:
# /Users/jsrozner/docs_local/_programming/research_constructions/constructions_repo/utils/utils_latex_matplot.py:62: UserWarning: /Library/TeX/textbin will be added to path
#   warnings.warn(f"/Library/TeX/textbin will be added to path")
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 10
#       4 words_1[2] = (r"\dots .")
#       5 # plot_new([gaf1], words_1)
#       6 # plot_new([gaf2], all_words)
#       8 fig = plot_mult([
#       9     ([gaf1], words_1),
# ---> 10     ([gaf2], all_words),
#      11 ],
#      12     overall_fig_size=(3,3),
#      13     x_locs=[[2], []]
#      14 )
#      15 save_fig(fig, "gaf_green_day_band.pdf")
#
# NameError: name 'gaf2' is not defined
